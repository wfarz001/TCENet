# %%
# !pip uninstall tensorflow 
# !pip install tensorflow-gpu==1.14

# %%
# !pip uninstall keras 
# !pip install keras==2.2.4

# %%
pip install h5py==2.10.0 --force-reinstall #need to install h5 ,otherwise it won't load the model properly

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# !cp /content/gdrive/MyDrive/Flood_Project/Image_Stylization/instancenormalization.py /content

# %%
from instancenormalization import InstanceNormalization
# Out:
# Using TensorFlow backend.

# %%
import os
import datetime
import keras
from keras.preprocessing.image import *
from keras.models import *
from keras.optimizers import *
from keras.layers import *
from keras_preprocessing.image import *
from keras import backend as K
from keras.callbacks import TensorBoard
from keras import losses
import random
import h5py

# %%
class CycleGAN():

    def __init__(self):

        self.sess = K.get_session()
        self.log_path = '/content/gdrive/MyDrive/Flood_Project/Image_Stylization/logs_car_water'
        self.domain_A_data_dir = '/content/gdrive/MyDrive/Flood_Project/Image_Stylization/Synthetic_to_Real/data_car_water/'
        self.domain_B_data_dir = '/content/gdrive/MyDrive/Flood_Project/Image_Stylization/Synthetic_to_Real/data_car_water/'
        self.f_size = 3
        self.first_f_size = 7
        self.d_f_size = 3
        self.leakyrel_alpha = 0.2
        self.img_height = 256
        self.img_width = 256
        self.img_channels = 3
        self.discr_dropout_rate = 0.0
        self.resblock_dropout = 0.5
        self.img_shape = (self.img_height, self.img_width, self.img_channels)
        self.image_data_generator = ImageDataGenerator(horizontal_flip=True)
        self.save_gens = 100
        self.batch_size = 1

        self.domain_A_datagen = self.image_data_generator.flow_from_directory(directory=self.domain_A_data_dir,
                                                                              target_size=(
                                                                              self.img_height, self.img_width),
                                                                              color_mode='rgb', classes=None,
                                                                              class_mode=None,
                                                                              batch_size=self.batch_size)
        self.domain_B_datagen = self.image_data_generator.flow_from_directory(directory=self.domain_B_data_dir,
                                                                              target_size=(
                                                                              self.img_height, self.img_width),
                                                                              color_mode='rgb', classes=None,
                                                                              class_mode=None,
                                                                              batch_size=self.batch_size)

        patch = int(self.img_height/2**4)
        self.disc_patch = (patch, patch, 1)

        self.g_f_ch = 32
        self.d_f_ch = 64

        self.lambda_perceptual_cycle_loss_wt = 10.0
        self.lambda_id_wt = 0.1 * self.lambda_perceptual_cycle_loss_wt
        self.mse_loss_wt = 1.0

        self.sample_modulus = 100
        self.id_modulus = 10
        self.stop_id = 100
        self.flip_labels_modulus = 0

        d_optimizer = Adam(lr=0.0002, beta_1=0.5)
        optimizer = Adam(lr=0.0002, beta_1=0.5)

        self.perceptual_model = self.build_perceptual_model()

        self.Disc_A = self.build_discriminator()
        self.Disc_B = self.build_discriminator()

        self.Disc_A.compile(loss=['mse'],
                            optimizer=d_optimizer, metrics=['accuracy'])
        self.Disc_B.compile(loss=['mse'],
                            optimizer=d_optimizer, metrics=['accuracy'])

        self.Gen_AB = self.build_generator()
        self.Gen_BA = self.build_generator()

        img_A = Input(shape=self.img_shape, name='image_A')
        img_B = Input(shape=self.img_shape, name='image_B')


        fake_B = self.Gen_AB([img_A])
        fake_A = self.Gen_BA([img_B])

        reconstruct_A = self.Gen_BA([fake_B])
        reconstruct_B = self.Gen_AB([fake_A])

        rec_content_A = self.perceptual_model(reconstruct_A)
        rec_content_B = self.perceptual_model(reconstruct_B)

        # Identity mapping of img

        img_A_id = self.Gen_BA([img_A])
        img_B_id = self.Gen_AB([img_B])

        self.Disc_A.trainable = False
        self.Disc_B.trainable = False

        valid_A = self.Disc_A(fake_A)
        valid_B = self.Disc_B(fake_B)

        comb_outputs = [valid_A, valid_B,
                    rec_content_A, rec_content_B
                    ]

        self.combined = Model(inputs=[img_A, img_B],
                        outputs=comb_outputs)

        self.combined.compile(
            loss=['mse', 'mse',
                  'mae', 'mae'
                  ],
            optimizer=optimizer,
            loss_weights = [self.mse_loss_wt, self.mse_loss_wt,
                            self.lambda_perceptual_cycle_loss_wt,
                            self.lambda_perceptual_cycle_loss_wt,
                            ])

        self.id_trainer = Model(inputs=[img_A, img_B],
                                outputs=[img_A_id, img_B_id])

        self.id_trainer.compile(loss=['mae', 'mae'],
                                optimizer=optimizer, loss_weights=[self.lambda_id_wt, self.lambda_id_wt])

    def build_perceptual_model(self):
        vgg = keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=(self.img_shape))
        content_layer = ['block5_conv3']
        #style_layers = ["block1_conv2", "block2_conv2", "block3_conv3", "block4_conv3", "block5_conv3"]
        # Get output layers corresponding to style and content layers
        content_outputs = [vgg.get_layer(name).output for name in content_layer ]
        model = Model(vgg.input, content_outputs)
        model.trainable = False
        model.summary()
        return model

    def build_generator(self):
        """U-Net/ Resblock Generator"""

        def conv2d(layer_input, filters, f_size=self.f_size, s=2):
            """Layers used during downsampling"""
            d_1 = Conv2D(filters, kernel_size=f_size, strides=s, padding='same')(layer_input)
            d_1 = LeakyReLU(self.leakyrel_alpha)(d_1)
            d = InstanceNormalization()(d_1)
            return d

        def deconv2d(layer_input, skip_input, filters, f_size=self.f_size, dropout_rate=0.0):
            """Layers used during upsampling"""
            u = UpSampling2D()(layer_input)
            u = Conv2D(filters=filters, kernel_size=f_size, strides=1, activation='relu', padding='same')(u)
            u = InstanceNormalization()(u)
            if skip_input is not None:
                u = Concatenate()([u, skip_input])
            if dropout_rate:
                u = Dropout(dropout_rate)(u)
            return u

        def residual_block(x, filters, f_size, dropout=self.resblock_dropout):
            if K.shape(x)[2] == filters:
                x = x
            else:
                x = Conv2D(filters=filters, kernel_size=f_size, strides=(1, 1), padding='same', activation='relu')(x)
                x = InstanceNormalization()(x)
            conv1 = Conv2D(filters=filters, kernel_size=f_size, strides=(1, 1), padding='same', activation='relu')(x)
            inst_norm = InstanceNormalization()(conv1)
            if dropout:
                inst_norm = GaussianDropout(dropout)(inst_norm)
            conv2 = Conv2D(filters=filters, kernel_size=f_size, strides=(1, 1), padding='same')(inst_norm)
            x = Add()([x, conv2])
            x = Activation('relu')(x)
            x = InstanceNormalization()(x)
            return x

        # Image input
        d0 = Input(shape=self.img_shape)

        # Downsampling
        d1 = conv2d(d0, self.g_f_ch, f_size=self.first_f_size, s=1)
        d1 = GaussianNoise(0.01)(d1)

        d2 = conv2d(d1, self.g_f_ch * 2)
        d3 = conv2d(d2, self.g_f_ch * 4)
        d4 = conv2d(d3, self.g_f_ch * 8)


        t1 = residual_block(d4, filters=self.g_f_ch * 8, f_size=self.f_size)
        t2 = residual_block(t1, filters=self.g_f_ch * 8, f_size=self.f_size)
        t3 = residual_block(t2, filters=self.g_f_ch * 8, f_size=self.f_size)
        t4 = residual_block(t3, filters=self.g_f_ch * 8, f_size=self.f_size)
        t5 = residual_block(t4, filters=self.g_f_ch * 8, f_size=self.f_size)
        t5 = GaussianNoise(0.01)(t5)
        t6 = residual_block(t5, filters=self.g_f_ch * 8, f_size=self.f_size)
        t7 = residual_block(t6, filters=self.g_f_ch * 8, f_size=self.f_size)
        t8 = residual_block(t7, filters=self.g_f_ch * 8, f_size=self.f_size)
        t9 = residual_block(t8, filters=self.g_f_ch * 8, f_size=self.f_size)
        t10 = residual_block(t9, filters=self.g_f_ch * 8, f_size=self.f_size)

        # Upsampling
        u1 = deconv2d(t10, skip_input=d3, filters=self.g_f_ch * 4)
        u2 = deconv2d(u1, skip_input=d2, filters=self.g_f_ch * 2)
        u3 = UpSampling2D(2)(u2)
        output_img = Conv2D(self.img_channels, kernel_size=self.first_f_size, strides=1, padding='same', activation='tanh')(u3)



        return Model([d0], output_img)

    # Discriminator

    def build_discriminator(self):

        def d_layer(layer_input, filters, dropout=self.discr_dropout_rate, f_size=self.d_f_size, normalization=True, s=2, dilation_rate=1):
            """Layers used during downsampling"""
            d = Conv2D(filters, kernel_size=f_size, strides=s, padding='same', dilation_rate=dilation_rate)(layer_input)
            d = LeakyReLU(self.leakyrel_alpha)(d)
            if normalization:
                d = InstanceNormalization()(d)
            if dropout:
                d = Dropout(dropout)(d)
            return d

        img = Input(shape=self.img_shape)
        d1 = d_layer(img, self.d_f_ch, f_size=self.first_f_size, normalization=False, s=1)
        d2 = d_layer(d1, self.d_f_ch * 2)
        d3 = d_layer(d2, self.d_f_ch * 4)
        d4 = d_layer(d3, self.d_f_ch * 8)
        d5 = d_layer(d4, self.d_f_ch * 16, dropout=0.05)
        validity = Conv2D(1, kernel_size=self.d_f_size, strides=1, padding='same', activation='linear')(d5)
        return Model(img, [validity])

    def write_log(self, callback, names, logs, batch_no):
        for name, value in zip(names, logs):
            summary = tf.Summary()
            summary_value = summary.value.add()
            summary_value.simple_value = value
            summary_value.tag = name
            callback.writer.add_summary(summary, batch_no)
            callback.writer.flush()

    def train(self, epochs):


        self.combined.summary()

        start_time = datetime.datetime.now()
        batch_size = self.batch_size

        # Adversarial loss ground truths
        valid = np.ones((batch_size,) + self.disc_patch) * 0.9
        fake = np.zeros((batch_size,) + self.disc_patch)

        for epoch in range(epochs):
            epoch = epoch+1

            imgs_A = self.domain_A_datagen.next()
            imgs_B = self.domain_B_datagen.next()

            imgs_A = (imgs_A*1/127.5)-1
            imgs_B = (imgs_B*1/127.5)-1

            # ----------------------
            #  Train Discriminators
            # ----------------------
            if self.flip_labels_modulus > 0 and epoch % self.flip_labels_modulus == 0:
                valid = np.zeros((batch_size,) + self.disc_patch)
                fake = np.ones((batch_size,) + self.disc_patch) * 0.9

            # Translate images to opposite domain
            fake_B_d_train = self.Gen_AB.predict([imgs_A])
            fake_A_d_train = self.Gen_BA.predict([imgs_B])

            # Train the discriminators (original images = real / translated = Fake)

            dA_loss_real = self.Disc_A.train_on_batch(imgs_A, [valid])
            dA_loss_fake = self.Disc_A.train_on_batch(fake_A_d_train, [fake])
            dA_loss = 0.5 * np.add(np.mean(dA_loss_real), np.mean(dA_loss_fake))

            dB_loss_real = self.Disc_B.train_on_batch(imgs_B, [valid])
            dB_loss_fake = self.Disc_B.train_on_batch(fake_B_d_train, [fake])
            dB_loss = 0.5 * np.add(np.mean(dB_loss_real), np.mean(dB_loss_fake))

            # Total disciminator loss
            d_loss = 0.5 * np.add(dA_loss, dB_loss)

            # ------------------
            #  Train Generators
            # ------------------
            # Train the generators

            fake_B = self.Gen_AB.predict([imgs_A])
            fake_A = self.Gen_BA.predict([imgs_B])

            content_A = self.perceptual_model.predict_on_batch(imgs_A)
            content_B = self.perceptual_model.predict_on_batch(imgs_B)

            g_loss = self.combined.train_on_batch([imgs_A, imgs_B],
                                                    [valid, valid,
                                                    content_A, content_B
                                                    ])

            elapsed_time = datetime.datetime.now() - start_time

            adversarial_g_loss = np.mean((g_loss[0:1]))
            perceptual_reconstruction_loss = np.mean((g_loss[2:]))

            # Print the progress

            print("[Epoch %d/%d] [D loss: %05f] [Adversarial_G_Loss: %05f, perc_recon: %05f] time: %s"
                        %(epoch, epochs,
                        d_loss, adversarial_g_loss,
                        perceptual_reconstruction_loss, str(elapsed_time)))

            if self.id_modulus > 0 and epoch % self.id_modulus == 0 and epoch < self.stop_id:
                id_loss = self.id_trainer.train_on_batch(x=[imgs_A, imgs_B], y=[imgs_A, imgs_B])
                print("[ID_loss_A: %05f, ID_loss_B: %05f, ID_loss_A_B: %05f] " %(id_loss[0], id_loss[1], np.mean((id_loss))))

            if self.sample_modulus > 0 and epoch % self.sample_modulus == 0:
                imgs_frame = np.concatenate([imgs_A, fake_B, imgs_B, fake_A])
                imgs_frame = imgs_frame.reshape(batch_size * 4 * self.img_height, self.img_width, self.img_channels)
                imgs_frame = array_to_img(imgs_frame)
                imgs_frame.save('/content/gdrive/MyDrive/Flood_Project/Image_Stylization/logs_car_water/epoch_%d.jpg' % (epoch))

            # Reset data_gens / shuffle
            if self.domain_A_datagen.n == self.domain_A_datagen.batch_index:
                self.domain_A_datagen.reset()
                self.domain_A_datagen.on_epoch_end()

            if self.domain_B_datagen.n == self.domain_B_datagen.batch_index:
                self.domain_B_datagen.reset()
                self.domain_B_datagen.on_epoch_end()

            if self.save_gens > 0 and epoch % self.save_gens == 0:
                self.Gen_AB.save('/content/gdrive/MyDrive/Flood_Project/Image_Stylization/logs_car_water/gen_ab_v2_%d.h5' %(epoch))
                self.Gen_BA.save('/content/gdrive/MyDrive/Flood_Project/Image_Stylization/logs_car_water/gen_ba_v2_%d.h5' %(epoch))


if __name__ == '__main__':
    gan = CycleGAN()
    gan.train(epochs=10000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Found 1000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# =================================================================
# Total params: 17,664,576
# Trainable params: 0
# Non-trainable params: 17,664,576
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_B (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# image_A (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# model_5 (Model)                 (None, 256, 256, 3)  18556107    image_B[0][0]
#                                                                  model_4[1][0]
# __________________________________________________________________________________________________
# model_4 (Model)                 (None, 256, 256, 3)  18556107    image_A[0][0]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 16, 16, 1)    6287497     model_5[1][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 16, 16, 1)    6287497     model_4[1][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 16, 16, 512)  17664576    model_5[2][0]
#                                                                  model_4[2][0]
# ==================================================================================================
# Total params: 67,351,784
# Trainable params: 37,112,214
# Non-trainable params: 30,239,570
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# [Epoch 1/10000] [D loss: 14.386544] [Adversarial_G_Loss: 529.944214, perc_recon: 87.459595] time: 0:01:05.880583
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# [Epoch 2/10000] [D loss: 39.817163] [Adversarial_G_Loss: 344.471497, perc_recon: 97.852165] time: 0:01:06.843801
# [Epoch 3/10000] [D loss: 57.235422] [Adversarial_G_Loss: 143.051941, perc_recon: 44.764145] time: 0:01:07.794223
# [Epoch 4/10000] [D loss: 22.397645] [Adversarial_G_Loss: 17.491999, perc_recon: 3.070479] time: 0:01:08.795107
# [Epoch 5/10000] [D loss: 1.311500] [Adversarial_G_Loss: 7.602695, perc_recon: 0.487606] time: 0:01:09.771480
# [Epoch 6/10000] [D loss: 1.903701] [Adversarial_G_Loss: 8.173613, perc_recon: 0.380455] time: 0:01:11.546164
# [Epoch 7/10000] [D loss: 0.779719] [Adversarial_G_Loss: 7.253612, perc_recon: 0.520539] time: 0:01:12.421341
# [Epoch 8/10000] [D loss: 0.363111] [Adversarial_G_Loss: 7.247888, perc_recon: 0.591716] time: 0:01:13.193102
# [Epoch 9/10000] [D loss: 0.319171] [Adversarial_G_Loss: 6.743420, perc_recon: 0.423694] time: 0:01:14.164602
# [Epoch 10/10000] [D loss: 0.321341] [Adversarial_G_Loss: 7.152357, perc_recon: 0.443320] time: 0:01:14.941014
# [ID_loss_A: 1.342390, ID_loss_B: 0.595117, ID_loss_A_B: 0.894927]
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Streaming output truncated to the last 5000 lines.
# [Epoch 5001/10000] [D loss: 0.319574] [Adversarial_G_Loss: 2.354332, perc_recon: 0.129905] time: 0:56:32.351416
# [Epoch 5002/10000] [D loss: 0.251303] [Adversarial_G_Loss: 2.530606, perc_recon: 0.147580] time: 0:56:32.970254
# [Epoch 5003/10000] [D loss: 0.292324] [Adversarial_G_Loss: 2.067503, perc_recon: 0.112137] time: 0:56:33.579187
# [Epoch 5004/10000] [D loss: 0.283628] [Adversarial_G_Loss: 2.689404, perc_recon: 0.129193] time: 0:56:34.197053
# [Epoch 5005/10000] [D loss: 0.291497] [Adversarial_G_Loss: 2.720260, perc_recon: 0.140928] time: 0:56:34.807298
# [Epoch 5006/10000] [D loss: 0.291892] [Adversarial_G_Loss: 2.911953, perc_recon: 0.146632] time: 0:56:35.421342
# [Epoch 5007/10000] [D loss: 0.281517] [Adversarial_G_Loss: 2.921785, perc_recon: 0.159802] time: 0:56:36.035328
# [Epoch 5008/10000] [D loss: 0.359912] [Adversarial_G_Loss: 3.275523, perc_recon: 0.164053] time: 0:56:36.650592
# [Epoch 5009/10000] [D loss: 0.316309] [Adversarial_G_Loss: 2.793131, perc_recon: 0.147208] time: 0:56:37.265491
# [Epoch 5010/10000] [D loss: 0.257562] [Adversarial_G_Loss: 1.734099, perc_recon: 0.109358] time: 0:56:37.877639
# [Epoch 5011/10000] [D loss: 0.305191] [Adversarial_G_Loss: 2.070246, perc_recon: 0.125750] time: 0:56:38.493772
# [Epoch 5012/10000] [D loss: 0.342044] [Adversarial_G_Loss: 1.802948, perc_recon: 0.122071] time: 0:56:39.105673
# [Epoch 5013/10000] [D loss: 0.257041] [Adversarial_G_Loss: 2.158743, perc_recon: 0.137242] time: 0:56:39.722971
# [Epoch 5014/10000] [D loss: 0.341680] [Adversarial_G_Loss: 2.177872, perc_recon: 0.131430] time: 0:56:40.331326
# [Epoch 5015/10000] [D loss: 0.325879] [Adversarial_G_Loss: 2.535771, perc_recon: 0.138909] time: 0:56:40.943157
# [Epoch 5016/10000] [D loss: 0.297429] [Adversarial_G_Loss: 2.886942, perc_recon: 0.155722] time: 0:56:41.561395
# [Epoch 5017/10000] [D loss: 0.305536] [Adversarial_G_Loss: 2.535199, perc_recon: 0.134213] time: 0:56:42.193386
# [Epoch 5018/10000] [D loss: 0.309506] [Adversarial_G_Loss: 2.738422, perc_recon: 0.139384] time: 0:56:42.810926
# [Epoch 5019/10000] [D loss: 0.273921] [Adversarial_G_Loss: 2.511140, perc_recon: 0.142034] time: 0:56:43.426084
# [Epoch 5020/10000] [D loss: 0.263565] [Adversarial_G_Loss: 2.689185, perc_recon: 0.148735] time: 0:56:44.040739
# [Epoch 5021/10000] [D loss: 0.251327] [Adversarial_G_Loss: 2.846934, perc_recon: 0.150508] time: 0:56:44.649052
# [Epoch 5022/10000] [D loss: 0.324033] [Adversarial_G_Loss: 2.878695, perc_recon: 0.139710] time: 0:56:45.259216
# [Epoch 5023/10000] [D loss: 0.284324] [Adversarial_G_Loss: 3.248317, perc_recon: 0.152901] time: 0:56:45.869061
# [Epoch 5024/10000] [D loss: 0.303177] [Adversarial_G_Loss: 3.170470, perc_recon: 0.161792] time: 0:56:46.480706
# [Epoch 5025/10000] [D loss: 0.299343] [Adversarial_G_Loss: 2.822934, perc_recon: 0.155035] time: 0:56:47.093176
# [Epoch 5026/10000] [D loss: 0.298219] [Adversarial_G_Loss: 3.245903, perc_recon: 0.166974] time: 0:56:47.708418
# [Epoch 5027/10000] [D loss: 0.299025] [Adversarial_G_Loss: 3.031823, perc_recon: 0.150036] time: 0:56:48.319259
# [Epoch 5028/10000] [D loss: 0.291415] [Adversarial_G_Loss: 3.139310, perc_recon: 0.155441] time: 0:56:48.931128
# [Epoch 5029/10000] [D loss: 0.301979] [Adversarial_G_Loss: 2.631574, perc_recon: 0.136265] time: 0:56:49.545818
# [Epoch 5030/10000] [D loss: 0.290010] [Adversarial_G_Loss: 2.901740, perc_recon: 0.152456] time: 0:56:50.165480
# [Epoch 5031/10000] [D loss: 0.273023] [Adversarial_G_Loss: 3.409365, perc_recon: 0.153251] time: 0:56:50.779663
# [Epoch 5032/10000] [D loss: 0.289081] [Adversarial_G_Loss: 2.914161, perc_recon: 0.138367] time: 0:56:51.392056
# [Epoch 5033/10000] [D loss: 0.278805] [Adversarial_G_Loss: 2.905800, perc_recon: 0.134088] time: 0:56:52.007133
# [Epoch 5034/10000] [D loss: 0.268251] [Adversarial_G_Loss: 2.815210, perc_recon: 0.126972] time: 0:56:52.622331
# [Epoch 5035/10000] [D loss: 0.296121] [Adversarial_G_Loss: 3.119473, perc_recon: 0.146859] time: 0:56:53.238893
# [Epoch 5036/10000] [D loss: 0.302316] [Adversarial_G_Loss: 2.545770, perc_recon: 0.128820] time: 0:56:53.858301
# [Epoch 5037/10000] [D loss: 0.289611] [Adversarial_G_Loss: 2.575453, perc_recon: 0.128521] time: 0:56:54.468985
# [Epoch 5038/10000] [D loss: 0.287431] [Adversarial_G_Loss: 2.880560, perc_recon: 0.147082] time: 0:56:55.080392
# [Epoch 5039/10000] [D loss: 0.303992] [Adversarial_G_Loss: 2.408228, perc_recon: 0.126101] time: 0:56:55.695170
# [Epoch 5040/10000] [D loss: 0.305522] [Adversarial_G_Loss: 2.425618, perc_recon: 0.132989] time: 0:56:56.312153
# [Epoch 5041/10000] [D loss: 0.292290] [Adversarial_G_Loss: 2.857361, perc_recon: 0.151737] time: 0:56:56.920847
# [Epoch 5042/10000] [D loss: 0.253412] [Adversarial_G_Loss: 2.917220, perc_recon: 0.137744] time: 0:56:57.532205
# [Epoch 5043/10000] [D loss: 0.300062] [Adversarial_G_Loss: 2.894022, perc_recon: 0.149558] time: 0:56:58.144906
# [Epoch 5044/10000] [D loss: 0.306174] [Adversarial_G_Loss: 2.382267, perc_recon: 0.126673] time: 0:56:58.762270
# [Epoch 5045/10000] [D loss: 0.304120] [Adversarial_G_Loss: 2.951193, perc_recon: 0.145834] time: 0:56:59.376574
# [Epoch 5046/10000] [D loss: 0.303582] [Adversarial_G_Loss: 2.526882, perc_recon: 0.129302] time: 0:56:59.990331
# [Epoch 5047/10000] [D loss: 0.306745] [Adversarial_G_Loss: 2.699361, perc_recon: 0.135396] time: 0:57:00.613922
# [Epoch 5048/10000] [D loss: 0.306647] [Adversarial_G_Loss: 3.000957, perc_recon: 0.142490] time: 0:57:01.228103
# [Epoch 5049/10000] [D loss: 0.330927] [Adversarial_G_Loss: 2.460356, perc_recon: 0.127364] time: 0:57:01.846240
# [Epoch 5050/10000] [D loss: 0.223185] [Adversarial_G_Loss: 3.087792, perc_recon: 0.140097] time: 0:57:02.461355
# [Epoch 5051/10000] [D loss: 0.305848] [Adversarial_G_Loss: 3.030329, perc_recon: 0.165805] time: 0:57:03.074505
# [Epoch 5052/10000] [D loss: 0.305851] [Adversarial_G_Loss: 2.735640, perc_recon: 0.145850] time: 0:57:03.697730
# [Epoch 5053/10000] [D loss: 0.239435] [Adversarial_G_Loss: 2.253100, perc_recon: 0.132449] time: 0:57:04.311634
# [Epoch 5054/10000] [D loss: 0.257942] [Adversarial_G_Loss: 2.361063, perc_recon: 0.124649] time: 0:57:04.936746
# [Epoch 5055/10000] [D loss: 0.204280] [Adversarial_G_Loss: 1.835409, perc_recon: 0.117474] time: 0:57:05.551207
# [Epoch 5056/10000] [D loss: 0.325997] [Adversarial_G_Loss: 2.408298, perc_recon: 0.131900] time: 0:57:06.165667
# [Epoch 5057/10000] [D loss: 0.305255] [Adversarial_G_Loss: 2.619015, perc_recon: 0.127368] time: 0:57:06.780081
# [Epoch 5058/10000] [D loss: 0.310312] [Adversarial_G_Loss: 2.338012, perc_recon: 0.133503] time: 0:57:07.394407
# [Epoch 5059/10000] [D loss: 0.300251] [Adversarial_G_Loss: 2.653956, perc_recon: 0.126255] time: 0:57:08.006580
# [Epoch 5060/10000] [D loss: 0.286973] [Adversarial_G_Loss: 2.652604, perc_recon: 0.130548] time: 0:57:08.628260
# [Epoch 5061/10000] [D loss: 0.276630] [Adversarial_G_Loss: 2.961979, perc_recon: 0.137380] time: 0:57:09.239971
# [Epoch 5062/10000] [D loss: 0.284059] [Adversarial_G_Loss: 2.793329, perc_recon: 0.132864] time: 0:57:09.861692
# [Epoch 5063/10000] [D loss: 0.302686] [Adversarial_G_Loss: 2.937529, perc_recon: 0.147521] time: 0:57:10.476434
# [Epoch 5064/10000] [D loss: 0.301372] [Adversarial_G_Loss: 2.662445, perc_recon: 0.132252] time: 0:57:11.096211
# [Epoch 5065/10000] [D loss: 0.291325] [Adversarial_G_Loss: 2.744156, perc_recon: 0.131976] time: 0:57:11.717395
# [Epoch 5066/10000] [D loss: 0.272755] [Adversarial_G_Loss: 2.603307, perc_recon: 0.123257] time: 0:57:12.331531
# [Epoch 5067/10000] [D loss: 0.307253] [Adversarial_G_Loss: 2.611669, perc_recon: 0.139797] time: 0:57:12.950707
# [Epoch 5068/10000] [D loss: 0.309823] [Adversarial_G_Loss: 2.455013, perc_recon: 0.127576] time: 0:57:13.563605
# [Epoch 5069/10000] [D loss: 0.267279] [Adversarial_G_Loss: 2.463883, perc_recon: 0.128651] time: 0:57:14.174038
# [Epoch 5070/10000] [D loss: 0.353190] [Adversarial_G_Loss: 2.373874, perc_recon: 0.129825] time: 0:57:14.784376
# [Epoch 5071/10000] [D loss: 0.294306] [Adversarial_G_Loss: 2.443581, perc_recon: 0.131311] time: 0:57:15.400215
# [Epoch 5072/10000] [D loss: 0.317303] [Adversarial_G_Loss: 2.478895, perc_recon: 0.142489] time: 0:57:16.013897
# [Epoch 5073/10000] [D loss: 0.260186] [Adversarial_G_Loss: 2.089678, perc_recon: 0.126518] time: 0:57:16.625059
# [Epoch 5074/10000] [D loss: 0.285996] [Adversarial_G_Loss: 1.855609, perc_recon: 0.120410] time: 0:57:17.239033
# [Epoch 5075/10000] [D loss: 0.338803] [Adversarial_G_Loss: 2.925131, perc_recon: 0.153701] time: 0:57:17.858442
# [Epoch 5076/10000] [D loss: 0.208852] [Adversarial_G_Loss: 3.172748, perc_recon: 0.148801] time: 0:57:18.470969
# [Epoch 5077/10000] [D loss: 0.354225] [Adversarial_G_Loss: 2.659991, perc_recon: 0.153295] time: 0:57:19.082349
# [Epoch 5078/10000] [D loss: 0.334734] [Adversarial_G_Loss: 2.456189, perc_recon: 0.144666] time: 0:57:19.694958
# [Epoch 5079/10000] [D loss: 0.314276] [Adversarial_G_Loss: 2.549462, perc_recon: 0.143551] time: 0:57:20.314534
# [Epoch 5080/10000] [D loss: 0.278584] [Adversarial_G_Loss: 2.329417, perc_recon: 0.128569] time: 0:57:20.924781
# [Epoch 5081/10000] [D loss: 0.299681] [Adversarial_G_Loss: 2.696769, perc_recon: 0.146116] time: 0:57:21.539191
# [Epoch 5082/10000] [D loss: 0.286723] [Adversarial_G_Loss: 1.963966, perc_recon: 0.121273] time: 0:57:22.161386
# [Epoch 5083/10000] [D loss: 0.341455] [Adversarial_G_Loss: 2.797892, perc_recon: 0.146814] time: 0:57:22.776862
# [Epoch 5084/10000] [D loss: 0.350268] [Adversarial_G_Loss: 2.663204, perc_recon: 0.151604] time: 0:57:23.390672
# [Epoch 5085/10000] [D loss: 0.338818] [Adversarial_G_Loss: 1.863517, perc_recon: 0.115558] time: 0:57:24.006213
# [Epoch 5086/10000] [D loss: 0.313673] [Adversarial_G_Loss: 2.079801, perc_recon: 0.121465] time: 0:57:24.625721
# [Epoch 5087/10000] [D loss: 0.313307] [Adversarial_G_Loss: 2.461681, perc_recon: 0.145292] time: 0:57:25.249214
# [Epoch 5088/10000] [D loss: 0.273351] [Adversarial_G_Loss: 2.651659, perc_recon: 0.147976] time: 0:57:25.870342
# [Epoch 5089/10000] [D loss: 0.326275] [Adversarial_G_Loss: 1.642878, perc_recon: 0.120686] time: 0:57:26.487379
# [Epoch 5090/10000] [D loss: 0.306977] [Adversarial_G_Loss: 2.197849, perc_recon: 0.133716] time: 0:57:27.099396
# [Epoch 5091/10000] [D loss: 0.285504] [Adversarial_G_Loss: 1.905579, perc_recon: 0.119989] time: 0:57:27.710360
# [Epoch 5092/10000] [D loss: 0.325471] [Adversarial_G_Loss: 1.841899, perc_recon: 0.115828] time: 0:57:28.318127
# [Epoch 5093/10000] [D loss: 0.308005] [Adversarial_G_Loss: 1.893215, perc_recon: 0.121708] time: 0:57:28.929478
# [Epoch 5094/10000] [D loss: 0.237756] [Adversarial_G_Loss: 1.897346, perc_recon: 0.116436] time: 0:57:29.540601
# [Epoch 5095/10000] [D loss: 0.253297] [Adversarial_G_Loss: 1.544954, perc_recon: 0.100163] time: 0:57:30.160666
# [Epoch 5096/10000] [D loss: 0.320842] [Adversarial_G_Loss: 2.051261, perc_recon: 0.128614] time: 0:57:30.776121
# [Epoch 5097/10000] [D loss: 0.321620] [Adversarial_G_Loss: 2.030467, perc_recon: 0.122431] time: 0:57:31.394732
# [Epoch 5098/10000] [D loss: 0.331168] [Adversarial_G_Loss: 2.461881, perc_recon: 0.144898] time: 0:57:32.006823
# [Epoch 5099/10000] [D loss: 0.321888] [Adversarial_G_Loss: 2.459055, perc_recon: 0.148433] time: 0:57:32.626404
# [Epoch 5100/10000] [D loss: 0.306506] [Adversarial_G_Loss: 1.854666, perc_recon: 0.113697] time: 0:57:33.240441
# [Epoch 5101/10000] [D loss: 0.313739] [Adversarial_G_Loss: 1.685757, perc_recon: 0.105037] time: 0:57:34.552269
# [Epoch 5102/10000] [D loss: 0.316127] [Adversarial_G_Loss: 2.234439, perc_recon: 0.128277] time: 0:57:35.175122
# [Epoch 5103/10000] [D loss: 0.282644] [Adversarial_G_Loss: 2.258461, perc_recon: 0.137481] time: 0:57:35.788110
# [Epoch 5104/10000] [D loss: 0.319051] [Adversarial_G_Loss: 1.689607, perc_recon: 0.117370] time: 0:57:36.417214
# [Epoch 5105/10000] [D loss: 0.317679] [Adversarial_G_Loss: 1.713343, perc_recon: 0.117448] time: 0:57:37.032516
# [Epoch 5106/10000] [D loss: 0.323990] [Adversarial_G_Loss: 2.048694, perc_recon: 0.126178] time: 0:57:37.648752
# [Epoch 5107/10000] [D loss: 0.305046] [Adversarial_G_Loss: 2.823840, perc_recon: 0.167837] time: 0:57:38.259987
# [Epoch 5108/10000] [D loss: 0.291587] [Adversarial_G_Loss: 2.845288, perc_recon: 0.159127] time: 0:57:38.874488
# [Epoch 5109/10000] [D loss: 0.322862] [Adversarial_G_Loss: 1.973847, perc_recon: 0.133838] time: 0:57:39.488681
# [Epoch 5110/10000] [D loss: 0.255537] [Adversarial_G_Loss: 2.491108, perc_recon: 0.138390] time: 0:57:40.105479
# [Epoch 5111/10000] [D loss: 0.317130] [Adversarial_G_Loss: 2.633284, perc_recon: 0.141538] time: 0:57:40.714346
# [Epoch 5112/10000] [D loss: 0.314270] [Adversarial_G_Loss: 2.285395, perc_recon: 0.130489] time: 0:57:41.327062
# [Epoch 5113/10000] [D loss: 0.222633] [Adversarial_G_Loss: 2.194865, perc_recon: 0.127557] time: 0:57:41.936867
# [Epoch 5114/10000] [D loss: 0.313362] [Adversarial_G_Loss: 2.366702, perc_recon: 0.141258] time: 0:57:42.552961
# [Epoch 5115/10000] [D loss: 0.321733] [Adversarial_G_Loss: 1.894929, perc_recon: 0.119026] time: 0:57:43.164106
# [Epoch 5116/10000] [D loss: 0.291968] [Adversarial_G_Loss: 1.937745, perc_recon: 0.119236] time: 0:57:43.788804
# [Epoch 5117/10000] [D loss: 0.298440] [Adversarial_G_Loss: 2.403991, perc_recon: 0.134057] time: 0:57:44.417944
# [Epoch 5118/10000] [D loss: 0.245310] [Adversarial_G_Loss: 2.045517, perc_recon: 0.127083] time: 0:57:45.042108
# [Epoch 5119/10000] [D loss: 0.317914] [Adversarial_G_Loss: 1.719900, perc_recon: 0.117013] time: 0:57:45.654977
# [Epoch 5120/10000] [D loss: 0.348743] [Adversarial_G_Loss: 1.913580, perc_recon: 0.124187] time: 0:57:46.262892
# [Epoch 5121/10000] [D loss: 0.337005] [Adversarial_G_Loss: 1.655165, perc_recon: 0.115665] time: 0:57:46.873071
# [Epoch 5122/10000] [D loss: 0.298862] [Adversarial_G_Loss: 1.856006, perc_recon: 0.119728] time: 0:57:47.482235
# [Epoch 5123/10000] [D loss: 0.315818] [Adversarial_G_Loss: 1.525807, perc_recon: 0.104812] time: 0:57:48.093014
# [Epoch 5124/10000] [D loss: 0.265483] [Adversarial_G_Loss: 3.520967, perc_recon: 0.188375] time: 0:57:48.709378
# [Epoch 5125/10000] [D loss: 0.337396] [Adversarial_G_Loss: 2.085667, perc_recon: 0.133131] time: 0:57:49.321604
# [Epoch 5126/10000] [D loss: 0.314199] [Adversarial_G_Loss: 2.643564, perc_recon: 0.157223] time: 0:57:49.932016
# [Epoch 5127/10000] [D loss: 0.301875] [Adversarial_G_Loss: 2.236455, perc_recon: 0.123381] time: 0:57:50.539487
# [Epoch 5128/10000] [D loss: 0.321410] [Adversarial_G_Loss: 1.958460, perc_recon: 0.129231] time: 0:57:51.149257
# [Epoch 5129/10000] [D loss: 0.319473] [Adversarial_G_Loss: 2.117560, perc_recon: 0.136972] time: 0:57:51.760720
# [Epoch 5130/10000] [D loss: 0.292542] [Adversarial_G_Loss: 2.037098, perc_recon: 0.116398] time: 0:57:52.374648
# [Epoch 5131/10000] [D loss: 0.328946] [Adversarial_G_Loss: 2.210731, perc_recon: 0.138165] time: 0:57:52.993062
# [Epoch 5132/10000] [D loss: 0.303429] [Adversarial_G_Loss: 2.257975, perc_recon: 0.140938] time: 0:57:53.604766
# [Epoch 5133/10000] [D loss: 0.276799] [Adversarial_G_Loss: 1.690173, perc_recon: 0.107642] time: 0:57:54.222418
# [Epoch 5134/10000] [D loss: 0.299090] [Adversarial_G_Loss: 1.953151, perc_recon: 0.118716] time: 0:57:54.835348
# [Epoch 5135/10000] [D loss: 0.307072] [Adversarial_G_Loss: 1.824605, perc_recon: 0.113742] time: 0:57:55.449838
# [Epoch 5136/10000] [D loss: 0.325534] [Adversarial_G_Loss: 1.744231, perc_recon: 0.114359] time: 0:57:56.064408
# [Epoch 5137/10000] [D loss: 0.315646] [Adversarial_G_Loss: 1.760198, perc_recon: 0.117044] time: 0:57:56.676680
# [Epoch 5138/10000] [D loss: 0.242106] [Adversarial_G_Loss: 2.416759, perc_recon: 0.147259] time: 0:57:57.284640
# [Epoch 5139/10000] [D loss: 0.279893] [Adversarial_G_Loss: 1.682374, perc_recon: 0.113073] time: 0:57:57.899902
# [Epoch 5140/10000] [D loss: 0.334770] [Adversarial_G_Loss: 2.166084, perc_recon: 0.134471] time: 0:57:58.512240
# [Epoch 5141/10000] [D loss: 0.335343] [Adversarial_G_Loss: 2.359953, perc_recon: 0.135593] time: 0:57:59.120582
# [Epoch 5142/10000] [D loss: 0.315865] [Adversarial_G_Loss: 2.321961, perc_recon: 0.145475] time: 0:57:59.732030
# [Epoch 5143/10000] [D loss: 0.313147] [Adversarial_G_Loss: 2.121428, perc_recon: 0.120507] time: 0:58:00.345526
# [Epoch 5144/10000] [D loss: 0.261685] [Adversarial_G_Loss: 1.940615, perc_recon: 0.117257] time: 0:58:00.958702
# [Epoch 5145/10000] [D loss: 0.252873] [Adversarial_G_Loss: 2.345272, perc_recon: 0.146557] time: 0:58:01.570506
# [Epoch 5146/10000] [D loss: 0.318770] [Adversarial_G_Loss: 2.239126, perc_recon: 0.132384] time: 0:58:02.186447
# [Epoch 5147/10000] [D loss: 0.306317] [Adversarial_G_Loss: 2.406314, perc_recon: 0.132721] time: 0:58:02.795761
# [Epoch 5148/10000] [D loss: 0.253517] [Adversarial_G_Loss: 2.292502, perc_recon: 0.139607] time: 0:58:03.403846
# [Epoch 5149/10000] [D loss: 0.317756] [Adversarial_G_Loss: 2.010467, perc_recon: 0.124862] time: 0:58:04.014500
# [Epoch 5150/10000] [D loss: 0.313463] [Adversarial_G_Loss: 2.035391, perc_recon: 0.128806] time: 0:58:04.623982
# [Epoch 5151/10000] [D loss: 0.306598] [Adversarial_G_Loss: 2.447667, perc_recon: 0.147336] time: 0:58:05.236751
# [Epoch 5152/10000] [D loss: 0.312110] [Adversarial_G_Loss: 1.766355, perc_recon: 0.110172] time: 0:58:05.850860
# [Epoch 5153/10000] [D loss: 0.297119] [Adversarial_G_Loss: 2.015001, perc_recon: 0.117947] time: 0:58:06.468609
# [Epoch 5154/10000] [D loss: 0.312826] [Adversarial_G_Loss: 1.776233, perc_recon: 0.118403] time: 0:58:07.077541
# [Epoch 5155/10000] [D loss: 0.247754] [Adversarial_G_Loss: 2.168187, perc_recon: 0.138512] time: 0:58:07.689797
# [Epoch 5156/10000] [D loss: 0.348222] [Adversarial_G_Loss: 2.036265, perc_recon: 0.120221] time: 0:58:08.302813
# [Epoch 5157/10000] [D loss: 0.321623] [Adversarial_G_Loss: 1.912614, perc_recon: 0.116859] time: 0:58:08.919475
# [Epoch 5158/10000] [D loss: 0.326081] [Adversarial_G_Loss: 2.060311, perc_recon: 0.141146] time: 0:58:09.531269
# [Epoch 5159/10000] [D loss: 0.310657] [Adversarial_G_Loss: 2.560136, perc_recon: 0.137386] time: 0:58:10.148656
# [Epoch 5160/10000] [D loss: 0.299624] [Adversarial_G_Loss: 2.240559, perc_recon: 0.124125] time: 0:58:10.754596
# [Epoch 5161/10000] [D loss: 0.271807] [Adversarial_G_Loss: 2.193259, perc_recon: 0.130409] time: 0:58:11.369446
# [Epoch 5162/10000] [D loss: 0.321157] [Adversarial_G_Loss: 2.397555, perc_recon: 0.145398] time: 0:58:11.989177
# [Epoch 5163/10000] [D loss: 0.276678] [Adversarial_G_Loss: 1.792009, perc_recon: 0.117793] time: 0:58:12.606543
# [Epoch 5164/10000] [D loss: 0.321650] [Adversarial_G_Loss: 2.070563, perc_recon: 0.125434] time: 0:58:13.220237
# [Epoch 5165/10000] [D loss: 0.303351] [Adversarial_G_Loss: 1.973367, perc_recon: 0.124451] time: 0:58:13.834577
# [Epoch 5166/10000] [D loss: 0.323703] [Adversarial_G_Loss: 2.190894, perc_recon: 0.135436] time: 0:58:14.443477
# [Epoch 5167/10000] [D loss: 0.314801] [Adversarial_G_Loss: 1.984296, perc_recon: 0.120125] time: 0:58:15.052744
# [Epoch 5168/10000] [D loss: 0.280155] [Adversarial_G_Loss: 2.163515, perc_recon: 0.134864] time: 0:58:15.660084
# [Epoch 5169/10000] [D loss: 0.317051] [Adversarial_G_Loss: 1.742153, perc_recon: 0.118257] time: 0:58:16.273436
# [Epoch 5170/10000] [D loss: 0.330402] [Adversarial_G_Loss: 2.114300, perc_recon: 0.125409] time: 0:58:16.888074
# [Epoch 5171/10000] [D loss: 0.312666] [Adversarial_G_Loss: 2.617706, perc_recon: 0.148087] time: 0:58:17.501429
# [Epoch 5172/10000] [D loss: 0.289810] [Adversarial_G_Loss: 2.003027, perc_recon: 0.115903] time: 0:58:18.119455
# [Epoch 5173/10000] [D loss: 0.284533] [Adversarial_G_Loss: 2.289676, perc_recon: 0.124288] time: 0:58:18.730074
# [Epoch 5174/10000] [D loss: 0.311938] [Adversarial_G_Loss: 2.443301, perc_recon: 0.130745] time: 0:58:19.343278
# [Epoch 5175/10000] [D loss: 0.337599] [Adversarial_G_Loss: 2.525940, perc_recon: 0.140404] time: 0:58:19.963123
# [Epoch 5176/10000] [D loss: 0.282140] [Adversarial_G_Loss: 2.767112, perc_recon: 0.141563] time: 0:58:20.575636
# [Epoch 5177/10000] [D loss: 0.232820] [Adversarial_G_Loss: 2.665059, perc_recon: 0.166953] time: 0:58:21.184648
# [Epoch 5178/10000] [D loss: 0.243101] [Adversarial_G_Loss: 2.289150, perc_recon: 0.139525] time: 0:58:21.796287
# [Epoch 5179/10000] [D loss: 0.296194] [Adversarial_G_Loss: 2.226335, perc_recon: 0.120071] time: 0:58:22.406926
# [Epoch 5180/10000] [D loss: 0.308799] [Adversarial_G_Loss: 2.365542, perc_recon: 0.130168] time: 0:58:23.023923
# [Epoch 5181/10000] [D loss: 0.277268] [Adversarial_G_Loss: 2.358839, perc_recon: 0.119828] time: 0:58:23.639169
# [Epoch 5182/10000] [D loss: 0.299779] [Adversarial_G_Loss: 2.485053, perc_recon: 0.132941] time: 0:58:24.253102
# [Epoch 5183/10000] [D loss: 0.287567] [Adversarial_G_Loss: 2.631968, perc_recon: 0.134249] time: 0:58:24.871042
# [Epoch 5184/10000] [D loss: 0.316116] [Adversarial_G_Loss: 3.241703, perc_recon: 0.163075] time: 0:58:25.480745
# [Epoch 5185/10000] [D loss: 0.311904] [Adversarial_G_Loss: 2.373305, perc_recon: 0.124808] time: 0:58:26.098716
# [Epoch 5186/10000] [D loss: 0.283833] [Adversarial_G_Loss: 3.077300, perc_recon: 0.140176] time: 0:58:26.715937
# [Epoch 5187/10000] [D loss: 0.283369] [Adversarial_G_Loss: 2.900101, perc_recon: 0.135871] time: 0:58:27.329802
# [Epoch 5188/10000] [D loss: 0.300093] [Adversarial_G_Loss: 2.596975, perc_recon: 0.129987] time: 0:58:27.941962
# [Epoch 5189/10000] [D loss: 0.286020] [Adversarial_G_Loss: 2.985416, perc_recon: 0.144764] time: 0:58:28.553400
# [Epoch 5190/10000] [D loss: 0.305432] [Adversarial_G_Loss: 2.901939, perc_recon: 0.152151] time: 0:58:29.170344
# [Epoch 5191/10000] [D loss: 0.298175] [Adversarial_G_Loss: 2.305549, perc_recon: 0.127887] time: 0:58:29.784686
# [Epoch 5192/10000] [D loss: 0.298757] [Adversarial_G_Loss: 2.768304, perc_recon: 0.137926] time: 0:58:30.396387
# [Epoch 5193/10000] [D loss: 0.288676] [Adversarial_G_Loss: 2.392350, perc_recon: 0.118076] time: 0:58:31.012841
# [Epoch 5194/10000] [D loss: 0.306996] [Adversarial_G_Loss: 2.817217, perc_recon: 0.141408] time: 0:58:31.629447
# [Epoch 5195/10000] [D loss: 0.307452] [Adversarial_G_Loss: 2.524606, perc_recon: 0.137734] time: 0:58:32.246363
# [Epoch 5196/10000] [D loss: 0.296995] [Adversarial_G_Loss: 3.050105, perc_recon: 0.142197] time: 0:58:32.866761
# [Epoch 5197/10000] [D loss: 0.279528] [Adversarial_G_Loss: 2.778064, perc_recon: 0.132953] time: 0:58:33.478324
# [Epoch 5198/10000] [D loss: 0.281968] [Adversarial_G_Loss: 2.378099, perc_recon: 0.116464] time: 0:58:34.093338
# [Epoch 5199/10000] [D loss: 0.320295] [Adversarial_G_Loss: 3.163109, perc_recon: 0.161164] time: 0:58:34.705984
# [Epoch 5200/10000] [D loss: 0.235557] [Adversarial_G_Loss: 2.310536, perc_recon: 0.104456] time: 0:58:35.321676
# [Epoch 5201/10000] [D loss: 0.268696] [Adversarial_G_Loss: 2.235358, perc_recon: 0.118430] time: 0:58:36.600704
# [Epoch 5202/10000] [D loss: 0.230229] [Adversarial_G_Loss: 2.494343, perc_recon: 0.128327] time: 0:58:37.214032
# [Epoch 5203/10000] [D loss: 0.265375] [Adversarial_G_Loss: 2.438976, perc_recon: 0.117720] time: 0:58:37.824641
# [Epoch 5204/10000] [D loss: 0.304303] [Adversarial_G_Loss: 2.544356, perc_recon: 0.125990] time: 0:58:38.451631
# [Epoch 5205/10000] [D loss: 0.298326] [Adversarial_G_Loss: 2.210205, perc_recon: 0.118678] time: 0:58:39.067451
# [Epoch 5206/10000] [D loss: 0.290624] [Adversarial_G_Loss: 1.960483, perc_recon: 0.132422] time: 0:58:39.676701
# [Epoch 5207/10000] [D loss: 0.312999] [Adversarial_G_Loss: 2.231925, perc_recon: 0.122458] time: 0:58:40.290018
# [Epoch 5208/10000] [D loss: 0.243139] [Adversarial_G_Loss: 2.212913, perc_recon: 0.131300] time: 0:58:40.904731
# [Epoch 5209/10000] [D loss: 0.307177] [Adversarial_G_Loss: 2.536808, perc_recon: 0.123773] time: 0:58:41.523660
# [Epoch 5210/10000] [D loss: 0.319436] [Adversarial_G_Loss: 2.736880, perc_recon: 0.135711] time: 0:58:42.134489
# [Epoch 5211/10000] [D loss: 0.301008] [Adversarial_G_Loss: 3.094904, perc_recon: 0.152649] time: 0:58:42.752510
# [Epoch 5212/10000] [D loss: 0.286049] [Adversarial_G_Loss: 2.891728, perc_recon: 0.140114] time: 0:58:43.369285
# [Epoch 5213/10000] [D loss: 0.307897] [Adversarial_G_Loss: 2.256613, perc_recon: 0.122590] time: 0:58:43.982638
# [Epoch 5214/10000] [D loss: 0.299651] [Adversarial_G_Loss: 2.474041, perc_recon: 0.117359] time: 0:58:44.594326
# [Epoch 5215/10000] [D loss: 0.290121] [Adversarial_G_Loss: 2.574153, perc_recon: 0.123076] time: 0:58:45.206189
# [Epoch 5216/10000] [D loss: 0.230025] [Adversarial_G_Loss: 2.357456, perc_recon: 0.131246] time: 0:58:45.834074
# [Epoch 5217/10000] [D loss: 0.336585] [Adversarial_G_Loss: 2.958124, perc_recon: 0.140856] time: 0:58:46.464175
# [Epoch 5218/10000] [D loss: 0.209426] [Adversarial_G_Loss: 2.519477, perc_recon: 0.136534] time: 0:58:47.082558
# [Epoch 5219/10000] [D loss: 0.307972] [Adversarial_G_Loss: 2.556640, perc_recon: 0.136134] time: 0:58:47.700317
# [Epoch 5220/10000] [D loss: 0.302887] [Adversarial_G_Loss: 2.585754, perc_recon: 0.130151] time: 0:58:48.317102
# [Epoch 5221/10000] [D loss: 0.322900] [Adversarial_G_Loss: 3.150610, perc_recon: 0.151923] time: 0:58:48.933684
# [Epoch 5222/10000] [D loss: 0.300068] [Adversarial_G_Loss: 2.940965, perc_recon: 0.142230] time: 0:58:49.547338
# [Epoch 5223/10000] [D loss: 0.290745] [Adversarial_G_Loss: 2.542470, perc_recon: 0.127720] time: 0:58:50.155527
# [Epoch 5224/10000] [D loss: 0.293643] [Adversarial_G_Loss: 2.424703, perc_recon: 0.129398] time: 0:58:50.769434
# [Epoch 5225/10000] [D loss: 0.302233] [Adversarial_G_Loss: 2.471930, perc_recon: 0.138914] time: 0:58:51.389872
# [Epoch 5226/10000] [D loss: 0.258725] [Adversarial_G_Loss: 2.563878, perc_recon: 0.118157] time: 0:58:52.006514
# [Epoch 5227/10000] [D loss: 0.257560] [Adversarial_G_Loss: 2.452018, perc_recon: 0.114863] time: 0:58:52.618742
# [Epoch 5228/10000] [D loss: 0.267142] [Adversarial_G_Loss: 2.163466, perc_recon: 0.111928] time: 0:58:53.232153
# [Epoch 5229/10000] [D loss: 0.328643] [Adversarial_G_Loss: 2.670241, perc_recon: 0.143604] time: 0:58:53.848272
# [Epoch 5230/10000] [D loss: 0.305897] [Adversarial_G_Loss: 2.422626, perc_recon: 0.134195] time: 0:58:54.468880
# [Epoch 5231/10000] [D loss: 0.284315] [Adversarial_G_Loss: 2.111561, perc_recon: 0.118884] time: 0:58:55.085212
# [Epoch 5232/10000] [D loss: 0.246717] [Adversarial_G_Loss: 1.922904, perc_recon: 0.121283] time: 0:58:55.698098
# [Epoch 5233/10000] [D loss: 0.249708] [Adversarial_G_Loss: 2.182211, perc_recon: 0.134573] time: 0:58:56.316272
# [Epoch 5234/10000] [D loss: 0.357622] [Adversarial_G_Loss: 2.499169, perc_recon: 0.140659] time: 0:58:56.930252
# [Epoch 5235/10000] [D loss: 0.318217] [Adversarial_G_Loss: 2.142036, perc_recon: 0.131991] time: 0:58:57.544469
# [Epoch 5236/10000] [D loss: 0.311007] [Adversarial_G_Loss: 2.006804, perc_recon: 0.114826] time: 0:58:58.155532
# [Epoch 5237/10000] [D loss: 0.292361] [Adversarial_G_Loss: 2.016906, perc_recon: 0.119195] time: 0:58:58.773194
# [Epoch 5238/10000] [D loss: 0.243978] [Adversarial_G_Loss: 2.096957, perc_recon: 0.135653] time: 0:58:59.383104
# [Epoch 5239/10000] [D loss: 0.287943] [Adversarial_G_Loss: 2.240301, perc_recon: 0.132136] time: 0:58:59.997489
# [Epoch 5240/10000] [D loss: 0.262013] [Adversarial_G_Loss: 1.911187, perc_recon: 0.119868] time: 0:59:00.609412
# [Epoch 5241/10000] [D loss: 0.316263] [Adversarial_G_Loss: 2.271755, perc_recon: 0.134760] time: 0:59:01.218843
# [Epoch 5242/10000] [D loss: 0.260979] [Adversarial_G_Loss: 2.698480, perc_recon: 0.148652] time: 0:59:01.828151
# [Epoch 5243/10000] [D loss: 0.338110] [Adversarial_G_Loss: 1.958596, perc_recon: 0.126108] time: 0:59:02.450932
# [Epoch 5244/10000] [D loss: 0.319771] [Adversarial_G_Loss: 2.178391, perc_recon: 0.136765] time: 0:59:03.065928
# [Epoch 5245/10000] [D loss: 0.322493] [Adversarial_G_Loss: 2.051113, perc_recon: 0.126905] time: 0:59:03.677122
# [Epoch 5246/10000] [D loss: 0.278565] [Adversarial_G_Loss: 2.843586, perc_recon: 0.156930] time: 0:59:04.286230
# [Epoch 5247/10000] [D loss: 0.303142] [Adversarial_G_Loss: 2.016805, perc_recon: 0.128879] time: 0:59:04.895078
# [Epoch 5248/10000] [D loss: 0.277731] [Adversarial_G_Loss: 2.466620, perc_recon: 0.136204] time: 0:59:05.513142
# [Epoch 5249/10000] [D loss: 0.339217] [Adversarial_G_Loss: 1.894759, perc_recon: 0.132713] time: 0:59:06.126471
# [Epoch 5250/10000] [D loss: 0.302707] [Adversarial_G_Loss: 2.257088, perc_recon: 0.132218] time: 0:59:06.738892
# [Epoch 5251/10000] [D loss: 0.325262] [Adversarial_G_Loss: 2.127263, perc_recon: 0.141270] time: 0:59:07.354123
# [Epoch 5252/10000] [D loss: 0.324492] [Adversarial_G_Loss: 2.492036, perc_recon: 0.146020] time: 0:59:07.966225
# [Epoch 5253/10000] [D loss: 0.315032] [Adversarial_G_Loss: 1.847937, perc_recon: 0.125988] time: 0:59:08.581112
# [Epoch 5254/10000] [D loss: 0.320230] [Adversarial_G_Loss: 2.246580, perc_recon: 0.131363] time: 0:59:09.194817
# [Epoch 5255/10000] [D loss: 0.319206] [Adversarial_G_Loss: 2.695778, perc_recon: 0.134860] time: 0:59:09.805273
# [Epoch 5256/10000] [D loss: 0.302967] [Adversarial_G_Loss: 2.314639, perc_recon: 0.118867] time: 0:59:10.418308
# [Epoch 5257/10000] [D loss: 0.304801] [Adversarial_G_Loss: 2.339897, perc_recon: 0.136932] time: 0:59:11.034091
# [Epoch 5258/10000] [D loss: 0.309733] [Adversarial_G_Loss: 2.161216, perc_recon: 0.129197] time: 0:59:11.648967
# [Epoch 5259/10000] [D loss: 0.234277] [Adversarial_G_Loss: 2.070664, perc_recon: 0.124188] time: 0:59:12.257550
# [Epoch 5260/10000] [D loss: 0.252755] [Adversarial_G_Loss: 2.094661, perc_recon: 0.139690] time: 0:59:12.871582
# [Epoch 5261/10000] [D loss: 0.282355] [Adversarial_G_Loss: 2.421953, perc_recon: 0.129519] time: 0:59:13.481893
# [Epoch 5262/10000] [D loss: 0.309793] [Adversarial_G_Loss: 2.761681, perc_recon: 0.157340] time: 0:59:14.091968
# [Epoch 5263/10000] [D loss: 0.279388] [Adversarial_G_Loss: 2.128513, perc_recon: 0.141549] time: 0:59:14.700908
# [Epoch 5264/10000] [D loss: 0.239647] [Adversarial_G_Loss: 2.158538, perc_recon: 0.120478] time: 0:59:15.316447
# [Epoch 5265/10000] [D loss: 0.330008] [Adversarial_G_Loss: 2.170681, perc_recon: 0.131060] time: 0:59:15.927256
# [Epoch 5266/10000] [D loss: 0.310347] [Adversarial_G_Loss: 2.295547, perc_recon: 0.134218] time: 0:59:16.537830
# [Epoch 5267/10000] [D loss: 0.315404] [Adversarial_G_Loss: 2.147255, perc_recon: 0.132299] time: 0:59:17.150978
# [Epoch 5268/10000] [D loss: 0.315036] [Adversarial_G_Loss: 2.390963, perc_recon: 0.132094] time: 0:59:17.762619
# [Epoch 5269/10000] [D loss: 0.309482] [Adversarial_G_Loss: 2.276746, perc_recon: 0.122737] time: 0:59:18.383845
# [Epoch 5270/10000] [D loss: 0.302458] [Adversarial_G_Loss: 2.525205, perc_recon: 0.128094] time: 0:59:19.004715
# [Epoch 5271/10000] [D loss: 0.307360] [Adversarial_G_Loss: 2.083742, perc_recon: 0.120254] time: 0:59:19.631605
# [Epoch 5272/10000] [D loss: 0.306734] [Adversarial_G_Loss: 2.724027, perc_recon: 0.143697] time: 0:59:20.245744
# [Epoch 5273/10000] [D loss: 0.279554] [Adversarial_G_Loss: 2.490552, perc_recon: 0.128061] time: 0:59:20.856220
# [Epoch 5274/10000] [D loss: 0.299112] [Adversarial_G_Loss: 2.133421, perc_recon: 0.117875] time: 0:59:21.467024
# [Epoch 5275/10000] [D loss: 0.273120] [Adversarial_G_Loss: 2.422932, perc_recon: 0.123482] time: 0:59:22.079937
# [Epoch 5276/10000] [D loss: 0.293711] [Adversarial_G_Loss: 2.411108, perc_recon: 0.116334] time: 0:59:22.697313
# [Epoch 5277/10000] [D loss: 0.286502] [Adversarial_G_Loss: 2.804365, perc_recon: 0.142965] time: 0:59:23.308677
# [Epoch 5278/10000] [D loss: 0.246900] [Adversarial_G_Loss: 2.785985, perc_recon: 0.128867] time: 0:59:23.920851
# [Epoch 5279/10000] [D loss: 0.295460] [Adversarial_G_Loss: 2.705536, perc_recon: 0.138187] time: 0:59:24.527574
# [Epoch 5280/10000] [D loss: 0.294325] [Adversarial_G_Loss: 3.222933, perc_recon: 0.156403] time: 0:59:25.136736
# [Epoch 5281/10000] [D loss: 0.308062] [Adversarial_G_Loss: 2.684626, perc_recon: 0.135121] time: 0:59:25.748456
# [Epoch 5282/10000] [D loss: 0.325219] [Adversarial_G_Loss: 2.896062, perc_recon: 0.141128] time: 0:59:26.358288
# [Epoch 5283/10000] [D loss: 0.296170] [Adversarial_G_Loss: 2.519795, perc_recon: 0.124205] time: 0:59:26.968019
# [Epoch 5284/10000] [D loss: 0.222995] [Adversarial_G_Loss: 2.360391, perc_recon: 0.116710] time: 0:59:27.582535
# [Epoch 5285/10000] [D loss: 0.314052] [Adversarial_G_Loss: 2.618797, perc_recon: 0.136475] time: 0:59:28.197370
# [Epoch 5286/10000] [D loss: 0.380184] [Adversarial_G_Loss: 2.458779, perc_recon: 0.129515] time: 0:59:28.809071
# [Epoch 5287/10000] [D loss: 0.295143] [Adversarial_G_Loss: 2.241707, perc_recon: 0.116782] time: 0:59:29.423342
# [Epoch 5288/10000] [D loss: 0.314074] [Adversarial_G_Loss: 1.941566, perc_recon: 0.112935] time: 0:59:30.038455
# [Epoch 5289/10000] [D loss: 0.221349] [Adversarial_G_Loss: 1.845430, perc_recon: 0.121782] time: 0:59:30.644417
# [Epoch 5290/10000] [D loss: 0.304993] [Adversarial_G_Loss: 2.203482, perc_recon: 0.133739] time: 0:59:31.261541
# [Epoch 5291/10000] [D loss: 0.320868] [Adversarial_G_Loss: 2.422632, perc_recon: 0.137903] time: 0:59:31.869973
# [Epoch 5292/10000] [D loss: 0.317334] [Adversarial_G_Loss: 2.224491, perc_recon: 0.121080] time: 0:59:32.479729
# [Epoch 5293/10000] [D loss: 0.306859] [Adversarial_G_Loss: 2.636620, perc_recon: 0.134504] time: 0:59:33.099143
# [Epoch 5294/10000] [D loss: 0.297021] [Adversarial_G_Loss: 2.460415, perc_recon: 0.126255] time: 0:59:33.714360
# [Epoch 5295/10000] [D loss: 0.268168] [Adversarial_G_Loss: 2.717893, perc_recon: 0.139112] time: 0:59:34.328349
# [Epoch 5296/10000] [D loss: 0.301757] [Adversarial_G_Loss: 2.566493, perc_recon: 0.122409] time: 0:59:34.935428
# [Epoch 5297/10000] [D loss: 0.302870] [Adversarial_G_Loss: 2.764821, perc_recon: 0.140563] time: 0:59:35.547325
# [Epoch 5298/10000] [D loss: 0.296532] [Adversarial_G_Loss: 2.287760, perc_recon: 0.122481] time: 0:59:36.161714
# [Epoch 5299/10000] [D loss: 0.308958] [Adversarial_G_Loss: 2.552065, perc_recon: 0.144231] time: 0:59:36.774372
# [Epoch 5300/10000] [D loss: 0.274433] [Adversarial_G_Loss: 1.850037, perc_recon: 0.119838] time: 0:59:37.384974
# [Epoch 5301/10000] [D loss: 0.307253] [Adversarial_G_Loss: 2.287765, perc_recon: 0.135125] time: 0:59:38.685776
# [Epoch 5302/10000] [D loss: 0.312400] [Adversarial_G_Loss: 2.693689, perc_recon: 0.142449] time: 0:59:39.296935
# [Epoch 5303/10000] [D loss: 0.313358] [Adversarial_G_Loss: 2.343978, perc_recon: 0.128420] time: 0:59:39.904043
# [Epoch 5304/10000] [D loss: 0.313024] [Adversarial_G_Loss: 2.932891, perc_recon: 0.140794] time: 0:59:40.515571
# [Epoch 5305/10000] [D loss: 0.307561] [Adversarial_G_Loss: 2.971944, perc_recon: 0.139815] time: 0:59:41.133927
# [Epoch 5306/10000] [D loss: 0.340495] [Adversarial_G_Loss: 3.194456, perc_recon: 0.149690] time: 0:59:41.751141
# [Epoch 5307/10000] [D loss: 0.282985] [Adversarial_G_Loss: 2.871022, perc_recon: 0.142253] time: 0:59:42.364659
# [Epoch 5308/10000] [D loss: 0.261005] [Adversarial_G_Loss: 3.214178, perc_recon: 0.140124] time: 0:59:42.983677
# [Epoch 5309/10000] [D loss: 0.304518] [Adversarial_G_Loss: 2.661294, perc_recon: 0.132300] time: 0:59:43.602442
# [Epoch 5310/10000] [D loss: 0.292581] [Adversarial_G_Loss: 2.567235, perc_recon: 0.128594] time: 0:59:44.210159
# [Epoch 5311/10000] [D loss: 0.221215] [Adversarial_G_Loss: 1.917572, perc_recon: 0.124359] time: 0:59:44.821221
# [Epoch 5312/10000] [D loss: 0.300613] [Adversarial_G_Loss: 2.724222, perc_recon: 0.134547] time: 0:59:45.432541
# [Epoch 5313/10000] [D loss: 0.243932] [Adversarial_G_Loss: 2.634428, perc_recon: 0.119698] time: 0:59:46.045804
# [Epoch 5314/10000] [D loss: 0.251858] [Adversarial_G_Loss: 2.896920, perc_recon: 0.132530] time: 0:59:46.658491
# [Epoch 5315/10000] [D loss: 0.287951] [Adversarial_G_Loss: 2.698168, perc_recon: 0.130815] time: 0:59:47.271853
# [Epoch 5316/10000] [D loss: 0.294114] [Adversarial_G_Loss: 2.854323, perc_recon: 0.139848] time: 0:59:47.893866
# [Epoch 5317/10000] [D loss: 0.253115] [Adversarial_G_Loss: 2.920182, perc_recon: 0.133201] time: 0:59:48.518268
# [Epoch 5318/10000] [D loss: 0.291597] [Adversarial_G_Loss: 2.545721, perc_recon: 0.124927] time: 0:59:49.153067
# [Epoch 5319/10000] [D loss: 0.282199] [Adversarial_G_Loss: 2.726000, perc_recon: 0.132123] time: 0:59:49.766932
# [Epoch 5320/10000] [D loss: 0.299893] [Adversarial_G_Loss: 2.371829, perc_recon: 0.124266] time: 0:59:50.385066
# [Epoch 5321/10000] [D loss: 0.300613] [Adversarial_G_Loss: 2.509380, perc_recon: 0.127356] time: 0:59:51.002587
# [Epoch 5322/10000] [D loss: 0.297708] [Adversarial_G_Loss: 2.383715, perc_recon: 0.124399] time: 0:59:51.612768
# [Epoch 5323/10000] [D loss: 0.286378] [Adversarial_G_Loss: 2.272597, perc_recon: 0.115704] time: 0:59:52.234040
# [Epoch 5324/10000] [D loss: 0.260106] [Adversarial_G_Loss: 2.553402, perc_recon: 0.151188] time: 0:59:52.852673
# [Epoch 5325/10000] [D loss: 0.257569] [Adversarial_G_Loss: 2.861075, perc_recon: 0.150226] time: 0:59:53.469010
# [Epoch 5326/10000] [D loss: 0.258956] [Adversarial_G_Loss: 2.700963, perc_recon: 0.152811] time: 0:59:54.085781
# [Epoch 5327/10000] [D loss: 0.216339] [Adversarial_G_Loss: 2.156596, perc_recon: 0.126952] time: 0:59:54.700106
# [Epoch 5328/10000] [D loss: 0.395770] [Adversarial_G_Loss: 2.848085, perc_recon: 0.156011] time: 0:59:55.310257
# [Epoch 5329/10000] [D loss: 0.314402] [Adversarial_G_Loss: 2.475608, perc_recon: 0.137565] time: 0:59:55.922595
# [Epoch 5330/10000] [D loss: 0.309964] [Adversarial_G_Loss: 2.253991, perc_recon: 0.127771] time: 0:59:56.534779
# [Epoch 5331/10000] [D loss: 0.263504] [Adversarial_G_Loss: 2.663811, perc_recon: 0.150342] time: 0:59:57.145557
# [Epoch 5332/10000] [D loss: 0.142722] [Adversarial_G_Loss: 2.902102, perc_recon: 0.141547] time: 0:59:57.763298
# [Epoch 5333/10000] [D loss: 0.239172] [Adversarial_G_Loss: 2.239473, perc_recon: 0.161171] time: 0:59:58.377030
# [Epoch 5334/10000] [D loss: 0.263142] [Adversarial_G_Loss: 1.723132, perc_recon: 0.137518] time: 0:59:59.003450
# [Epoch 5335/10000] [D loss: 0.316447] [Adversarial_G_Loss: 2.599802, perc_recon: 0.156263] time: 0:59:59.618090
# [Epoch 5336/10000] [D loss: 0.325955] [Adversarial_G_Loss: 1.771079, perc_recon: 0.129510] time: 1:00:00.239169
# [Epoch 5337/10000] [D loss: 0.383199] [Adversarial_G_Loss: 3.278169, perc_recon: 0.176847] time: 1:00:00.856807
# [Epoch 5338/10000] [D loss: 0.241218] [Adversarial_G_Loss: 1.890288, perc_recon: 0.126408] time: 1:00:01.475059
# [Epoch 5339/10000] [D loss: 0.323428] [Adversarial_G_Loss: 2.216965, perc_recon: 0.135072] time: 1:00:02.099988
# ...
# [Epoch 9859/10000] [D loss: 0.278453] [Adversarial_G_Loss: 1.360115, perc_recon: 0.112011] time: 1:47:01.172573
# [Epoch 9860/10000] [D loss: 0.316525] [Adversarial_G_Loss: 1.731863, perc_recon: 0.111192] time: 1:47:01.793652
# [Epoch 9861/10000] [D loss: 0.336245] [Adversarial_G_Loss: 1.653876, perc_recon: 0.115484] time: 1:47:02.417706
# [Epoch 9862/10000] [D loss: 0.312643] [Adversarial_G_Loss: 1.301741, perc_recon: 0.110172] time: 1:47:03.033194
# [Epoch 9863/10000] [D loss: 0.251193] [Adversarial_G_Loss: 1.415713, perc_recon: 0.085140] time: 1:47:03.652721
# [Epoch 9864/10000] [D loss: 0.316374] [Adversarial_G_Loss: 1.338106, perc_recon: 0.106846] time: 1:47:04.274138
# [Epoch 9865/10000] [D loss: 0.327838] [Adversarial_G_Loss: 1.582465, perc_recon: 0.116315] time: 1:47:04.896822
# [Epoch 9866/10000] [D loss: 0.327543] [Adversarial_G_Loss: 1.493263, perc_recon: 0.116522] time: 1:47:05.521021
# [Epoch 9867/10000] [D loss: 0.274463] [Adversarial_G_Loss: 1.880826, perc_recon: 0.110447] time: 1:47:06.139868
# [Epoch 9868/10000] [D loss: 0.250296] [Adversarial_G_Loss: 1.330845, perc_recon: 0.139369] time: 1:47:06.752309
# [Epoch 9869/10000] [D loss: 0.332502] [Adversarial_G_Loss: 1.214787, perc_recon: 0.096865] time: 1:47:07.381974
# [Epoch 9870/10000] [D loss: 0.333817] [Adversarial_G_Loss: 1.253812, perc_recon: 0.100629] time: 1:47:08.000610
# [Epoch 9871/10000] [D loss: 0.315594] [Adversarial_G_Loss: 1.596249, perc_recon: 0.124815] time: 1:47:08.621250
# [Epoch 9872/10000] [D loss: 0.317944] [Adversarial_G_Loss: 1.312531, perc_recon: 0.108931] time: 1:47:09.242995
# [Epoch 9873/10000] [D loss: 0.189189] [Adversarial_G_Loss: 2.319678, perc_recon: 0.112938] time: 1:47:09.868174
# [Epoch 9874/10000] [D loss: 0.305865] [Adversarial_G_Loss: 1.616807, perc_recon: 0.114549] time: 1:47:10.486168
# [Epoch 9875/10000] [D loss: 0.310792] [Adversarial_G_Loss: 1.544619, perc_recon: 0.109833] time: 1:47:11.106298
# [Epoch 9876/10000] [D loss: 0.321362] [Adversarial_G_Loss: 1.378120, perc_recon: 0.160921] time: 1:47:11.733573
# [Epoch 9877/10000] [D loss: 0.261445] [Adversarial_G_Loss: 2.043522, perc_recon: 0.114923] time: 1:47:12.368894
# [Epoch 9878/10000] [D loss: 0.297967] [Adversarial_G_Loss: 1.417057, perc_recon: 0.108448] time: 1:47:12.997799
# [Epoch 9879/10000] [D loss: 0.322477] [Adversarial_G_Loss: 1.894222, perc_recon: 0.127200] time: 1:47:13.625331
# [Epoch 9880/10000] [D loss: 0.304622] [Adversarial_G_Loss: 1.479041, perc_recon: 0.112882] time: 1:47:14.256670
# [Epoch 9881/10000] [D loss: 0.301331] [Adversarial_G_Loss: 1.487809, perc_recon: 0.099491] time: 1:47:14.878301
# [Epoch 9882/10000] [D loss: 0.344976] [Adversarial_G_Loss: 1.666300, perc_recon: 0.118864] time: 1:47:15.503662
# [Epoch 9883/10000] [D loss: 0.241828] [Adversarial_G_Loss: 1.836705, perc_recon: 0.116017] time: 1:47:16.123224
# [Epoch 9884/10000] [D loss: 0.297765] [Adversarial_G_Loss: 1.419203, perc_recon: 0.101433] time: 1:47:16.745461
# [Epoch 9885/10000] [D loss: 0.308805] [Adversarial_G_Loss: 1.473294, perc_recon: 0.106541] time: 1:47:17.358276
# [Epoch 9886/10000] [D loss: 0.323538] [Adversarial_G_Loss: 1.315917, perc_recon: 0.099579] time: 1:47:17.982162
# [Epoch 9887/10000] [D loss: 0.300086] [Adversarial_G_Loss: 1.332565, perc_recon: 0.100151] time: 1:47:18.615003
# [Epoch 9888/10000] [D loss: 0.300781] [Adversarial_G_Loss: 1.541163, perc_recon: 0.109204] time: 1:47:19.234090
# [Epoch 9889/10000] [D loss: 0.364781] [Adversarial_G_Loss: 1.677265, perc_recon: 0.116552] time: 1:47:19.847195
# [Epoch 9890/10000] [D loss: 0.350873] [Adversarial_G_Loss: 1.510814, perc_recon: 0.103024] time: 1:47:20.472161
# [Epoch 9891/10000] [D loss: 0.322858] [Adversarial_G_Loss: 1.651148, perc_recon: 0.110516] time: 1:47:21.099556
# [Epoch 9892/10000] [D loss: 0.314003] [Adversarial_G_Loss: 1.458616, perc_recon: 0.104071] time: 1:47:21.724939
# [Epoch 9893/10000] [D loss: 0.302202] [Adversarial_G_Loss: 1.179621, perc_recon: 0.100113] time: 1:47:22.352608
# [Epoch 9894/10000] [D loss: 0.264715] [Adversarial_G_Loss: 1.263130, perc_recon: 0.100205] time: 1:47:22.980869
# [Epoch 9895/10000] [D loss: 0.328561] [Adversarial_G_Loss: 1.551862, perc_recon: 0.121022] time: 1:47:23.607306
# [Epoch 9896/10000] [D loss: 0.318840] [Adversarial_G_Loss: 1.693963, perc_recon: 0.113659] time: 1:47:24.231171
# [Epoch 9897/10000] [D loss: 0.295356] [Adversarial_G_Loss: 1.823189, perc_recon: 0.123650] time: 1:47:24.850371
# [Epoch 9898/10000] [D loss: 0.319007] [Adversarial_G_Loss: 1.562045, perc_recon: 0.127507] time: 1:47:25.471491
# [Epoch 9899/10000] [D loss: 0.323646] [Adversarial_G_Loss: 1.433965, perc_recon: 0.114680] time: 1:47:26.086565
# [Epoch 9900/10000] [D loss: 0.182048] [Adversarial_G_Loss: 1.320032, perc_recon: 0.095261] time: 1:47:26.706346
# [Epoch 9901/10000] [D loss: 0.343909] [Adversarial_G_Loss: 1.560415, perc_recon: 0.114478] time: 1:47:28.033017
# [Epoch 9902/10000] [D loss: 0.350507] [Adversarial_G_Loss: 1.600775, perc_recon: 0.128231] time: 1:47:28.652526
# [Epoch 9903/10000] [D loss: 0.307451] [Adversarial_G_Loss: 1.441506, perc_recon: 0.119827] time: 1:47:29.275851
# [Epoch 9904/10000] [D loss: 0.311830] [Adversarial_G_Loss: 1.217062, perc_recon: 0.141251] time: 1:47:29.904921
# [Epoch 9905/10000] [D loss: 0.339073] [Adversarial_G_Loss: 1.103882, perc_recon: 0.100439] time: 1:47:30.523180
# [Epoch 9906/10000] [D loss: 0.311340] [Adversarial_G_Loss: 1.128645, perc_recon: 0.100996] time: 1:47:31.144133
# [Epoch 9907/10000] [D loss: 0.312116] [Adversarial_G_Loss: 1.083338, perc_recon: 0.094974] time: 1:47:31.770409
# [Epoch 9908/10000] [D loss: 0.355728] [Adversarial_G_Loss: 1.621067, perc_recon: 0.112005] time: 1:47:32.387007
# [Epoch 9909/10000] [D loss: 0.336559] [Adversarial_G_Loss: 1.654529, perc_recon: 0.120065] time: 1:47:33.000298
# [Epoch 9910/10000] [D loss: 0.318407] [Adversarial_G_Loss: 1.112585, perc_recon: 0.098315] time: 1:47:33.617697
# [Epoch 9911/10000] [D loss: 0.293649] [Adversarial_G_Loss: 1.475955, perc_recon: 0.114168] time: 1:47:34.234753
# [Epoch 9912/10000] [D loss: 0.328577] [Adversarial_G_Loss: 1.712667, perc_recon: 0.123376] time: 1:47:34.852291
# [Epoch 9913/10000] [D loss: 0.316041] [Adversarial_G_Loss: 1.345884, perc_recon: 0.108865] time: 1:47:35.469919
# [Epoch 9914/10000] [D loss: 0.318499] [Adversarial_G_Loss: 1.660022, perc_recon: 0.124134] time: 1:47:36.086939
# [Epoch 9915/10000] [D loss: 0.238344] [Adversarial_G_Loss: 1.336969, perc_recon: 0.106291] time: 1:47:36.708870
# [Epoch 9916/10000] [D loss: 0.161772] [Adversarial_G_Loss: 0.976557, perc_recon: 0.093132] time: 1:47:37.351915
# [Epoch 9917/10000] [D loss: 0.346301] [Adversarial_G_Loss: 1.721230, perc_recon: 0.129281] time: 1:47:37.980908
# [Epoch 9918/10000] [D loss: 0.303905] [Adversarial_G_Loss: 1.391539, perc_recon: 0.101086] time: 1:47:38.603718
# [Epoch 9919/10000] [D loss: 0.259667] [Adversarial_G_Loss: 1.145249, perc_recon: 0.118838] time: 1:47:39.220564
# [Epoch 9920/10000] [D loss: 0.350614] [Adversarial_G_Loss: 1.654848, perc_recon: 0.129628] time: 1:47:39.837536
# [Epoch 9921/10000] [D loss: 0.317010] [Adversarial_G_Loss: 1.129448, perc_recon: 0.095107] time: 1:47:40.453876
# [Epoch 9922/10000] [D loss: 0.326571] [Adversarial_G_Loss: 1.482050, perc_recon: 0.120982] time: 1:47:41.069540
# [Epoch 9923/10000] [D loss: 0.291965] [Adversarial_G_Loss: 1.304424, perc_recon: 0.103292] time: 1:47:41.685516
# [Epoch 9924/10000] [D loss: 0.281752] [Adversarial_G_Loss: 1.191183, perc_recon: 0.089671] time: 1:47:42.304201
# [Epoch 9925/10000] [D loss: 0.232374] [Adversarial_G_Loss: 1.384616, perc_recon: 0.107978] time: 1:47:42.926091
# [Epoch 9926/10000] [D loss: 0.311881] [Adversarial_G_Loss: 1.657521, perc_recon: 0.114889] time: 1:47:43.545294
# [Epoch 9927/10000] [D loss: 0.247339] [Adversarial_G_Loss: 2.072962, perc_recon: 0.140619] time: 1:47:44.163530
# [Epoch 9928/10000] [D loss: 0.339528] [Adversarial_G_Loss: 1.462824, perc_recon: 0.122044] time: 1:47:44.775693
# [Epoch 9929/10000] [D loss: 0.327277] [Adversarial_G_Loss: 1.333853, perc_recon: 0.106957] time: 1:47:45.396119
# [Epoch 9930/10000] [D loss: 0.325685] [Adversarial_G_Loss: 1.689853, perc_recon: 0.120209] time: 1:47:46.012585
# [Epoch 9931/10000] [D loss: 0.307760] [Adversarial_G_Loss: 1.672765, perc_recon: 0.119919] time: 1:47:46.627439
# [Epoch 9932/10000] [D loss: 0.271061] [Adversarial_G_Loss: 1.294145, perc_recon: 0.091293] time: 1:47:47.246180
# [Epoch 9933/10000] [D loss: 0.238097] [Adversarial_G_Loss: 1.673493, perc_recon: 0.130513] time: 1:47:47.867527
# [Epoch 9934/10000] [D loss: 0.300741] [Adversarial_G_Loss: 1.355865, perc_recon: 0.101524] time: 1:47:48.487996
# [Epoch 9935/10000] [D loss: 0.250238] [Adversarial_G_Loss: 1.324221, perc_recon: 0.102013] time: 1:47:49.108409
# [Epoch 9936/10000] [D loss: 0.330549] [Adversarial_G_Loss: 1.894752, perc_recon: 0.131808] time: 1:47:49.725556
# [Epoch 9937/10000] [D loss: 0.332360] [Adversarial_G_Loss: 1.871375, perc_recon: 0.134002] time: 1:47:50.336833
# [Epoch 9938/10000] [D loss: 0.313237] [Adversarial_G_Loss: 2.311930, perc_recon: 0.146880] time: 1:47:50.953142
# [Epoch 9939/10000] [D loss: 0.298914] [Adversarial_G_Loss: 1.923775, perc_recon: 0.122078] time: 1:47:51.567637
# [Epoch 9940/10000] [D loss: 0.320355] [Adversarial_G_Loss: 1.669323, perc_recon: 0.114528] time: 1:47:52.180161
# [Epoch 9941/10000] [D loss: 0.227681] [Adversarial_G_Loss: 1.401781, perc_recon: 0.103870] time: 1:47:52.792975
# [Epoch 9942/10000] [D loss: 0.294974] [Adversarial_G_Loss: 1.583775, perc_recon: 0.113650] time: 1:47:53.414530
# [Epoch 9943/10000] [D loss: 0.214519] [Adversarial_G_Loss: 1.430354, perc_recon: 0.102365] time: 1:47:54.022372
# [Epoch 9944/10000] [D loss: 0.332595] [Adversarial_G_Loss: 1.778833, perc_recon: 0.121846] time: 1:47:54.634668
# [Epoch 9945/10000] [D loss: 0.292936] [Adversarial_G_Loss: 1.302755, perc_recon: 0.091404] time: 1:47:55.245580
# [Epoch 9946/10000] [D loss: 0.325186] [Adversarial_G_Loss: 1.596680, perc_recon: 0.127188] time: 1:47:55.861399
# [Epoch 9947/10000] [D loss: 0.273050] [Adversarial_G_Loss: 1.145299, perc_recon: 0.085310] time: 1:47:56.477982
# [Epoch 9948/10000] [D loss: 0.323158] [Adversarial_G_Loss: 1.499160, perc_recon: 0.107213] time: 1:47:57.092252
# [Epoch 9949/10000] [D loss: 0.254694] [Adversarial_G_Loss: 1.471313, perc_recon: 0.116242] time: 1:47:57.707148
# [Epoch 9950/10000] [D loss: 0.323557] [Adversarial_G_Loss: 1.481225, perc_recon: 0.106461] time: 1:47:58.322738
# [Epoch 9951/10000] [D loss: 0.320617] [Adversarial_G_Loss: 1.975437, perc_recon: 0.136436] time: 1:47:58.935411
# [Epoch 9952/10000] [D loss: 0.296621] [Adversarial_G_Loss: 1.892006, perc_recon: 0.123157] time: 1:47:59.559559
# [Epoch 9953/10000] [D loss: 0.264750] [Adversarial_G_Loss: 1.673358, perc_recon: 0.110283] time: 1:48:00.181701
# [Epoch 9954/10000] [D loss: 0.282668] [Adversarial_G_Loss: 1.868077, perc_recon: 0.156135] time: 1:48:00.804003
# [Epoch 9955/10000] [D loss: 0.297336] [Adversarial_G_Loss: 1.927879, perc_recon: 0.124035] time: 1:48:01.436935
# [Epoch 9956/10000] [D loss: 0.275164] [Adversarial_G_Loss: 2.152743, perc_recon: 0.143612] time: 1:48:02.061988
# [Epoch 9957/10000] [D loss: 0.275761] [Adversarial_G_Loss: 2.139749, perc_recon: 0.117945] time: 1:48:02.685291
# [Epoch 9958/10000] [D loss: 0.303231] [Adversarial_G_Loss: 2.435299, perc_recon: 0.134809] time: 1:48:03.311736
# [Epoch 9959/10000] [D loss: 0.293046] [Adversarial_G_Loss: 2.196203, perc_recon: 0.141857] time: 1:48:03.932939
# [Epoch 9960/10000] [D loss: 0.234747] [Adversarial_G_Loss: 1.864672, perc_recon: 0.110799] time: 1:48:04.557077
# [Epoch 9961/10000] [D loss: 0.293034] [Adversarial_G_Loss: 1.695571, perc_recon: 0.109384] time: 1:48:05.182103
# [Epoch 9962/10000] [D loss: 0.317541] [Adversarial_G_Loss: 2.251912, perc_recon: 0.143018] time: 1:48:05.807160
# [Epoch 9963/10000] [D loss: 0.243519] [Adversarial_G_Loss: 1.754086, perc_recon: 0.101814] time: 1:48:06.432595
# [Epoch 9964/10000] [D loss: 0.299792] [Adversarial_G_Loss: 2.166553, perc_recon: 0.131583] time: 1:48:07.058777
# [Epoch 9965/10000] [D loss: 0.303786] [Adversarial_G_Loss: 1.916604, perc_recon: 0.118354] time: 1:48:07.684246
# [Epoch 9966/10000] [D loss: 0.320601] [Adversarial_G_Loss: 2.623867, perc_recon: 0.136566] time: 1:48:08.306654
# [Epoch 9967/10000] [D loss: 0.238366] [Adversarial_G_Loss: 1.701607, perc_recon: 0.116067] time: 1:48:08.929467
# [Epoch 9968/10000] [D loss: 0.283039] [Adversarial_G_Loss: 1.963412, perc_recon: 0.138453] time: 1:48:09.550997
# [Epoch 9969/10000] [D loss: 0.263969] [Adversarial_G_Loss: 1.865808, perc_recon: 0.125141] time: 1:48:10.169008
# [Epoch 9970/10000] [D loss: 0.317279] [Adversarial_G_Loss: 2.232986, perc_recon: 0.123393] time: 1:48:10.778248
# [Epoch 9971/10000] [D loss: 0.316298] [Adversarial_G_Loss: 2.573786, perc_recon: 0.144396] time: 1:48:11.399062
# [Epoch 9972/10000] [D loss: 0.258477] [Adversarial_G_Loss: 1.564437, perc_recon: 0.118020] time: 1:48:12.016088
# [Epoch 9973/10000] [D loss: 0.279147] [Adversarial_G_Loss: 1.633066, perc_recon: 0.113983] time: 1:48:12.630351
# [Epoch 9974/10000] [D loss: 0.342877] [Adversarial_G_Loss: 1.722820, perc_recon: 0.120704] time: 1:48:13.250350
# [Epoch 9975/10000] [D loss: 0.281415] [Adversarial_G_Loss: 1.641452, perc_recon: 0.117310] time: 1:48:13.863106
# [Epoch 9976/10000] [D loss: 0.249863] [Adversarial_G_Loss: 1.734200, perc_recon: 0.126408] time: 1:48:14.480089
# [Epoch 9977/10000] [D loss: 0.344426] [Adversarial_G_Loss: 1.636518, perc_recon: 0.111934] time: 1:48:15.096238
# [Epoch 9978/10000] [D loss: 0.243710] [Adversarial_G_Loss: 1.113169, perc_recon: 0.100088] time: 1:48:15.709041
# [Epoch 9979/10000] [D loss: 0.323570] [Adversarial_G_Loss: 1.457704, perc_recon: 0.097876] time: 1:48:16.320010
# [Epoch 9980/10000] [D loss: 0.326689] [Adversarial_G_Loss: 1.945054, perc_recon: 0.118115] time: 1:48:16.937206
# [Epoch 9981/10000] [D loss: 0.312530] [Adversarial_G_Loss: 1.721806, perc_recon: 0.106231] time: 1:48:17.554622
# [Epoch 9982/10000] [D loss: 0.299796] [Adversarial_G_Loss: 1.741317, perc_recon: 0.110172] time: 1:48:18.164506
# [Epoch 9983/10000] [D loss: 0.317112] [Adversarial_G_Loss: 1.594697, perc_recon: 0.108129] time: 1:48:18.779816
# [Epoch 9984/10000] [D loss: 0.285714] [Adversarial_G_Loss: 1.889947, perc_recon: 0.112103] time: 1:48:19.394949
# [Epoch 9985/10000] [D loss: 0.302170] [Adversarial_G_Loss: 2.058824, perc_recon: 0.123979] time: 1:48:20.016423
# [Epoch 9986/10000] [D loss: 0.294394] [Adversarial_G_Loss: 1.851290, perc_recon: 0.104348] time: 1:48:20.631721
# [Epoch 9987/10000] [D loss: 0.265475] [Adversarial_G_Loss: 1.398616, perc_recon: 0.100278] time: 1:48:21.240654
# [Epoch 9988/10000] [D loss: 0.301776] [Adversarial_G_Loss: 2.220409, perc_recon: 0.125415] time: 1:48:21.857167
# [Epoch 9989/10000] [D loss: 0.265016] [Adversarial_G_Loss: 1.863478, perc_recon: 0.124668] time: 1:48:22.478150
# [Epoch 9990/10000] [D loss: 0.307667] [Adversarial_G_Loss: 1.806712, perc_recon: 0.110643] time: 1:48:23.095910
# [Epoch 9991/10000] [D loss: 0.330372] [Adversarial_G_Loss: 2.487530, perc_recon: 0.132877] time: 1:48:23.708712
# [Epoch 9992/10000] [D loss: 0.314582] [Adversarial_G_Loss: 2.195611, perc_recon: 0.132105] time: 1:48:24.320715
# [Epoch 9993/10000] [D loss: 0.293655] [Adversarial_G_Loss: 2.333704, perc_recon: 0.133928] time: 1:48:24.936445
# [Epoch 9994/10000] [D loss: 0.323367] [Adversarial_G_Loss: 1.415638, perc_recon: 0.108095] time: 1:48:25.553628
# [Epoch 9995/10000] [D loss: 0.223140] [Adversarial_G_Loss: 1.275311, perc_recon: 0.106670] time: 1:48:26.170097
# [Epoch 9996/10000] [D loss: 0.297527] [Adversarial_G_Loss: 1.583660, perc_recon: 0.113823] time: 1:48:26.782259
# [Epoch 9997/10000] [D loss: 0.280131] [Adversarial_G_Loss: 1.640316, perc_recon: 0.121664] time: 1:48:27.393988
# [Epoch 9998/10000] [D loss: 0.259395] [Adversarial_G_Loss: 1.425907, perc_recon: 0.108317] time: 1:48:28.007143
# [Epoch 9999/10000] [D loss: 0.288506] [Adversarial_G_Loss: 1.175792, perc_recon: 0.108778] time: 1:48:28.622132
# [Epoch 10000/10000] [D loss: 0.298937] [Adversarial_G_Loss: 1.469332, perc_recon: 0.133062] time: 1:48:29.232387
