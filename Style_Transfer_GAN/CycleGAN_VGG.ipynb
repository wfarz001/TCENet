# %%
# !pip uninstall tensorflow 
# !pip install tensorflow-gpu==1.14

# %%
# !pip uninstall keras 
# !pip install keras==2.2.4

# %%
pip install h5py==2.10.0 --force-reinstall #need to install h5 ,otherwise it won't load the model properly

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# !cp /content/gdrive/MyDrive/Flood_Project/Image_Stylization/instancenormalization.py /content

# %%
from instancenormalization import InstanceNormalization
# Out:
# Using TensorFlow backend.

# %%
import os
import datetime
import keras
from keras.preprocessing.image import *
from keras.models import *
from keras.optimizers import *
from keras.layers import *
from keras_preprocessing.image import *
from keras import backend as K
from keras.callbacks import TensorBoard
from keras import losses
import random
import h5py

# %%
class CycleGAN():

    def __init__(self):

        self.sess = K.get_session()
        self.log_path = '/content/gdrive/MyDrive/Flood_Project/Image_Stylization/logs_2'
        self.domain_A_data_dir = '/content/gdrive/MyDrive/Flood_Project/Image_Stylization/Synthetic_to_Real/data/'
        self.domain_B_data_dir = '/content/gdrive/MyDrive/Flood_Project/Image_Stylization/Synthetic_to_Real/data/'
        self.f_size = 3
        self.first_f_size = 7
        self.d_f_size = 3
        self.leakyrel_alpha = 0.2
        self.img_height = 256
        self.img_width = 256
        self.img_channels = 3
        self.discr_dropout_rate = 0.0
        self.resblock_dropout = 0.5
        self.img_shape = (self.img_height, self.img_width, self.img_channels)
        self.image_data_generator = ImageDataGenerator(horizontal_flip=True)
        self.save_gens = 100
        self.batch_size = 1

        self.domain_A_datagen = self.image_data_generator.flow_from_directory(directory=self.domain_A_data_dir,
                                                                              target_size=(
                                                                              self.img_height, self.img_width),
                                                                              color_mode='rgb', classes=None,
                                                                              class_mode=None,
                                                                              batch_size=self.batch_size)
        self.domain_B_datagen = self.image_data_generator.flow_from_directory(directory=self.domain_B_data_dir,
                                                                              target_size=(
                                                                              self.img_height, self.img_width),
                                                                              color_mode='rgb', classes=None,
                                                                              class_mode=None,
                                                                              batch_size=self.batch_size)

        patch = int(self.img_height/2**4)
        self.disc_patch = (patch, patch, 1)

        self.g_f_ch = 32
        self.d_f_ch = 64

        self.lambda_perceptual_cycle_loss_wt = 10.0
        self.lambda_id_wt = 0.1 * self.lambda_perceptual_cycle_loss_wt
        self.mse_loss_wt = 1.0

        self.sample_modulus = 100
        self.id_modulus = 10
        self.stop_id = 100
        self.flip_labels_modulus = 0

        d_optimizer = Adam(lr=0.0002, beta_1=0.5)
        optimizer = Adam(lr=0.0002, beta_1=0.5)

        self.perceptual_model = self.build_perceptual_model()

        self.Disc_A = self.build_discriminator()
        self.Disc_B = self.build_discriminator()

        self.Disc_A.compile(loss=['mse'],
                            optimizer=d_optimizer, metrics=['accuracy'])
        self.Disc_B.compile(loss=['mse'],
                            optimizer=d_optimizer, metrics=['accuracy'])

        self.Gen_AB = self.build_generator()
        self.Gen_BA = self.build_generator()

        img_A = Input(shape=self.img_shape, name='image_A')
        img_B = Input(shape=self.img_shape, name='image_B')


        fake_B = self.Gen_AB([img_A])
        fake_A = self.Gen_BA([img_B])

        reconstruct_A = self.Gen_BA([fake_B])
        reconstruct_B = self.Gen_AB([fake_A])

        rec_content_A = self.perceptual_model(reconstruct_A)
        rec_content_B = self.perceptual_model(reconstruct_B)

        # Identity mapping of img

        img_A_id = self.Gen_BA([img_A])
        img_B_id = self.Gen_AB([img_B])

        self.Disc_A.trainable = False
        self.Disc_B.trainable = False

        valid_A = self.Disc_A(fake_A)
        valid_B = self.Disc_B(fake_B)

        comb_outputs = [valid_A, valid_B,
                    rec_content_A, rec_content_B
                    ]

        self.combined = Model(inputs=[img_A, img_B],
                        outputs=comb_outputs)

        self.combined.compile(
            loss=['mse', 'mse',
                  'mae', 'mae'
                  ],
            optimizer=optimizer,
            loss_weights = [self.mse_loss_wt, self.mse_loss_wt,
                            self.lambda_perceptual_cycle_loss_wt,
                            self.lambda_perceptual_cycle_loss_wt,
                            ])

        self.id_trainer = Model(inputs=[img_A, img_B],
                                outputs=[img_A_id, img_B_id])

        self.id_trainer.compile(loss=['mae', 'mae'],
                                optimizer=optimizer, loss_weights=[self.lambda_id_wt, self.lambda_id_wt])

    def build_perceptual_model(self):
        vgg = keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=(self.img_shape))
        content_layer = ['block5_conv3']
        #style_layers = ["block1_conv2", "block2_conv2", "block3_conv3", "block4_conv3", "block5_conv3"]
        # Get output layers corresponding to style and content layers
        content_outputs = [vgg.get_layer(name).output for name in content_layer ]
        model = Model(vgg.input, content_outputs)
        model.trainable = False
        model.summary()
        return model

    def build_generator(self):
        """U-Net/ Resblock Generator"""

        def conv2d(layer_input, filters, f_size=self.f_size, s=2):
            """Layers used during downsampling"""
            d_1 = Conv2D(filters, kernel_size=f_size, strides=s, padding='same')(layer_input)
            d_1 = LeakyReLU(self.leakyrel_alpha)(d_1)
            d = InstanceNormalization()(d_1)
            return d

        def deconv2d(layer_input, skip_input, filters, f_size=self.f_size, dropout_rate=0.0):
            """Layers used during upsampling"""
            u = UpSampling2D()(layer_input)
            u = Conv2D(filters=filters, kernel_size=f_size, strides=1, activation='relu', padding='same')(u)
            u = InstanceNormalization()(u)
            if skip_input is not None:
                u = Concatenate()([u, skip_input])
            if dropout_rate:
                u = Dropout(dropout_rate)(u)
            return u

        def residual_block(x, filters, f_size, dropout=self.resblock_dropout):
            if K.shape(x)[2] == filters:
                x = x
            else:
                x = Conv2D(filters=filters, kernel_size=f_size, strides=(1, 1), padding='same', activation='relu')(x)
                x = InstanceNormalization()(x)
            conv1 = Conv2D(filters=filters, kernel_size=f_size, strides=(1, 1), padding='same', activation='relu')(x)
            inst_norm = InstanceNormalization()(conv1)
            if dropout:
                inst_norm = GaussianDropout(dropout)(inst_norm)
            conv2 = Conv2D(filters=filters, kernel_size=f_size, strides=(1, 1), padding='same')(inst_norm)
            x = Add()([x, conv2])
            x = Activation('relu')(x)
            x = InstanceNormalization()(x)
            return x

        # Image input
        d0 = Input(shape=self.img_shape)

        # Downsampling
        d1 = conv2d(d0, self.g_f_ch, f_size=self.first_f_size, s=1)
        d1 = GaussianNoise(0.01)(d1)

        d2 = conv2d(d1, self.g_f_ch * 2)
        d3 = conv2d(d2, self.g_f_ch * 4)
        d4 = conv2d(d3, self.g_f_ch * 8)


        t1 = residual_block(d4, filters=self.g_f_ch * 8, f_size=self.f_size)
        t2 = residual_block(t1, filters=self.g_f_ch * 8, f_size=self.f_size)
        t3 = residual_block(t2, filters=self.g_f_ch * 8, f_size=self.f_size)
        t4 = residual_block(t3, filters=self.g_f_ch * 8, f_size=self.f_size)
        t5 = residual_block(t4, filters=self.g_f_ch * 8, f_size=self.f_size)
        t5 = GaussianNoise(0.01)(t5)
        t6 = residual_block(t5, filters=self.g_f_ch * 8, f_size=self.f_size)
        t7 = residual_block(t6, filters=self.g_f_ch * 8, f_size=self.f_size)
        t8 = residual_block(t7, filters=self.g_f_ch * 8, f_size=self.f_size)
        t9 = residual_block(t8, filters=self.g_f_ch * 8, f_size=self.f_size)
        t10 = residual_block(t9, filters=self.g_f_ch * 8, f_size=self.f_size)

        # Upsampling
        u1 = deconv2d(t10, skip_input=d3, filters=self.g_f_ch * 4)
        u2 = deconv2d(u1, skip_input=d2, filters=self.g_f_ch * 2)
        u3 = UpSampling2D(2)(u2)
        output_img = Conv2D(self.img_channels, kernel_size=self.first_f_size, strides=1, padding='same', activation='tanh')(u3)



        return Model([d0], output_img)

    # Discriminator

    def build_discriminator(self):

        def d_layer(layer_input, filters, dropout=self.discr_dropout_rate, f_size=self.d_f_size, normalization=True, s=2, dilation_rate=1):
            """Layers used during downsampling"""
            d = Conv2D(filters, kernel_size=f_size, strides=s, padding='same', dilation_rate=dilation_rate)(layer_input)
            d = LeakyReLU(self.leakyrel_alpha)(d)
            if normalization:
                d = InstanceNormalization()(d)
            if dropout:
                d = Dropout(dropout)(d)
            return d

        img = Input(shape=self.img_shape)
        d1 = d_layer(img, self.d_f_ch, f_size=self.first_f_size, normalization=False, s=1)
        d2 = d_layer(d1, self.d_f_ch * 2)
        d3 = d_layer(d2, self.d_f_ch * 4)
        d4 = d_layer(d3, self.d_f_ch * 8)
        d5 = d_layer(d4, self.d_f_ch * 16, dropout=0.05)
        validity = Conv2D(1, kernel_size=self.d_f_size, strides=1, padding='same', activation='linear')(d5)
        return Model(img, [validity])

    def write_log(self, callback, names, logs, batch_no):
        for name, value in zip(names, logs):
            summary = tf.Summary()
            summary_value = summary.value.add()
            summary_value.simple_value = value
            summary_value.tag = name
            callback.writer.add_summary(summary, batch_no)
            callback.writer.flush()

    def train(self, epochs):


        self.combined.summary()

        start_time = datetime.datetime.now()
        batch_size = self.batch_size

        # Adversarial loss ground truths
        valid = np.ones((batch_size,) + self.disc_patch) * 0.9
        fake = np.zeros((batch_size,) + self.disc_patch)

        for epoch in range(epochs):
            epoch = epoch+1

            imgs_A = self.domain_A_datagen.next()
            imgs_B = self.domain_B_datagen.next()

            imgs_A = (imgs_A*1/127.5)-1
            imgs_B = (imgs_B*1/127.5)-1

            # ----------------------
            #  Train Discriminators
            # ----------------------
            if self.flip_labels_modulus > 0 and epoch % self.flip_labels_modulus == 0:
                valid = np.zeros((batch_size,) + self.disc_patch)
                fake = np.ones((batch_size,) + self.disc_patch) * 0.9

            # Translate images to opposite domain
            fake_B_d_train = self.Gen_AB.predict([imgs_A])
            fake_A_d_train = self.Gen_BA.predict([imgs_B])

            # Train the discriminators (original images = real / translated = Fake)

            dA_loss_real = self.Disc_A.train_on_batch(imgs_A, [valid])
            dA_loss_fake = self.Disc_A.train_on_batch(fake_A_d_train, [fake])
            dA_loss = 0.5 * np.add(np.mean(dA_loss_real), np.mean(dA_loss_fake))

            dB_loss_real = self.Disc_B.train_on_batch(imgs_B, [valid])
            dB_loss_fake = self.Disc_B.train_on_batch(fake_B_d_train, [fake])
            dB_loss = 0.5 * np.add(np.mean(dB_loss_real), np.mean(dB_loss_fake))

            # Total disciminator loss
            d_loss = 0.5 * np.add(dA_loss, dB_loss)

            # ------------------
            #  Train Generators
            # ------------------
            # Train the generators

            fake_B = self.Gen_AB.predict([imgs_A])
            fake_A = self.Gen_BA.predict([imgs_B])

            content_A = self.perceptual_model.predict_on_batch(imgs_A)
            content_B = self.perceptual_model.predict_on_batch(imgs_B)

            g_loss = self.combined.train_on_batch([imgs_A, imgs_B],
                                                    [valid, valid,
                                                    content_A, content_B
                                                    ])

            elapsed_time = datetime.datetime.now() - start_time

            adversarial_g_loss = np.mean((g_loss[0:1]))
            perceptual_reconstruction_loss = np.mean((g_loss[2:]))

            # Print the progress

            print("[Epoch %d/%d] [D loss: %05f] [Adversarial_G_Loss: %05f, perc_recon: %05f] time: %s"
                        %(epoch, epochs,
                        d_loss, adversarial_g_loss,
                        perceptual_reconstruction_loss, str(elapsed_time)))

            if self.id_modulus > 0 and epoch % self.id_modulus == 0 and epoch < self.stop_id:
                id_loss = self.id_trainer.train_on_batch(x=[imgs_A, imgs_B], y=[imgs_A, imgs_B])
                print("[ID_loss_A: %05f, ID_loss_B: %05f, ID_loss_A_B: %05f] " %(id_loss[0], id_loss[1], np.mean((id_loss))))

            if self.sample_modulus > 0 and epoch % self.sample_modulus == 0:
                imgs_frame = np.concatenate([imgs_A, fake_B, imgs_B, fake_A])
                imgs_frame = imgs_frame.reshape(batch_size * 4 * self.img_height, self.img_width, self.img_channels)
                imgs_frame = array_to_img(imgs_frame)
                imgs_frame.save('/content/gdrive/MyDrive/Flood_Project/Image_Stylization/log_5/epoch_%d.jpg' % (epoch))

            # Reset data_gens / shuffle
            if self.domain_A_datagen.n == self.domain_A_datagen.batch_index:
                self.domain_A_datagen.reset()
                self.domain_A_datagen.on_epoch_end()

            if self.domain_B_datagen.n == self.domain_B_datagen.batch_index:
                self.domain_B_datagen.reset()
                self.domain_B_datagen.on_epoch_end()

            if self.save_gens > 0 and epoch % self.save_gens == 0:
                self.Gen_AB.save('/content/gdrive/MyDrive/Flood_Project/Image_Stylization/log_5/gen_ab_v2_%d.h5' %(epoch))
                self.Gen_BA.save('/content/gdrive/MyDrive/Flood_Project/Image_Stylization/log_5/gen_ba_v2_%d.h5' %(epoch))


if __name__ == '__main__':
    gan = CycleGAN()
    gan.train(epochs=10000)
# Out:
# Found 1000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# =================================================================
# Total params: 17,664,576
# Trainable params: 0
# Non-trainable params: 17,664,576
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_B (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# image_A (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# model_10 (Model)                (None, 256, 256, 3)  18556107    image_B[0][0]
#                                                                  model_9[1][0]
# __________________________________________________________________________________________________
# model_9 (Model)                 (None, 256, 256, 3)  18556107    image_A[0][0]
#                                                                  model_10[1][0]
# __________________________________________________________________________________________________
# model_7 (Model)                 (None, 16, 16, 1)    6287497     model_10[1][0]
# __________________________________________________________________________________________________
# model_8 (Model)                 (None, 16, 16, 1)    6287497     model_9[1][0]
# __________________________________________________________________________________________________
# model_6 (Model)                 (None, 16, 16, 512)  17664576    model_10[2][0]
#                                                                  model_9[2][0]
# ==================================================================================================
# Total params: 67,351,784
# Trainable params: 37,112,214
# Non-trainable params: 30,239,570
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# [Epoch 1/10000] [D loss: 25.943441] [Adversarial_G_Loss: 403.360413, perc_recon: 43.046631] time: 0:01:07.036712
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# [Epoch 2/10000] [D loss: 56.887312] [Adversarial_G_Loss: 89.013367, perc_recon: 22.991823] time: 0:01:08.198792
# [Epoch 3/10000] [D loss: 70.153793] [Adversarial_G_Loss: 126.972748, perc_recon: 27.417517] time: 0:01:09.627503
# [Epoch 4/10000] [D loss: 24.004235] [Adversarial_G_Loss: 24.703861, perc_recon: 3.113143] time: 0:01:10.796615
# [Epoch 5/10000] [D loss: 2.712669] [Adversarial_G_Loss: 13.092405, perc_recon: 2.042856] time: 0:01:20.669258
# [Epoch 6/10000] [D loss: 2.169471] [Adversarial_G_Loss: 6.846816, perc_recon: 0.485273] time: 0:01:21.499386
# [Epoch 7/10000] [D loss: 0.646737] [Adversarial_G_Loss: 7.896449, perc_recon: 0.485524] time: 0:01:22.333555
# [Epoch 8/10000] [D loss: 0.603688] [Adversarial_G_Loss: 6.452048, perc_recon: 0.583703] time: 0:01:23.138864
# [Epoch 9/10000] [D loss: 1.020990] [Adversarial_G_Loss: 7.574659, perc_recon: 0.676945] time: 0:01:24.262293
# [Epoch 10/10000] [D loss: 0.720233] [Adversarial_G_Loss: 8.355481, perc_recon: 0.529748] time: 0:01:25.177479
# [ID_loss_A: 1.128028, ID_loss_B: 0.588061, ID_loss_A_B: 0.752019]
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Streaming output truncated to the last 5000 lines.
# [Epoch 5001/10000] [D loss: 0.287936] [Adversarial_G_Loss: 2.917990, perc_recon: 0.262089] time: 1:10:11.071741
# [Epoch 5002/10000] [D loss: 0.303456] [Adversarial_G_Loss: 2.793170, perc_recon: 0.250140] time: 1:10:11.852811
# [Epoch 5003/10000] [D loss: 0.287179] [Adversarial_G_Loss: 2.972234, perc_recon: 0.314506] time: 1:10:12.573565
# [Epoch 5004/10000] [D loss: 0.309340] [Adversarial_G_Loss: 2.583922, perc_recon: 0.277160] time: 1:10:13.301715
# [Epoch 5005/10000] [D loss: 0.307905] [Adversarial_G_Loss: 2.970917, perc_recon: 0.327959] time: 1:10:14.089706
# [Epoch 5006/10000] [D loss: 0.301034] [Adversarial_G_Loss: 2.780952, perc_recon: 0.280377] time: 1:10:14.848544
# [Epoch 5007/10000] [D loss: 0.290863] [Adversarial_G_Loss: 2.618255, perc_recon: 0.337968] time: 1:10:15.677643
# [Epoch 5008/10000] [D loss: 0.302501] [Adversarial_G_Loss: 3.130245, perc_recon: 0.243981] time: 1:10:16.399541
# [Epoch 5009/10000] [D loss: 0.276579] [Adversarial_G_Loss: 2.926713, perc_recon: 0.282353] time: 1:10:17.155559
# [Epoch 5010/10000] [D loss: 0.271514] [Adversarial_G_Loss: 2.667058, perc_recon: 0.204561] time: 1:10:17.953668
# [Epoch 5011/10000] [D loss: 0.298942] [Adversarial_G_Loss: 2.547224, perc_recon: 0.325360] time: 1:10:18.799884
# [Epoch 5012/10000] [D loss: 0.281677] [Adversarial_G_Loss: 3.084147, perc_recon: 0.352368] time: 1:10:19.572232
# [Epoch 5013/10000] [D loss: 0.271431] [Adversarial_G_Loss: 2.561177, perc_recon: 0.197415] time: 1:10:20.470296
# [Epoch 5014/10000] [D loss: 0.270168] [Adversarial_G_Loss: 3.539635, perc_recon: 0.375009] time: 1:10:21.204685
# [Epoch 5015/10000] [D loss: 0.324022] [Adversarial_G_Loss: 2.439446, perc_recon: 0.261579] time: 1:10:22.036356
# [Epoch 5016/10000] [D loss: 0.204883] [Adversarial_G_Loss: 2.175856, perc_recon: 0.239827] time: 1:10:22.882507
# [Epoch 5017/10000] [D loss: 0.303777] [Adversarial_G_Loss: 2.551400, perc_recon: 0.294499] time: 1:10:23.726612
# [Epoch 5018/10000] [D loss: 0.330821] [Adversarial_G_Loss: 2.366429, perc_recon: 0.276081] time: 1:10:24.485672
# [Epoch 5019/10000] [D loss: 0.266352] [Adversarial_G_Loss: 2.299307, perc_recon: 0.260558] time: 1:10:25.334005
# [Epoch 5020/10000] [D loss: 0.295727] [Adversarial_G_Loss: 3.442492, perc_recon: 0.318904] time: 1:10:26.047587
# [Epoch 5021/10000] [D loss: 0.299303] [Adversarial_G_Loss: 2.038663, perc_recon: 0.191452] time: 1:10:26.904600
# [Epoch 5022/10000] [D loss: 0.294085] [Adversarial_G_Loss: 2.944266, perc_recon: 0.278532] time: 1:10:27.660045
# [Epoch 5023/10000] [D loss: 0.340680] [Adversarial_G_Loss: 2.493113, perc_recon: 0.182081] time: 1:10:28.431238
# [Epoch 5024/10000] [D loss: 0.256561] [Adversarial_G_Loss: 2.506183, perc_recon: 0.230761] time: 1:10:29.180077
# [Epoch 5025/10000] [D loss: 0.304808] [Adversarial_G_Loss: 2.635914, perc_recon: 0.208662] time: 1:10:29.931534
# [Epoch 5026/10000] [D loss: 0.321625] [Adversarial_G_Loss: 2.672449, perc_recon: 0.237028] time: 1:10:30.721513
# [Epoch 5027/10000] [D loss: 0.310339] [Adversarial_G_Loss: 2.409734, perc_recon: 0.252959] time: 1:10:31.484590
# [Epoch 5028/10000] [D loss: 0.295296] [Adversarial_G_Loss: 2.698119, perc_recon: 0.266459] time: 1:10:32.177956
# [Epoch 5029/10000] [D loss: 0.246889] [Adversarial_G_Loss: 2.622957, perc_recon: 0.335511] time: 1:10:33.036441
# [Epoch 5030/10000] [D loss: 0.293547] [Adversarial_G_Loss: 3.193167, perc_recon: 0.274547] time: 1:10:33.747922
# [Epoch 5031/10000] [D loss: 0.288184] [Adversarial_G_Loss: 2.497489, perc_recon: 0.277553] time: 1:10:34.518635
# [Epoch 5032/10000] [D loss: 0.290490] [Adversarial_G_Loss: 2.815912, perc_recon: 0.302776] time: 1:10:35.296384
# [Epoch 5033/10000] [D loss: 0.317500] [Adversarial_G_Loss: 2.800614, perc_recon: 0.289324] time: 1:10:36.082293
# [Epoch 5034/10000] [D loss: 0.285629] [Adversarial_G_Loss: 2.147338, perc_recon: 0.214079] time: 1:10:36.934167
# [Epoch 5035/10000] [D loss: 0.292451] [Adversarial_G_Loss: 2.331141, perc_recon: 0.237242] time: 1:10:37.786069
# [Epoch 5036/10000] [D loss: 0.288410] [Adversarial_G_Loss: 2.984014, perc_recon: 0.313826] time: 1:10:38.584547
# [Epoch 5037/10000] [D loss: 0.236243] [Adversarial_G_Loss: 3.051875, perc_recon: 0.222495] time: 1:10:39.262084
# [Epoch 5038/10000] [D loss: 0.271574] [Adversarial_G_Loss: 2.863911, perc_recon: 0.340561] time: 1:10:40.018792
# [Epoch 5039/10000] [D loss: 0.307245] [Adversarial_G_Loss: 2.126001, perc_recon: 0.217060] time: 1:10:40.799057
# [Epoch 5040/10000] [D loss: 0.328041] [Adversarial_G_Loss: 2.512371, perc_recon: 0.307143] time: 1:10:41.573600
# [Epoch 5041/10000] [D loss: 0.383629] [Adversarial_G_Loss: 2.287541, perc_recon: 0.175187] time: 1:10:42.336269
# [Epoch 5042/10000] [D loss: 0.355905] [Adversarial_G_Loss: 1.942956, perc_recon: 0.160206] time: 1:10:43.153634
# [Epoch 5043/10000] [D loss: 0.231157] [Adversarial_G_Loss: 2.605878, perc_recon: 0.193476] time: 1:10:43.940930
# [Epoch 5044/10000] [D loss: 0.302648] [Adversarial_G_Loss: 2.065596, perc_recon: 0.177497] time: 1:10:44.799656
# [Epoch 5045/10000] [D loss: 0.295576] [Adversarial_G_Loss: 2.559103, perc_recon: 0.197822] time: 1:10:45.584365
# [Epoch 5046/10000] [D loss: 0.351677] [Adversarial_G_Loss: 2.419726, perc_recon: 0.165250] time: 1:10:46.235152
# [Epoch 5047/10000] [D loss: 0.294103] [Adversarial_G_Loss: 2.992376, perc_recon: 0.209485] time: 1:10:46.908536
# [Epoch 5048/10000] [D loss: 0.307860] [Adversarial_G_Loss: 2.521928, perc_recon: 0.201958] time: 1:10:47.593180
# [Epoch 5049/10000] [D loss: 0.271166] [Adversarial_G_Loss: 2.513042, perc_recon: 0.212428] time: 1:10:48.381618
# [Epoch 5050/10000] [D loss: 0.309667] [Adversarial_G_Loss: 2.279452, perc_recon: 0.201194] time: 1:10:49.171865
# [Epoch 5051/10000] [D loss: 0.276128] [Adversarial_G_Loss: 2.524375, perc_recon: 0.212515] time: 1:10:49.890891
# [Epoch 5052/10000] [D loss: 0.313092] [Adversarial_G_Loss: 2.509629, perc_recon: 0.204349] time: 1:10:50.685294
# [Epoch 5053/10000] [D loss: 0.304333] [Adversarial_G_Loss: 2.756884, perc_recon: 0.217929] time: 1:10:51.468088
# [Epoch 5054/10000] [D loss: 0.273589] [Adversarial_G_Loss: 2.576812, perc_recon: 0.221355] time: 1:10:52.242803
# [Epoch 5055/10000] [D loss: 0.301019] [Adversarial_G_Loss: 2.616600, perc_recon: 0.277511] time: 1:10:52.969175
# [Epoch 5056/10000] [D loss: 0.272393] [Adversarial_G_Loss: 2.927846, perc_recon: 0.220516] time: 1:10:53.679455
# [Epoch 5057/10000] [D loss: 0.317342] [Adversarial_G_Loss: 3.206785, perc_recon: 0.272559] time: 1:10:54.390601
# [Epoch 5058/10000] [D loss: 0.313735] [Adversarial_G_Loss: 2.688752, perc_recon: 0.245775] time: 1:10:55.162094
# [Epoch 5059/10000] [D loss: 0.251597] [Adversarial_G_Loss: 2.625795, perc_recon: 0.182003] time: 1:10:55.932199
# [Epoch 5060/10000] [D loss: 0.278019] [Adversarial_G_Loss: 2.764857, perc_recon: 0.270317] time: 1:10:56.724027
# [Epoch 5061/10000] [D loss: 0.274651] [Adversarial_G_Loss: 2.966306, perc_recon: 0.297648] time: 1:10:57.438167
# [Epoch 5062/10000] [D loss: 0.341804] [Adversarial_G_Loss: 3.064887, perc_recon: 0.260318] time: 1:10:58.148826
# [Epoch 5063/10000] [D loss: 0.247955] [Adversarial_G_Loss: 2.842003, perc_recon: 0.243681] time: 1:10:58.923481
# [Epoch 5064/10000] [D loss: 0.300633] [Adversarial_G_Loss: 2.607301, perc_recon: 0.273727] time: 1:10:59.777092
# [Epoch 5065/10000] [D loss: 0.290895] [Adversarial_G_Loss: 3.161258, perc_recon: 0.285993] time: 1:11:00.501128
# [Epoch 5066/10000] [D loss: 0.372523] [Adversarial_G_Loss: 2.790407, perc_recon: 0.217187] time: 1:11:01.293708
# [Epoch 5067/10000] [D loss: 0.349262] [Adversarial_G_Loss: 2.338448, perc_recon: 0.209434] time: 1:11:02.141687
# [Epoch 5068/10000] [D loss: 0.309031] [Adversarial_G_Loss: 2.592391, perc_recon: 0.259112] time: 1:11:02.929130
# [Epoch 5069/10000] [D loss: 0.330167] [Adversarial_G_Loss: 3.747345, perc_recon: 0.289384] time: 1:11:03.645918
# [Epoch 5070/10000] [D loss: 0.308290] [Adversarial_G_Loss: 2.284244, perc_recon: 0.209055] time: 1:11:04.435413
# [Epoch 5071/10000] [D loss: 0.310205] [Adversarial_G_Loss: 2.584192, perc_recon: 0.262650] time: 1:11:05.204923
# [Epoch 5072/10000] [D loss: 0.310529] [Adversarial_G_Loss: 2.386288, perc_recon: 0.273550] time: 1:11:06.054383
# [Epoch 5073/10000] [D loss: 0.303157] [Adversarial_G_Loss: 2.495975, perc_recon: 0.350498] time: 1:11:06.882203
# [Epoch 5074/10000] [D loss: 0.342515] [Adversarial_G_Loss: 2.560321, perc_recon: 0.248127] time: 1:11:07.664968
# [Epoch 5075/10000] [D loss: 0.292247] [Adversarial_G_Loss: 2.013949, perc_recon: 0.225655] time: 1:11:08.514355
# [Epoch 5076/10000] [D loss: 0.319709] [Adversarial_G_Loss: 2.503871, perc_recon: 0.247470] time: 1:11:09.363729
# [Epoch 5077/10000] [D loss: 0.332327] [Adversarial_G_Loss: 2.218009, perc_recon: 0.227144] time: 1:11:10.153271
# [Epoch 5078/10000] [D loss: 0.277042] [Adversarial_G_Loss: 2.734741, perc_recon: 0.314676] time: 1:11:10.940894
# [Epoch 5079/10000] [D loss: 0.316496] [Adversarial_G_Loss: 3.146865, perc_recon: 0.322024] time: 1:11:11.699924
# [Epoch 5080/10000] [D loss: 0.319367] [Adversarial_G_Loss: 2.661199, perc_recon: 0.261995] time: 1:11:12.482870
# [Epoch 5081/10000] [D loss: 0.298590] [Adversarial_G_Loss: 2.607448, perc_recon: 0.234062] time: 1:11:13.268243
# [Epoch 5082/10000] [D loss: 0.291423] [Adversarial_G_Loss: 2.253555, perc_recon: 0.264143] time: 1:11:14.125230
# [Epoch 5083/10000] [D loss: 0.316236] [Adversarial_G_Loss: 2.235337, perc_recon: 0.221568] time: 1:11:14.871367
# [Epoch 5084/10000] [D loss: 0.316609] [Adversarial_G_Loss: 2.190307, perc_recon: 0.252852] time: 1:11:15.640006
# [Epoch 5085/10000] [D loss: 0.302878] [Adversarial_G_Loss: 2.713997, perc_recon: 0.267891] time: 1:11:16.349903
# [Epoch 5086/10000] [D loss: 0.299682] [Adversarial_G_Loss: 3.105956, perc_recon: 0.315788] time: 1:11:17.067614
# [Epoch 5087/10000] [D loss: 0.288917] [Adversarial_G_Loss: 2.057065, perc_recon: 0.178397] time: 1:11:17.893992
# [Epoch 5088/10000] [D loss: 0.297280] [Adversarial_G_Loss: 3.180663, perc_recon: 0.302332] time: 1:11:18.611283
# [Epoch 5089/10000] [D loss: 0.314084] [Adversarial_G_Loss: 2.900935, perc_recon: 0.225708] time: 1:11:19.323809
# [Epoch 5090/10000] [D loss: 0.295197] [Adversarial_G_Loss: 2.807148, perc_recon: 0.324447] time: 1:11:20.188677
# [Epoch 5091/10000] [D loss: 0.323033] [Adversarial_G_Loss: 2.447969, perc_recon: 0.337972] time: 1:11:20.922124
# [Epoch 5092/10000] [D loss: 0.319236] [Adversarial_G_Loss: 2.482924, perc_recon: 0.200731] time: 1:11:21.716904
# [Epoch 5093/10000] [D loss: 0.307335] [Adversarial_G_Loss: 2.367560, perc_recon: 0.246181] time: 1:11:22.451827
# [Epoch 5094/10000] [D loss: 0.316624] [Adversarial_G_Loss: 2.775759, perc_recon: 0.270497] time: 1:11:23.241143
# [Epoch 5095/10000] [D loss: 0.334456] [Adversarial_G_Loss: 2.179410, perc_recon: 0.171826] time: 1:11:24.107519
# [Epoch 5096/10000] [D loss: 0.307126] [Adversarial_G_Loss: 2.328262, perc_recon: 0.236817] time: 1:11:24.891366
# [Epoch 5097/10000] [D loss: 0.304489] [Adversarial_G_Loss: 2.664067, perc_recon: 0.246619] time: 1:11:25.679574
# [Epoch 5098/10000] [D loss: 0.327554] [Adversarial_G_Loss: 1.903629, perc_recon: 0.193359] time: 1:11:26.449761
# [Epoch 5099/10000] [D loss: 0.304333] [Adversarial_G_Loss: 3.085294, perc_recon: 0.366934] time: 1:11:27.229413
# [Epoch 5100/10000] [D loss: 0.328024] [Adversarial_G_Loss: 2.638829, perc_recon: 0.306789] time: 1:11:28.014146
# [Epoch 5101/10000] [D loss: 0.290826] [Adversarial_G_Loss: 2.482407, perc_recon: 0.195523] time: 1:11:29.521375
# [Epoch 5102/10000] [D loss: 0.305462] [Adversarial_G_Loss: 2.624488, perc_recon: 0.202268] time: 1:11:30.230255
# [Epoch 5103/10000] [D loss: 0.245104] [Adversarial_G_Loss: 2.418242, perc_recon: 0.183375] time: 1:11:30.947135
# [Epoch 5104/10000] [D loss: 0.339385] [Adversarial_G_Loss: 2.554399, perc_recon: 0.262237] time: 1:11:31.723293
# [Epoch 5105/10000] [D loss: 0.319264] [Adversarial_G_Loss: 2.082750, perc_recon: 0.228216] time: 1:11:32.554603
# [Epoch 5106/10000] [D loss: 0.246812] [Adversarial_G_Loss: 2.080595, perc_recon: 0.170148] time: 1:11:33.324962
# [Epoch 5107/10000] [D loss: 0.292363] [Adversarial_G_Loss: 2.077267, perc_recon: 0.217924] time: 1:11:34.180564
# [Epoch 5108/10000] [D loss: 0.296650] [Adversarial_G_Loss: 2.463981, perc_recon: 0.249421] time: 1:11:35.064623
# [Epoch 5109/10000] [D loss: 0.290769] [Adversarial_G_Loss: 2.492494, perc_recon: 0.285399] time: 1:11:35.847884
# [Epoch 5110/10000] [D loss: 0.285545] [Adversarial_G_Loss: 2.856469, perc_recon: 0.267973] time: 1:11:36.561105
# [Epoch 5111/10000] [D loss: 0.282455] [Adversarial_G_Loss: 2.235932, perc_recon: 0.147508] time: 1:11:37.274592
# [Epoch 5112/10000] [D loss: 0.297290] [Adversarial_G_Loss: 2.498955, perc_recon: 0.285666] time: 1:11:38.164120
# [Epoch 5113/10000] [D loss: 0.284810] [Adversarial_G_Loss: 2.362916, perc_recon: 0.288469] time: 1:11:38.932852
# [Epoch 5114/10000] [D loss: 0.294452] [Adversarial_G_Loss: 2.579244, perc_recon: 0.282853] time: 1:11:39.721082
# [Epoch 5115/10000] [D loss: 0.284199] [Adversarial_G_Loss: 2.824031, perc_recon: 0.166312] time: 1:11:40.518948
# [Epoch 5116/10000] [D loss: 0.315710] [Adversarial_G_Loss: 2.448631, perc_recon: 0.181776] time: 1:11:41.371089
# [Epoch 5117/10000] [D loss: 0.313014] [Adversarial_G_Loss: 2.010746, perc_recon: 0.097428] time: 1:11:42.224413
# [Epoch 5118/10000] [D loss: 0.278189] [Adversarial_G_Loss: 2.924414, perc_recon: 0.258491] time: 1:11:42.910278
# [Epoch 5119/10000] [D loss: 0.337724] [Adversarial_G_Loss: 2.404512, perc_recon: 0.116056] time: 1:11:43.679306
# [Epoch 5120/10000] [D loss: 0.282543] [Adversarial_G_Loss: 1.740465, perc_recon: 0.079327] time: 1:11:44.449641
# [Epoch 5121/10000] [D loss: 0.289962] [Adversarial_G_Loss: 2.520812, perc_recon: 0.082176] time: 1:11:45.128643
# [Epoch 5122/10000] [D loss: 0.307916] [Adversarial_G_Loss: 2.454689, perc_recon: 0.159850] time: 1:11:45.838273
# [Epoch 5123/10000] [D loss: 0.296614] [Adversarial_G_Loss: 2.501195, perc_recon: 0.177434] time: 1:11:46.714968
# [Epoch 5124/10000] [D loss: 0.306844] [Adversarial_G_Loss: 2.490068, perc_recon: 0.131082] time: 1:11:47.486675
# [Epoch 5125/10000] [D loss: 0.297379] [Adversarial_G_Loss: 2.696129, perc_recon: 0.243038] time: 1:11:48.239333
# [Epoch 5126/10000] [D loss: 0.290785] [Adversarial_G_Loss: 2.569690, perc_recon: 0.286715] time: 1:11:49.101752
# [Epoch 5127/10000] [D loss: 0.292316] [Adversarial_G_Loss: 3.179291, perc_recon: 0.306753] time: 1:11:49.899069
# [Epoch 5128/10000] [D loss: 0.280028] [Adversarial_G_Loss: 2.939024, perc_recon: 0.301724] time: 1:11:50.757582
# [Epoch 5129/10000] [D loss: 0.289179] [Adversarial_G_Loss: 2.429167, perc_recon: 0.229605] time: 1:11:51.507574
# [Epoch 5130/10000] [D loss: 0.215710] [Adversarial_G_Loss: 2.294713, perc_recon: 0.266807] time: 1:11:52.347167
# [Epoch 5131/10000] [D loss: 0.314319] [Adversarial_G_Loss: 2.545376, perc_recon: 0.226259] time: 1:11:53.130541
# [Epoch 5132/10000] [D loss: 0.258964] [Adversarial_G_Loss: 3.201028, perc_recon: 0.240751] time: 1:11:53.846947
# [Epoch 5133/10000] [D loss: 0.276023] [Adversarial_G_Loss: 2.659118, perc_recon: 0.327143] time: 1:11:54.626776
# [Epoch 5134/10000] [D loss: 0.307372] [Adversarial_G_Loss: 2.379036, perc_recon: 0.215423] time: 1:11:55.351680
# [Epoch 5135/10000] [D loss: 0.268489] [Adversarial_G_Loss: 2.417431, perc_recon: 0.255466] time: 1:11:56.144531
# [Epoch 5136/10000] [D loss: 0.307626] [Adversarial_G_Loss: 3.047328, perc_recon: 0.300773] time: 1:11:56.838244
# [Epoch 5137/10000] [D loss: 0.350226] [Adversarial_G_Loss: 2.625374, perc_recon: 0.170740] time: 1:11:57.622057
# [Epoch 5138/10000] [D loss: 0.258365] [Adversarial_G_Loss: 2.373271, perc_recon: 0.108113] time: 1:11:58.396693
# [Epoch 5139/10000] [D loss: 0.277798] [Adversarial_G_Loss: 2.075671, perc_recon: 0.061381] time: 1:11:59.177876
# [Epoch 5140/10000] [D loss: 0.300236] [Adversarial_G_Loss: 2.598797, perc_recon: 0.089185] time: 1:11:59.963353
# [Epoch 5141/10000] [D loss: 0.336699] [Adversarial_G_Loss: 2.093807, perc_recon: 0.094090] time: 1:12:00.680348
# [Epoch 5142/10000] [D loss: 0.286812] [Adversarial_G_Loss: 2.361281, perc_recon: 0.104537] time: 1:12:01.437316
# [Epoch 5143/10000] [D loss: 0.281043] [Adversarial_G_Loss: 2.821948, perc_recon: 0.271426] time: 1:12:02.152070
# [Epoch 5144/10000] [D loss: 0.257179] [Adversarial_G_Loss: 2.118778, perc_recon: 0.067534] time: 1:12:02.873285
# [Epoch 5145/10000] [D loss: 0.279348] [Adversarial_G_Loss: 2.427897, perc_recon: 0.121912] time: 1:12:03.552336
# [Epoch 5146/10000] [D loss: 0.318357] [Adversarial_G_Loss: 2.875762, perc_recon: 0.317742] time: 1:12:04.295252
# [Epoch 5147/10000] [D loss: 0.278191] [Adversarial_G_Loss: 2.884943, perc_recon: 0.136186] time: 1:12:05.080852
# [Epoch 5148/10000] [D loss: 0.292073] [Adversarial_G_Loss: 2.801758, perc_recon: 0.287600] time: 1:12:05.857446
# [Epoch 5149/10000] [D loss: 0.367326] [Adversarial_G_Loss: 1.747409, perc_recon: 0.058587] time: 1:12:06.697923
# [Epoch 5150/10000] [D loss: 0.322263] [Adversarial_G_Loss: 3.238054, perc_recon: 0.124485] time: 1:12:07.414099
# [Epoch 5151/10000] [D loss: 0.259277] [Adversarial_G_Loss: 1.936001, perc_recon: 0.088579] time: 1:12:08.196608
# [Epoch 5152/10000] [D loss: 0.254932] [Adversarial_G_Loss: 2.163320, perc_recon: 0.069179] time: 1:12:08.993190
# [Epoch 5153/10000] [D loss: 0.313944] [Adversarial_G_Loss: 1.802226, perc_recon: 0.053964] time: 1:12:09.782654
# [Epoch 5154/10000] [D loss: 0.312712] [Adversarial_G_Loss: 2.310981, perc_recon: 0.131836] time: 1:12:10.495399
# [Epoch 5155/10000] [D loss: 0.313036] [Adversarial_G_Loss: 1.974082, perc_recon: 0.067568] time: 1:12:11.271195
# [Epoch 5156/10000] [D loss: 0.320930] [Adversarial_G_Loss: 2.331331, perc_recon: 0.085887] time: 1:12:11.957122
# [Epoch 5157/10000] [D loss: 0.261670] [Adversarial_G_Loss: 1.958231, perc_recon: 0.142644] time: 1:12:12.735773
# [Epoch 5158/10000] [D loss: 0.336847] [Adversarial_G_Loss: 1.541521, perc_recon: 0.057551] time: 1:12:13.558752
# [Epoch 5159/10000] [D loss: 0.290203] [Adversarial_G_Loss: 1.952278, perc_recon: 0.082592] time: 1:12:14.409480
# [Epoch 5160/10000] [D loss: 0.209156] [Adversarial_G_Loss: 2.157499, perc_recon: 0.086301] time: 1:12:15.258361
# [Epoch 5161/10000] [D loss: 0.322252] [Adversarial_G_Loss: 1.942610, perc_recon: 0.057749] time: 1:12:16.063279
# [Epoch 5162/10000] [D loss: 0.291492] [Adversarial_G_Loss: 1.810549, perc_recon: 0.078575] time: 1:12:16.914161
# [Epoch 5163/10000] [D loss: 0.296521] [Adversarial_G_Loss: 2.495478, perc_recon: 0.079615] time: 1:12:17.710779
# [Epoch 5164/10000] [D loss: 0.320640] [Adversarial_G_Loss: 2.020967, perc_recon: 0.074098] time: 1:12:18.425573
# [Epoch 5165/10000] [D loss: 0.243867] [Adversarial_G_Loss: 2.434266, perc_recon: 0.130674] time: 1:12:19.142052
# [Epoch 5166/10000] [D loss: 0.298482] [Adversarial_G_Loss: 2.605549, perc_recon: 0.129602] time: 1:12:19.929540
# [Epoch 5167/10000] [D loss: 0.301137] [Adversarial_G_Loss: 1.866931, perc_recon: 0.108212] time: 1:12:20.777928
# [Epoch 5168/10000] [D loss: 0.267417] [Adversarial_G_Loss: 2.375853, perc_recon: 0.094827] time: 1:12:21.498681
# [Epoch 5169/10000] [D loss: 0.363199] [Adversarial_G_Loss: 2.231308, perc_recon: 0.065337] time: 1:12:22.264704
# [Epoch 5170/10000] [D loss: 0.311839] [Adversarial_G_Loss: 2.229285, perc_recon: 0.071173] time: 1:12:22.956162
# [Epoch 5171/10000] [D loss: 0.261050] [Adversarial_G_Loss: 2.384928, perc_recon: 0.105677] time: 1:12:23.743237
# [Epoch 5172/10000] [D loss: 0.349115] [Adversarial_G_Loss: 2.185213, perc_recon: 0.101425] time: 1:12:24.436785
# [Epoch 5173/10000] [D loss: 0.314827] [Adversarial_G_Loss: 2.157089, perc_recon: 0.079511] time: 1:12:25.227981
# [Epoch 5174/10000] [D loss: 0.274235] [Adversarial_G_Loss: 2.379765, perc_recon: 0.076651] time: 1:12:26.026356
# [Epoch 5175/10000] [D loss: 0.273900] [Adversarial_G_Loss: 2.289866, perc_recon: 0.078082] time: 1:12:26.824758
# [Epoch 5176/10000] [D loss: 0.294891] [Adversarial_G_Loss: 2.032605, perc_recon: 0.064742] time: 1:12:27.589939
# [Epoch 5177/10000] [D loss: 0.263460] [Adversarial_G_Loss: 1.616657, perc_recon: 0.062174] time: 1:12:28.439245
# [Epoch 5178/10000] [D loss: 0.283376] [Adversarial_G_Loss: 2.609580, perc_recon: 0.083640] time: 1:12:29.150676
# [Epoch 5179/10000] [D loss: 0.271199] [Adversarial_G_Loss: 2.080977, perc_recon: 0.088478] time: 1:12:29.828605
# [Epoch 5180/10000] [D loss: 0.294274] [Adversarial_G_Loss: 1.882717, perc_recon: 0.063392] time: 1:12:30.544492
# [Epoch 5181/10000] [D loss: 0.295456] [Adversarial_G_Loss: 2.302816, perc_recon: 0.105709] time: 1:12:31.227606
# [Epoch 5182/10000] [D loss: 0.292737] [Adversarial_G_Loss: 1.906766, perc_recon: 0.070661] time: 1:12:32.022267
# [Epoch 5183/10000] [D loss: 0.275661] [Adversarial_G_Loss: 2.620016, perc_recon: 0.100257] time: 1:12:32.808611
# [Epoch 5184/10000] [D loss: 0.299325] [Adversarial_G_Loss: 1.796325, perc_recon: 0.056575] time: 1:12:33.545589
# [Epoch 5185/10000] [D loss: 0.260816] [Adversarial_G_Loss: 2.192735, perc_recon: 0.170711] time: 1:12:34.265605
# [Epoch 5186/10000] [D loss: 0.291453] [Adversarial_G_Loss: 2.295332, perc_recon: 0.075285] time: 1:12:34.984987
# [Epoch 5187/10000] [D loss: 0.327661] [Adversarial_G_Loss: 2.129950, perc_recon: 0.111664] time: 1:12:35.760598
# [Epoch 5188/10000] [D loss: 0.301443] [Adversarial_G_Loss: 1.864227, perc_recon: 0.066741] time: 1:12:36.542859
# [Epoch 5189/10000] [D loss: 0.268666] [Adversarial_G_Loss: 1.502414, perc_recon: 0.072415] time: 1:12:37.357875
# [Epoch 5190/10000] [D loss: 0.291760] [Adversarial_G_Loss: 1.873032, perc_recon: 0.078535] time: 1:12:38.124518
# [Epoch 5191/10000] [D loss: 0.232507] [Adversarial_G_Loss: 2.507198, perc_recon: 0.173974] time: 1:12:38.803560
# [Epoch 5192/10000] [D loss: 0.287126] [Adversarial_G_Loss: 1.630881, perc_recon: 0.071098] time: 1:12:39.661866
# [Epoch 5193/10000] [D loss: 0.292737] [Adversarial_G_Loss: 1.919227, perc_recon: 0.096641] time: 1:12:40.521993
# [Epoch 5194/10000] [D loss: 0.311729] [Adversarial_G_Loss: 2.310124, perc_recon: 0.087108] time: 1:12:41.318645
# [Epoch 5195/10000] [D loss: 0.296363] [Adversarial_G_Loss: 1.704860, perc_recon: 0.057357] time: 1:12:42.085773
# [Epoch 5196/10000] [D loss: 0.295745] [Adversarial_G_Loss: 1.818086, perc_recon: 0.054844] time: 1:12:42.853039
# [Epoch 5197/10000] [D loss: 0.292288] [Adversarial_G_Loss: 1.854964, perc_recon: 0.113661] time: 1:12:43.717834
# [Epoch 5198/10000] [D loss: 0.284692] [Adversarial_G_Loss: 2.070913, perc_recon: 0.067961] time: 1:12:44.564066
# [Epoch 5199/10000] [D loss: 0.313041] [Adversarial_G_Loss: 1.480440, perc_recon: 0.091672] time: 1:12:45.387732
# [Epoch 5200/10000] [D loss: 0.275431] [Adversarial_G_Loss: 1.704874, perc_recon: 0.054961] time: 1:12:46.261647
# [Epoch 5201/10000] [D loss: 0.286361] [Adversarial_G_Loss: 1.246803, perc_recon: 0.038239] time: 1:12:47.842925
# [Epoch 5202/10000] [D loss: 0.252947] [Adversarial_G_Loss: 1.885391, perc_recon: 0.065720] time: 1:12:48.612891
# [Epoch 5203/10000] [D loss: 0.288095] [Adversarial_G_Loss: 2.127600, perc_recon: 0.083279] time: 1:12:49.325689
# [Epoch 5204/10000] [D loss: 0.324084] [Adversarial_G_Loss: 1.962874, perc_recon: 0.115619] time: 1:12:50.181501
# [Epoch 5205/10000] [D loss: 0.327826] [Adversarial_G_Loss: 2.016452, perc_recon: 0.091134] time: 1:12:50.930334
# [Epoch 5206/10000] [D loss: 0.295483] [Adversarial_G_Loss: 1.644556, perc_recon: 0.056723] time: 1:12:51.790145
# [Epoch 5207/10000] [D loss: 0.284061] [Adversarial_G_Loss: 1.906607, perc_recon: 0.062930] time: 1:12:52.532414
# [Epoch 5208/10000] [D loss: 0.287680] [Adversarial_G_Loss: 1.489335, perc_recon: 0.054470] time: 1:12:53.282393
# [Epoch 5209/10000] [D loss: 0.291334] [Adversarial_G_Loss: 2.313534, perc_recon: 0.099973] time: 1:12:54.065583
# [Epoch 5210/10000] [D loss: 0.280789] [Adversarial_G_Loss: 2.357865, perc_recon: 0.088046] time: 1:12:54.783208
# [Epoch 5211/10000] [D loss: 0.256407] [Adversarial_G_Loss: 1.489969, perc_recon: 0.129880] time: 1:12:55.600336
# [Epoch 5212/10000] [D loss: 0.287391] [Adversarial_G_Loss: 1.382468, perc_recon: 0.055764] time: 1:12:56.458812
# [Epoch 5213/10000] [D loss: 0.331006] [Adversarial_G_Loss: 1.855162, perc_recon: 0.072340] time: 1:12:57.234296
# [Epoch 5214/10000] [D loss: 0.280380] [Adversarial_G_Loss: 1.839680, perc_recon: 0.062579] time: 1:12:58.120765
# [Epoch 5215/10000] [D loss: 0.268942] [Adversarial_G_Loss: 1.722320, perc_recon: 0.052104] time: 1:12:58.941941
# [Epoch 5216/10000] [D loss: 0.236040] [Adversarial_G_Loss: 1.683110, perc_recon: 0.049415] time: 1:12:59.725074
# [Epoch 5217/10000] [D loss: 0.342386] [Adversarial_G_Loss: 1.563175, perc_recon: 0.074699] time: 1:13:00.498852
# [Epoch 5218/10000] [D loss: 0.205580] [Adversarial_G_Loss: 2.356631, perc_recon: 0.169275] time: 1:13:01.274380
# [Epoch 5219/10000] [D loss: 0.288829] [Adversarial_G_Loss: 2.152611, perc_recon: 0.126121] time: 1:13:01.971305
# [Epoch 5220/10000] [D loss: 0.301404] [Adversarial_G_Loss: 2.285607, perc_recon: 0.091493] time: 1:13:02.776448
# [Epoch 5221/10000] [D loss: 0.305547] [Adversarial_G_Loss: 2.122297, perc_recon: 0.088931] time: 1:13:03.462441
# [Epoch 5222/10000] [D loss: 0.322113] [Adversarial_G_Loss: 1.857308, perc_recon: 0.069595] time: 1:13:04.241726
# [Epoch 5223/10000] [D loss: 0.218095] [Adversarial_G_Loss: 2.106096, perc_recon: 0.066212] time: 1:13:05.019796
# [Epoch 5224/10000] [D loss: 0.274357] [Adversarial_G_Loss: 1.911353, perc_recon: 0.128036] time: 1:13:05.789831
# [Epoch 5225/10000] [D loss: 0.324840] [Adversarial_G_Loss: 2.540528, perc_recon: 0.088444] time: 1:13:06.494033
# [Epoch 5226/10000] [D loss: 0.257957] [Adversarial_G_Loss: 1.822554, perc_recon: 0.080362] time: 1:13:07.262299
# [Epoch 5227/10000] [D loss: 0.267616] [Adversarial_G_Loss: 2.310157, perc_recon: 0.084568] time: 1:13:07.984980
# [Epoch 5228/10000] [D loss: 0.313297] [Adversarial_G_Loss: 2.077212, perc_recon: 0.083238] time: 1:13:08.716238
# [Epoch 5229/10000] [D loss: 0.288822] [Adversarial_G_Loss: 1.721583, perc_recon: 0.101633] time: 1:13:09.490389
# [Epoch 5230/10000] [D loss: 0.261152] [Adversarial_G_Loss: 1.931288, perc_recon: 0.087123] time: 1:13:10.179200
# [Epoch 5231/10000] [D loss: 0.253777] [Adversarial_G_Loss: 1.397194, perc_recon: 0.077017] time: 1:13:11.014512
# [Epoch 5232/10000] [D loss: 0.227094] [Adversarial_G_Loss: 2.308977, perc_recon: 0.128895] time: 1:13:11.806741
# [Epoch 5233/10000] [D loss: 0.281760] [Adversarial_G_Loss: 2.018562, perc_recon: 0.115159] time: 1:13:12.683988
# [Epoch 5234/10000] [D loss: 0.303098] [Adversarial_G_Loss: 1.702486, perc_recon: 0.064656] time: 1:13:13.544778
# [Epoch 5235/10000] [D loss: 0.284381] [Adversarial_G_Loss: 1.509285, perc_recon: 0.087091] time: 1:13:14.396305
# [Epoch 5236/10000] [D loss: 0.314725] [Adversarial_G_Loss: 1.649219, perc_recon: 0.053802] time: 1:13:15.182243
# [Epoch 5237/10000] [D loss: 0.276963] [Adversarial_G_Loss: 1.601023, perc_recon: 0.068823] time: 1:13:16.017948
# [Epoch 5238/10000] [D loss: 0.304346] [Adversarial_G_Loss: 2.479926, perc_recon: 0.100770] time: 1:13:16.695930
# [Epoch 5239/10000] [D loss: 0.293961] [Adversarial_G_Loss: 1.959503, perc_recon: 0.070349] time: 1:13:17.465924
# [Epoch 5240/10000] [D loss: 0.278222] [Adversarial_G_Loss: 1.571248, perc_recon: 0.065396] time: 1:13:18.289552
# [Epoch 5241/10000] [D loss: 0.276819] [Adversarial_G_Loss: 1.363276, perc_recon: 0.056076] time: 1:13:19.147438
# [Epoch 5242/10000] [D loss: 0.287749] [Adversarial_G_Loss: 2.294010, perc_recon: 0.082107] time: 1:13:19.837178
# [Epoch 5243/10000] [D loss: 0.278810] [Adversarial_G_Loss: 1.780596, perc_recon: 0.074628] time: 1:13:20.689752
# [Epoch 5244/10000] [D loss: 0.275979] [Adversarial_G_Loss: 1.862989, perc_recon: 0.066096] time: 1:13:21.340528
# [Epoch 5245/10000] [D loss: 0.265006] [Adversarial_G_Loss: 1.778210, perc_recon: 0.059070] time: 1:13:22.199552
# [Epoch 5246/10000] [D loss: 0.281038] [Adversarial_G_Loss: 1.405110, perc_recon: 0.053609] time: 1:13:23.046257
# [Epoch 5247/10000] [D loss: 0.306880] [Adversarial_G_Loss: 1.090280, perc_recon: 0.038596] time: 1:13:23.867920
# [Epoch 5248/10000] [D loss: 0.265086] [Adversarial_G_Loss: 1.837632, perc_recon: 0.059671] time: 1:13:24.701568
# [Epoch 5249/10000] [D loss: 0.280414] [Adversarial_G_Loss: 2.089728, perc_recon: 0.126363] time: 1:13:25.504565
# [Epoch 5250/10000] [D loss: 0.280474] [Adversarial_G_Loss: 2.048034, perc_recon: 0.075612] time: 1:13:26.281629
# [Epoch 5251/10000] [D loss: 0.252780] [Adversarial_G_Loss: 1.935193, perc_recon: 0.109923] time: 1:13:26.968435
# [Epoch 5252/10000] [D loss: 0.272309] [Adversarial_G_Loss: 1.715196, perc_recon: 0.109707] time: 1:13:27.823855
# [Epoch 5253/10000] [D loss: 0.289943] [Adversarial_G_Loss: 1.464313, perc_recon: 0.053874] time: 1:13:28.667832
# [Epoch 5254/10000] [D loss: 0.281685] [Adversarial_G_Loss: 1.811662, perc_recon: 0.102565] time: 1:13:29.529148
# [Epoch 5255/10000] [D loss: 0.265854] [Adversarial_G_Loss: 1.819268, perc_recon: 0.083805] time: 1:13:30.310250
# [Epoch 5256/10000] [D loss: 0.306196] [Adversarial_G_Loss: 1.440364, perc_recon: 0.050637] time: 1:13:31.159054
# [Epoch 5257/10000] [D loss: 0.474572] [Adversarial_G_Loss: 1.554594, perc_recon: 0.080477] time: 1:13:31.913671
# [Epoch 5258/10000] [D loss: 0.287858] [Adversarial_G_Loss: 1.657910, perc_recon: 0.053884] time: 1:13:32.744758
# [Epoch 5259/10000] [D loss: 0.303372] [Adversarial_G_Loss: 1.792570, perc_recon: 0.096187] time: 1:13:33.578230
# [Epoch 5260/10000] [D loss: 0.283846] [Adversarial_G_Loss: 1.924278, perc_recon: 0.068437] time: 1:13:34.351773
# [Epoch 5261/10000] [D loss: 0.293672] [Adversarial_G_Loss: 1.639491, perc_recon: 0.052621] time: 1:13:35.096483
# [Epoch 5262/10000] [D loss: 0.291040] [Adversarial_G_Loss: 1.722400, perc_recon: 0.058756] time: 1:13:35.947862
# [Epoch 5263/10000] [D loss: 0.230983] [Adversarial_G_Loss: 1.730938, perc_recon: 0.081267] time: 1:13:36.672952
# [Epoch 5264/10000] [D loss: 0.301708] [Adversarial_G_Loss: 1.605524, perc_recon: 0.053447] time: 1:13:37.502607
# [Epoch 5265/10000] [D loss: 0.270591] [Adversarial_G_Loss: 2.439143, perc_recon: 0.119503] time: 1:13:38.216768
# [Epoch 5266/10000] [D loss: 0.290873] [Adversarial_G_Loss: 2.019941, perc_recon: 0.069308] time: 1:13:39.003856
# [Epoch 5267/10000] [D loss: 0.310183] [Adversarial_G_Loss: 1.941907, perc_recon: 0.078067] time: 1:13:39.687024
# [Epoch 5268/10000] [D loss: 0.302431] [Adversarial_G_Loss: 2.361426, perc_recon: 0.188198] time: 1:13:40.479371
# [Epoch 5269/10000] [D loss: 0.291301] [Adversarial_G_Loss: 1.521854, perc_recon: 0.062758] time: 1:13:41.337592
# [Epoch 5270/10000] [D loss: 0.265471] [Adversarial_G_Loss: 2.139148, perc_recon: 0.118247] time: 1:13:42.120104
# [Epoch 5271/10000] [D loss: 0.317457] [Adversarial_G_Loss: 1.668615, perc_recon: 0.058258] time: 1:13:42.879738
# [Epoch 5272/10000] [D loss: 0.277447] [Adversarial_G_Loss: 2.104472, perc_recon: 0.078362] time: 1:13:43.594110
# [Epoch 5273/10000] [D loss: 0.287993] [Adversarial_G_Loss: 2.351957, perc_recon: 0.154531] time: 1:13:44.318848
# [Epoch 5274/10000] [D loss: 0.282256] [Adversarial_G_Loss: 1.781756, perc_recon: 0.094633] time: 1:13:45.107931
# [Epoch 5275/10000] [D loss: 0.326434] [Adversarial_G_Loss: 2.107787, perc_recon: 0.101252] time: 1:13:45.819925
# [Epoch 5276/10000] [D loss: 0.276626] [Adversarial_G_Loss: 1.847696, perc_recon: 0.076239] time: 1:13:46.612761
# [Epoch 5277/10000] [D loss: 0.320910] [Adversarial_G_Loss: 2.024361, perc_recon: 0.084813] time: 1:13:47.369437
# [Epoch 5278/10000] [D loss: 0.263475] [Adversarial_G_Loss: 1.224115, perc_recon: 0.050715] time: 1:13:48.215533
# [Epoch 5279/10000] [D loss: 0.285387] [Adversarial_G_Loss: 1.135853, perc_recon: 0.041312] time: 1:13:49.074495
# [Epoch 5280/10000] [D loss: 0.314145] [Adversarial_G_Loss: 1.453713, perc_recon: 0.053629] time: 1:13:49.839277
# [Epoch 5281/10000] [D loss: 0.226806] [Adversarial_G_Loss: 2.032256, perc_recon: 0.141457] time: 1:13:50.612129
# [Epoch 5282/10000] [D loss: 0.295015] [Adversarial_G_Loss: 1.552304, perc_recon: 0.065738] time: 1:13:51.392973
# [Epoch 5283/10000] [D loss: 0.319892] [Adversarial_G_Loss: 1.555061, perc_recon: 0.054220] time: 1:13:52.218158
# [Epoch 5284/10000] [D loss: 0.306244] [Adversarial_G_Loss: 1.821170, perc_recon: 0.116104] time: 1:13:52.898589
# [Epoch 5285/10000] [D loss: 0.286966] [Adversarial_G_Loss: 1.812275, perc_recon: 0.067473] time: 1:13:53.585907
# [Epoch 5286/10000] [D loss: 0.300386] [Adversarial_G_Loss: 1.266358, perc_recon: 0.068605] time: 1:13:54.430806
# [Epoch 5287/10000] [D loss: 0.282936] [Adversarial_G_Loss: 1.963003, perc_recon: 0.087624] time: 1:13:55.146324
# [Epoch 5288/10000] [D loss: 0.281914] [Adversarial_G_Loss: 1.772247, perc_recon: 0.064191] time: 1:13:55.911240
# [Epoch 5289/10000] [D loss: 0.289521] [Adversarial_G_Loss: 1.883229, perc_recon: 0.070160] time: 1:13:56.637169
# [Epoch 5290/10000] [D loss: 0.227708] [Adversarial_G_Loss: 1.626325, perc_recon: 0.088341] time: 1:13:57.429165
# [Epoch 5291/10000] [D loss: 0.264541] [Adversarial_G_Loss: 1.878081, perc_recon: 0.096581] time: 1:13:58.223222
# [Epoch 5292/10000] [D loss: 0.297108] [Adversarial_G_Loss: 1.859366, perc_recon: 0.067330] time: 1:13:58.906410
# [Epoch 5293/10000] [D loss: 0.269386] [Adversarial_G_Loss: 1.791673, perc_recon: 0.067078] time: 1:13:59.760345
# [Epoch 5294/10000] [D loss: 0.278391] [Adversarial_G_Loss: 1.849458, perc_recon: 0.066304] time: 1:14:00.521650
# [Epoch 5295/10000] [D loss: 0.227783] [Adversarial_G_Loss: 1.479080, perc_recon: 0.051497] time: 1:14:01.385322
# [Epoch 5296/10000] [D loss: 0.296005] [Adversarial_G_Loss: 1.982474, perc_recon: 0.106042] time: 1:14:02.081358
# [Epoch 5297/10000] [D loss: 0.300828] [Adversarial_G_Loss: 1.572923, perc_recon: 0.051939] time: 1:14:02.914883
# [Epoch 5298/10000] [D loss: 0.287236] [Adversarial_G_Loss: 1.658589, perc_recon: 0.060344] time: 1:14:03.705731
# [Epoch 5299/10000] [D loss: 0.287889] [Adversarial_G_Loss: 1.449543, perc_recon: 0.049421] time: 1:14:04.552915
# [Epoch 5300/10000] [D loss: 0.276306] [Adversarial_G_Loss: 1.518852, perc_recon: 0.054265] time: 1:14:05.263531
# [Epoch 5301/10000] [D loss: 0.285906] [Adversarial_G_Loss: 1.624334, perc_recon: 0.062243] time: 1:14:06.651374
# [Epoch 5302/10000] [D loss: 0.265690] [Adversarial_G_Loss: 1.981106, perc_recon: 0.082971] time: 1:14:07.299253
# [Epoch 5303/10000] [D loss: 0.266200] [Adversarial_G_Loss: 1.585887, perc_recon: 0.064091] time: 1:14:08.080901
# [Epoch 5304/10000] [D loss: 0.324403] [Adversarial_G_Loss: 1.540973, perc_recon: 0.103436] time: 1:14:08.851175
# [Epoch 5305/10000] [D loss: 0.271303] [Adversarial_G_Loss: 2.074296, perc_recon: 0.077515] time: 1:14:09.640329
# [Epoch 5306/10000] [D loss: 0.292207] [Adversarial_G_Loss: 1.966328, perc_recon: 0.069525] time: 1:14:10.361053
# [Epoch 5307/10000] [D loss: 0.261027] [Adversarial_G_Loss: 1.889462, perc_recon: 0.089247] time: 1:14:11.151718
# [Epoch 5308/10000] [D loss: 0.311363] [Adversarial_G_Loss: 1.431795, perc_recon: 0.056761] time: 1:14:12.010970
# [Epoch 5309/10000] [D loss: 0.283031] [Adversarial_G_Loss: 1.540926, perc_recon: 0.077707] time: 1:14:12.869846
# [Epoch 5310/10000] [D loss: 0.315983] [Adversarial_G_Loss: 1.868842, perc_recon: 0.084259] time: 1:14:13.558942
# [Epoch 5311/10000] [D loss: 0.271785] [Adversarial_G_Loss: 1.921796, perc_recon: 0.063034] time: 1:14:14.423738
# [Epoch 5312/10000] [D loss: 0.300626] [Adversarial_G_Loss: 1.520755, perc_recon: 0.045815] time: 1:14:15.278587
# [Epoch 5313/10000] [D loss: 0.283753] [Adversarial_G_Loss: 2.039539, perc_recon: 0.103075] time: 1:14:15.982802
# [Epoch 5314/10000] [D loss: 0.343935] [Adversarial_G_Loss: 1.585578, perc_recon: 0.079882] time: 1:14:16.667540
# [Epoch 5315/10000] [D loss: 0.272918] [Adversarial_G_Loss: 1.324694, perc_recon: 0.045809] time: 1:14:17.546337
# [Epoch 5316/10000] [D loss: 0.284087] [Adversarial_G_Loss: 1.758913, perc_recon: 0.069957] time: 1:14:18.225971
# [Epoch 5317/10000] [D loss: 0.266965] [Adversarial_G_Loss: 2.059704, perc_recon: 0.075887] time: 1:14:18.934141
# [Epoch 5318/10000] [D loss: 0.303339] [Adversarial_G_Loss: 1.294998, perc_recon: 0.047527] time: 1:14:19.687224
# [Epoch 5319/10000] [D loss: 0.261307] [Adversarial_G_Loss: 1.129070, perc_recon: 0.043737] time: 1:14:20.527477
# [Epoch 5320/10000] [D loss: 0.258809] [Adversarial_G_Loss: 1.443724, perc_recon: 0.064500] time: 1:14:21.311186
# [Epoch 5321/10000] [D loss: 0.282809] [Adversarial_G_Loss: 1.315332, perc_recon: 0.045058] time: 1:14:22.097354
# [Epoch 5322/10000] [D loss: 0.268549] [Adversarial_G_Loss: 1.473868, perc_recon: 0.042130] time: 1:14:22.949087
# [Epoch 5323/10000] [D loss: 0.324041] [Adversarial_G_Loss: 1.132774, perc_recon: 0.045920] time: 1:14:23.807125
# [Epoch 5324/10000] [D loss: 0.296719] [Adversarial_G_Loss: 1.965491, perc_recon: 0.068912] time: 1:14:24.525144
# [Epoch 5325/10000] [D loss: 0.265674] [Adversarial_G_Loss: 1.602712, perc_recon: 0.053243] time: 1:14:25.383160
# [Epoch 5326/10000] [D loss: 0.360610] [Adversarial_G_Loss: 1.776679, perc_recon: 0.066131] time: 1:14:26.070937
# [Epoch 5327/10000] [D loss: 0.264219] [Adversarial_G_Loss: 2.151821, perc_recon: 0.073249] time: 1:14:26.853083
# [Epoch 5328/10000] [D loss: 0.281952] [Adversarial_G_Loss: 1.811807, perc_recon: 0.077232] time: 1:14:27.505404
# [Epoch 5329/10000] [D loss: 0.257792] [Adversarial_G_Loss: 1.618723, perc_recon: 0.059469] time: 1:14:28.289464
# [Epoch 5330/10000] [D loss: 0.313950] [Adversarial_G_Loss: 1.848313, perc_recon: 0.092180] time: 1:14:29.006840
# [Epoch 5331/10000] [D loss: 0.276261] [Adversarial_G_Loss: 2.118757, perc_recon: 0.072287] time: 1:14:29.769297
# [Epoch 5332/10000] [D loss: 0.276298] [Adversarial_G_Loss: 1.966500, perc_recon: 0.094691] time: 1:14:30.558006
# [Epoch 5333/10000] [D loss: 0.280211] [Adversarial_G_Loss: 1.695286, perc_recon: 0.056307] time: 1:14:31.385323
# [Epoch 5334/10000] [D loss: 0.260403] [Adversarial_G_Loss: 1.398836, perc_recon: 0.045960] time: 1:14:32.246699
# [Epoch 5335/10000] [D loss: 0.301263] [Adversarial_G_Loss: 1.391892, perc_recon: 0.050946] time: 1:14:33.046646
# [Epoch 5336/10000] [D loss: 0.269997] [Adversarial_G_Loss: 1.963305, perc_recon: 0.064501] time: 1:14:33.768807
# [Epoch 5337/10000] [D loss: 0.259618] [Adversarial_G_Loss: 2.658875, perc_recon: 0.086482] time: 1:14:34.482800
# [Epoch 5338/10000] [D loss: 0.271863] [Adversarial_G_Loss: 1.499776, perc_recon: 0.052521] time: 1:14:35.232389
# [Epoch 5339/10000] [D loss: 0.267548] [Adversarial_G_Loss: 2.101435, perc_recon: 0.074861] time: 1:14:36.015220
# [Epoch 5340/10000] [D loss: 0.266458] [Adversarial_G_Loss: 1.571271, perc_recon: 0.058203] time: 1:14:36.787371
# [Epoch 5341/10000] [D loss: 0.249867] [Adversarial_G_Loss: 1.801766, perc_recon: 0.071323] time: 1:14:37.434478
# [Epoch 5342/10000] [D loss: 0.269380] [Adversarial_G_Loss: 1.581717, perc_recon: 0.086730] time: 1:14:38.273355
# [Epoch 5343/10000] [D loss: 0.296060] [Adversarial_G_Loss: 1.675025, perc_recon: 0.068666] time: 1:14:39.116134
# [Epoch 5344/10000] [D loss: 0.266059] [Adversarial_G_Loss: 1.457377, perc_recon: 0.048603] time: 1:14:39.899677
# [Epoch 5345/10000] [D loss: 0.285334] [Adversarial_G_Loss: 1.551255, perc_recon: 0.052586] time: 1:14:40.665715
# [Epoch 5346/10000] [D loss: 0.264917] [Adversarial_G_Loss: 1.408870, perc_recon: 0.049204] time: 1:14:41.511078
# [Epoch 5347/10000] [D loss: 0.286671] [Adversarial_G_Loss: 1.629961, perc_recon: 0.061366] time: 1:14:42.377783
# [Epoch 5348/10000] [D loss: 2.837904] [Adversarial_G_Loss: 3.927873, perc_recon: 0.366289] time: 1:14:43.164134
# [Epoch 5349/10000] [D loss: 0.473093] [Adversarial_G_Loss: 2.724281, perc_recon: 0.216276] time: 1:14:43.917549
# [Epoch 5350/10000] [D loss: 0.442162] [Adversarial_G_Loss: 3.162067, perc_recon: 0.233031] time: 1:14:44.627308
# [Epoch 5351/10000] [D loss: 0.403244] [Adversarial_G_Loss: 2.934677, perc_recon: 0.176869] time: 1:14:45.496654
# [Epoch 5352/10000] [D loss: 0.350423] [Adversarial_G_Loss: 2.027634, perc_recon: 0.147548] time: 1:14:46.328052
# [Epoch 5353/10000] [D loss: 0.310094] [Adversarial_G_Loss: 2.615468, perc_recon: 0.149853] time: 1:14:47.015412
# [Epoch 5354/10000] [D loss: 0.293548] [Adversarial_G_Loss: 1.809614, perc_recon: 0.138893] time: 1:14:47.856915
# [Epoch 5355/10000] [D loss: 0.243007] [Adversarial_G_Loss: 2.710533, perc_recon: 0.165198] time: 1:14:48.614628
# [Epoch 5356/10000] [D loss: 0.249835] [Adversarial_G_Loss: 1.881464, perc_recon: 0.166041] time: 1:14:49.447089
# [Epoch 5357/10000] [D loss: 0.377295] [Adversarial_G_Loss: 2.462249, perc_recon: 0.179694] time: 1:14:50.160624
# [Epoch 5358/10000] [D loss: 0.273168] [Adversarial_G_Loss: 2.238414, perc_recon: 0.153209] time: 1:14:50.914650
# ...
# [Epoch 9859/10000] [D loss: 0.260565] [Adversarial_G_Loss: 0.795796, perc_recon: 0.039852] time: 2:13:09.202376
# [Epoch 9860/10000] [D loss: 0.267769] [Adversarial_G_Loss: 1.085438, perc_recon: 0.031987] time: 2:13:09.983313
# [Epoch 9861/10000] [D loss: 0.258777] [Adversarial_G_Loss: 0.863889, perc_recon: 0.029104] time: 2:13:10.751397
# [Epoch 9862/10000] [D loss: 0.258355] [Adversarial_G_Loss: 0.816741, perc_recon: 0.026754] time: 2:13:11.528947
# [Epoch 9863/10000] [D loss: 0.255388] [Adversarial_G_Loss: 0.805654, perc_recon: 0.036098] time: 2:13:12.372118
# [Epoch 9864/10000] [D loss: 0.257809] [Adversarial_G_Loss: 1.071055, perc_recon: 0.035397] time: 2:13:13.131221
# [Epoch 9865/10000] [D loss: 0.252746] [Adversarial_G_Loss: 0.896779, perc_recon: 0.028299] time: 2:13:13.978408
# [Epoch 9866/10000] [D loss: 0.255914] [Adversarial_G_Loss: 0.903525, perc_recon: 0.030675] time: 2:13:14.759217
# [Epoch 9867/10000] [D loss: 0.267055] [Adversarial_G_Loss: 0.981314, perc_recon: 0.033935] time: 2:13:15.533108
# [Epoch 9868/10000] [D loss: 0.264401] [Adversarial_G_Loss: 1.447847, perc_recon: 0.068554] time: 2:13:16.252742
# [Epoch 9869/10000] [D loss: 0.267437] [Adversarial_G_Loss: 1.004843, perc_recon: 0.033730] time: 2:13:17.026968
# [Epoch 9870/10000] [D loss: 0.262349] [Adversarial_G_Loss: 1.215447, perc_recon: 0.044311] time: 2:13:17.733022
# [Epoch 9871/10000] [D loss: 0.266291] [Adversarial_G_Loss: 0.679323, perc_recon: 0.025876] time: 2:13:18.546248
# [Epoch 9872/10000] [D loss: 0.263494] [Adversarial_G_Loss: 1.175541, perc_recon: 0.091046] time: 2:13:19.325917
# [Epoch 9873/10000] [D loss: 0.277152] [Adversarial_G_Loss: 0.641784, perc_recon: 0.022289] time: 2:13:20.096749
# [Epoch 9874/10000] [D loss: 0.257522] [Adversarial_G_Loss: 0.707241, perc_recon: 0.025899] time: 2:13:20.846077
# [Epoch 9875/10000] [D loss: 0.257525] [Adversarial_G_Loss: 1.217210, perc_recon: 0.042625] time: 2:13:21.554644
# [Epoch 9876/10000] [D loss: 0.263332] [Adversarial_G_Loss: 0.677953, perc_recon: 0.024251] time: 2:13:22.284988
# [Epoch 9877/10000] [D loss: 0.276044] [Adversarial_G_Loss: 0.907782, perc_recon: 0.030705] time: 2:13:22.962063
# [Epoch 9878/10000] [D loss: 0.260827] [Adversarial_G_Loss: 1.051165, perc_recon: 0.036747] time: 2:13:23.638579
# [Epoch 9879/10000] [D loss: 0.257647] [Adversarial_G_Loss: 0.864705, perc_recon: 0.028833] time: 2:13:24.415099
# [Epoch 9880/10000] [D loss: 0.255220] [Adversarial_G_Loss: 0.655376, perc_recon: 0.024085] time: 2:13:25.246639
# [Epoch 9881/10000] [D loss: 0.252254] [Adversarial_G_Loss: 0.661852, perc_recon: 0.022192] time: 2:13:26.078532
# [Epoch 9882/10000] [D loss: 0.254049] [Adversarial_G_Loss: 0.795471, perc_recon: 0.027463] time: 2:13:26.832339
# [Epoch 9883/10000] [D loss: 0.251887] [Adversarial_G_Loss: 0.882681, perc_recon: 0.036979] time: 2:13:27.604040
# [Epoch 9884/10000] [D loss: 0.254630] [Adversarial_G_Loss: 0.954739, perc_recon: 0.033995] time: 2:13:28.376300
# [Epoch 9885/10000] [D loss: 0.251584] [Adversarial_G_Loss: 1.224477, perc_recon: 0.042571] time: 2:13:29.142717
# [Epoch 9886/10000] [D loss: 0.256997] [Adversarial_G_Loss: 0.929505, perc_recon: 0.032000] time: 2:13:29.916116
# [Epoch 9887/10000] [D loss: 0.254359] [Adversarial_G_Loss: 0.715775, perc_recon: 0.025028] time: 2:13:30.753295
# [Epoch 9888/10000] [D loss: 0.252376] [Adversarial_G_Loss: 0.764739, perc_recon: 0.030493] time: 2:13:31.585791
# [Epoch 9889/10000] [D loss: 0.253553] [Adversarial_G_Loss: 0.971706, perc_recon: 0.032594] time: 2:13:32.377984
# [Epoch 9890/10000] [D loss: 0.266226] [Adversarial_G_Loss: 1.332542, perc_recon: 0.053438] time: 2:13:33.054429
# [Epoch 9891/10000] [D loss: 0.263538] [Adversarial_G_Loss: 0.746397, perc_recon: 0.033628] time: 2:13:33.894314
# [Epoch 9892/10000] [D loss: 0.261805] [Adversarial_G_Loss: 0.969708, perc_recon: 0.040015] time: 2:13:34.637720
# [Epoch 9893/10000] [D loss: 0.253678] [Adversarial_G_Loss: 1.012419, perc_recon: 0.050955] time: 2:13:35.413622
# [Epoch 9894/10000] [D loss: 0.254234] [Adversarial_G_Loss: 1.177950, perc_recon: 0.039412] time: 2:13:36.095849
# [Epoch 9895/10000] [D loss: 0.254555] [Adversarial_G_Loss: 0.967671, perc_recon: 0.033353] time: 2:13:36.906888
# [Epoch 9896/10000] [D loss: 0.254907] [Adversarial_G_Loss: 1.093256, perc_recon: 0.038331] time: 2:13:37.626144
# [Epoch 9897/10000] [D loss: 0.264784] [Adversarial_G_Loss: 0.966991, perc_recon: 0.032393] time: 2:13:38.374251
# [Epoch 9898/10000] [D loss: 0.253994] [Adversarial_G_Loss: 0.769298, perc_recon: 0.028340] time: 2:13:39.146820
# [Epoch 9899/10000] [D loss: 0.252585] [Adversarial_G_Loss: 0.917597, perc_recon: 0.034953] time: 2:13:39.930685
# [Epoch 9900/10000] [D loss: 0.259075] [Adversarial_G_Loss: 0.955035, perc_recon: 0.031039] time: 2:13:40.674539
# [Epoch 9901/10000] [D loss: 0.253973] [Adversarial_G_Loss: 0.955791, perc_recon: 0.036444] time: 2:13:42.153075
# [Epoch 9902/10000] [D loss: 0.253956] [Adversarial_G_Loss: 1.097545, perc_recon: 0.037560] time: 2:13:42.933377
# [Epoch 9903/10000] [D loss: 0.255574] [Adversarial_G_Loss: 1.146306, perc_recon: 0.038490] time: 2:13:43.715297
# [Epoch 9904/10000] [D loss: 0.259076] [Adversarial_G_Loss: 0.736369, perc_recon: 0.024684] time: 2:13:44.502451
# [Epoch 9905/10000] [D loss: 0.254166] [Adversarial_G_Loss: 1.006172, perc_recon: 0.035015] time: 2:13:45.243069
# [Epoch 9906/10000] [D loss: 0.256992] [Adversarial_G_Loss: 0.894035, perc_recon: 0.031851] time: 2:13:46.102698
# [Epoch 9907/10000] [D loss: 0.264691] [Adversarial_G_Loss: 0.992381, perc_recon: 0.036415] time: 2:13:46.874994
# [Epoch 9908/10000] [D loss: 0.259161] [Adversarial_G_Loss: 1.022899, perc_recon: 0.052862] time: 2:13:47.631131
# [Epoch 9909/10000] [D loss: 0.256510] [Adversarial_G_Loss: 1.104432, perc_recon: 0.042573] time: 2:13:48.301824
# [Epoch 9910/10000] [D loss: 0.254285] [Adversarial_G_Loss: 0.823649, perc_recon: 0.032151] time: 2:13:49.082565
# [Epoch 9911/10000] [D loss: 0.272437] [Adversarial_G_Loss: 1.210869, perc_recon: 0.039381] time: 2:13:49.799339
# [Epoch 9912/10000] [D loss: 0.253987] [Adversarial_G_Loss: 0.912649, perc_recon: 0.028770] time: 2:13:50.634881
# [Epoch 9913/10000] [D loss: 0.259459] [Adversarial_G_Loss: 0.936634, perc_recon: 0.031110] time: 2:13:51.363412
# [Epoch 9914/10000] [D loss: 0.258185] [Adversarial_G_Loss: 0.852073, perc_recon: 0.029857] time: 2:13:52.178058
# [Epoch 9915/10000] [D loss: 0.255957] [Adversarial_G_Loss: 0.651456, perc_recon: 0.039503] time: 2:13:53.015605
# [Epoch 9916/10000] [D loss: 0.254937] [Adversarial_G_Loss: 0.637980, perc_recon: 0.021799] time: 2:13:53.862941
# [Epoch 9917/10000] [D loss: 0.259310] [Adversarial_G_Loss: 1.012866, perc_recon: 0.035684] time: 2:13:54.646479
# [Epoch 9918/10000] [D loss: 0.259471] [Adversarial_G_Loss: 0.998847, perc_recon: 0.031840] time: 2:13:55.435915
# [Epoch 9919/10000] [D loss: 0.255494] [Adversarial_G_Loss: 0.840671, perc_recon: 0.028534] time: 2:13:56.208728
# [Epoch 9920/10000] [D loss: 0.254630] [Adversarial_G_Loss: 0.893471, perc_recon: 0.039659] time: 2:13:56.977898
# [Epoch 9921/10000] [D loss: 0.252418] [Adversarial_G_Loss: 1.042868, perc_recon: 0.035332] time: 2:13:57.751072
# [Epoch 9922/10000] [D loss: 0.254857] [Adversarial_G_Loss: 0.809422, perc_recon: 0.027363] time: 2:13:58.491890
# [Epoch 9923/10000] [D loss: 0.254938] [Adversarial_G_Loss: 0.690111, perc_recon: 0.023828] time: 2:13:59.324756
# [Epoch 9924/10000] [D loss: 0.256987] [Adversarial_G_Loss: 0.786551, perc_recon: 0.027024] time: 2:14:00.171083
# [Epoch 9925/10000] [D loss: 0.253066] [Adversarial_G_Loss: 0.741476, perc_recon: 0.025253] time: 2:14:00.991974
# [Epoch 9926/10000] [D loss: 0.254293] [Adversarial_G_Loss: 0.718215, perc_recon: 0.024297] time: 2:14:01.808284
# [Epoch 9927/10000] [D loss: 0.254061] [Adversarial_G_Loss: 0.538429, perc_recon: 0.018108] time: 2:14:02.627034
# [Epoch 9928/10000] [D loss: 0.268797] [Adversarial_G_Loss: 0.727259, perc_recon: 0.024527] time: 2:14:03.401947
# [Epoch 9929/10000] [D loss: 0.286200] [Adversarial_G_Loss: 0.979629, perc_recon: 0.028321] time: 2:14:04.164805
# [Epoch 9930/10000] [D loss: 0.260157] [Adversarial_G_Loss: 1.028323, perc_recon: 0.032578] time: 2:14:04.941194
# [Epoch 9931/10000] [D loss: 0.261475] [Adversarial_G_Loss: 0.879475, perc_recon: 0.044961] time: 2:14:05.790541
# [Epoch 9932/10000] [D loss: 0.262721] [Adversarial_G_Loss: 1.577959, perc_recon: 0.053349] time: 2:14:06.465345
# [Epoch 9933/10000] [D loss: 0.253769] [Adversarial_G_Loss: 0.907745, perc_recon: 0.036325] time: 2:14:07.320635
# [Epoch 9934/10000] [D loss: 0.252625] [Adversarial_G_Loss: 1.166947, perc_recon: 0.039861] time: 2:14:08.097406
# [Epoch 9935/10000] [D loss: 0.255023] [Adversarial_G_Loss: 1.051387, perc_recon: 0.035296] time: 2:14:08.936388
# [Epoch 9936/10000] [D loss: 0.253430] [Adversarial_G_Loss: 1.187244, perc_recon: 0.039445] time: 2:14:09.677484
# [Epoch 9937/10000] [D loss: 0.283087] [Adversarial_G_Loss: 0.851844, perc_recon: 0.028984] time: 2:14:10.387248
# [Epoch 9938/10000] [D loss: 0.259644] [Adversarial_G_Loss: 1.694219, perc_recon: 0.063145] time: 2:14:11.168296
# [Epoch 9939/10000] [D loss: 0.256932] [Adversarial_G_Loss: 0.832570, perc_recon: 0.032914] time: 2:14:12.017124
# [Epoch 9940/10000] [D loss: 0.261026] [Adversarial_G_Loss: 0.895759, perc_recon: 0.034358] time: 2:14:12.756236
# [Epoch 9941/10000] [D loss: 0.252165] [Adversarial_G_Loss: 0.820162, perc_recon: 0.027921] time: 2:14:13.515344
# [Epoch 9942/10000] [D loss: 0.254285] [Adversarial_G_Loss: 0.816121, perc_recon: 0.030961] time: 2:14:14.275488
# [Epoch 9943/10000] [D loss: 0.260271] [Adversarial_G_Loss: 0.817867, perc_recon: 0.026559] time: 2:14:14.996584
# [Epoch 9944/10000] [D loss: 0.256637] [Adversarial_G_Loss: 0.938971, perc_recon: 0.030801] time: 2:14:15.763108
# [Epoch 9945/10000] [D loss: 0.252840] [Adversarial_G_Loss: 0.832545, perc_recon: 0.029898] time: 2:14:16.611961
# [Epoch 9946/10000] [D loss: 0.254501] [Adversarial_G_Loss: 1.537350, perc_recon: 0.048362] time: 2:14:17.327836
# [Epoch 9947/10000] [D loss: 0.254650] [Adversarial_G_Loss: 0.943103, perc_recon: 0.030042] time: 2:14:18.104754
# [Epoch 9948/10000] [D loss: 0.254435] [Adversarial_G_Loss: 1.071144, perc_recon: 0.032817] time: 2:14:18.885224
# [Epoch 9949/10000] [D loss: 0.253805] [Adversarial_G_Loss: 0.826138, perc_recon: 0.027809] time: 2:14:19.719349
# [Epoch 9950/10000] [D loss: 0.253451] [Adversarial_G_Loss: 1.054869, perc_recon: 0.043520] time: 2:14:20.458241
# [Epoch 9951/10000] [D loss: 0.260615] [Adversarial_G_Loss: 1.234231, perc_recon: 0.040372] time: 2:14:21.234653
# [Epoch 9952/10000] [D loss: 0.256051] [Adversarial_G_Loss: 1.015569, perc_recon: 0.034871] time: 2:14:21.984185
# [Epoch 9953/10000] [D loss: 0.253107] [Adversarial_G_Loss: 0.640832, perc_recon: 0.023964] time: 2:14:22.798054
# [Epoch 9954/10000] [D loss: 0.254281] [Adversarial_G_Loss: 0.731122, perc_recon: 0.026055] time: 2:14:23.641776
# [Epoch 9955/10000] [D loss: 0.254325] [Adversarial_G_Loss: 1.180406, perc_recon: 0.039999] time: 2:14:24.352916
# [Epoch 9956/10000] [D loss: 0.260646] [Adversarial_G_Loss: 1.183249, perc_recon: 0.039992] time: 2:14:25.063257
# [Epoch 9957/10000] [D loss: 0.259926] [Adversarial_G_Loss: 0.865186, perc_recon: 0.033461] time: 2:14:25.850177
# [Epoch 9958/10000] [D loss: 0.260198] [Adversarial_G_Loss: 0.868497, perc_recon: 0.029159] time: 2:14:26.625277
# [Epoch 9959/10000] [D loss: 0.253345] [Adversarial_G_Loss: 0.810180, perc_recon: 0.028012] time: 2:14:27.460550
# [Epoch 9960/10000] [D loss: 0.253142] [Adversarial_G_Loss: 1.183921, perc_recon: 0.040027] time: 2:14:28.177772
# [Epoch 9961/10000] [D loss: 0.256556] [Adversarial_G_Loss: 1.068258, perc_recon: 0.039978] time: 2:14:28.884215
# [Epoch 9962/10000] [D loss: 0.270036] [Adversarial_G_Loss: 1.378012, perc_recon: 0.050649] time: 2:14:29.556251
# [Epoch 9963/10000] [D loss: 0.256574] [Adversarial_G_Loss: 0.998741, perc_recon: 0.033598] time: 2:14:30.392962
# [Epoch 9964/10000] [D loss: 0.261145] [Adversarial_G_Loss: 0.988414, perc_recon: 0.035348] time: 2:14:31.177409
# [Epoch 9965/10000] [D loss: 0.258317] [Adversarial_G_Loss: 0.747417, perc_recon: 0.032805] time: 2:14:32.019008
# [Epoch 9966/10000] [D loss: 0.268424] [Adversarial_G_Loss: 1.124678, perc_recon: 0.036092] time: 2:14:32.798487
# [Epoch 9967/10000] [D loss: 0.271103] [Adversarial_G_Loss: 1.295570, perc_recon: 0.050921] time: 2:14:33.504784
# [Epoch 9968/10000] [D loss: 0.271228] [Adversarial_G_Loss: 0.825963, perc_recon: 0.030219] time: 2:14:34.233672
# [Epoch 9969/10000] [D loss: 0.264242] [Adversarial_G_Loss: 0.806718, perc_recon: 0.029908] time: 2:14:35.006573
# [Epoch 9970/10000] [D loss: 0.261825] [Adversarial_G_Loss: 1.020560, perc_recon: 0.038218] time: 2:14:35.713311
# [Epoch 9971/10000] [D loss: 0.258429] [Adversarial_G_Loss: 1.325175, perc_recon: 0.044369] time: 2:14:36.356682
# [Epoch 9972/10000] [D loss: 0.257903] [Adversarial_G_Loss: 0.984417, perc_recon: 0.050921] time: 2:14:37.135976
# [Epoch 9973/10000] [D loss: 0.254655] [Adversarial_G_Loss: 1.016582, perc_recon: 0.031925] time: 2:14:37.888000
# [Epoch 9974/10000] [D loss: 0.272722] [Adversarial_G_Loss: 1.047297, perc_recon: 0.034075] time: 2:14:38.646970
# [Epoch 9975/10000] [D loss: 0.265804] [Adversarial_G_Loss: 1.286305, perc_recon: 0.046747] time: 2:14:39.325028
# [Epoch 9976/10000] [D loss: 0.254306] [Adversarial_G_Loss: 0.871832, perc_recon: 0.030955] time: 2:14:40.165956
# [Epoch 9977/10000] [D loss: 0.263832] [Adversarial_G_Loss: 1.140485, perc_recon: 0.042937] time: 2:14:40.871226
# [Epoch 9978/10000] [D loss: 0.255775] [Adversarial_G_Loss: 0.965139, perc_recon: 0.036779] time: 2:14:41.641178
# [Epoch 9979/10000] [D loss: 0.268729] [Adversarial_G_Loss: 0.893798, perc_recon: 0.030719] time: 2:14:42.420243
# [Epoch 9980/10000] [D loss: 0.259662] [Adversarial_G_Loss: 0.772702, perc_recon: 0.026083] time: 2:14:43.247628
# [Epoch 9981/10000] [D loss: 0.253598] [Adversarial_G_Loss: 1.263773, perc_recon: 0.048425] time: 2:14:43.959395
# [Epoch 9982/10000] [D loss: 0.252374] [Adversarial_G_Loss: 1.074935, perc_recon: 0.038104] time: 2:14:44.724779
# [Epoch 9983/10000] [D loss: 0.268524] [Adversarial_G_Loss: 1.240681, perc_recon: 0.047186] time: 2:14:45.503865
# [Epoch 9984/10000] [D loss: 0.253499] [Adversarial_G_Loss: 1.191953, perc_recon: 0.041466] time: 2:14:46.360739
# [Epoch 9985/10000] [D loss: 0.262170] [Adversarial_G_Loss: 1.285042, perc_recon: 0.052671] time: 2:14:47.027367
# [Epoch 9986/10000] [D loss: 0.261043] [Adversarial_G_Loss: 1.429004, perc_recon: 0.048597] time: 2:14:47.724563
# [Epoch 9987/10000] [D loss: 0.255781] [Adversarial_G_Loss: 1.101184, perc_recon: 0.041679] time: 2:14:48.441108
# [Epoch 9988/10000] [D loss: 0.255793] [Adversarial_G_Loss: 1.097290, perc_recon: 0.037668] time: 2:14:49.207196
# [Epoch 9989/10000] [D loss: 0.268929] [Adversarial_G_Loss: 1.746405, perc_recon: 0.065027] time: 2:14:49.915790
# [Epoch 9990/10000] [D loss: 0.260127] [Adversarial_G_Loss: 1.296159, perc_recon: 0.057157] time: 2:14:50.689729
# [Epoch 9991/10000] [D loss: 0.263756] [Adversarial_G_Loss: 1.199844, perc_recon: 0.041173] time: 2:14:51.334161
# [Epoch 9992/10000] [D loss: 0.257193] [Adversarial_G_Loss: 1.243349, perc_recon: 0.042755] time: 2:14:52.045798
# [Epoch 9993/10000] [D loss: 0.264892] [Adversarial_G_Loss: 0.926679, perc_recon: 0.040082] time: 2:14:52.882872
# [Epoch 9994/10000] [D loss: 0.255503] [Adversarial_G_Loss: 1.324344, perc_recon: 0.045581] time: 2:14:53.669118
# [Epoch 9995/10000] [D loss: 0.254183] [Adversarial_G_Loss: 0.784844, perc_recon: 0.026942] time: 2:14:54.556147
# [Epoch 9996/10000] [D loss: 0.252307] [Adversarial_G_Loss: 0.742710, perc_recon: 0.026212] time: 2:14:55.318654
# [Epoch 9997/10000] [D loss: 0.256447] [Adversarial_G_Loss: 0.778240, perc_recon: 0.030779] time: 2:14:56.096650
# [Epoch 9998/10000] [D loss: 0.252545] [Adversarial_G_Loss: 0.997030, perc_recon: 0.034378] time: 2:14:56.873200
# [Epoch 9999/10000] [D loss: 0.259629] [Adversarial_G_Loss: 0.857078, perc_recon: 0.030505] time: 2:14:57.580223
# [Epoch 10000/10000] [D loss: 0.259117] [Adversarial_G_Loss: 0.832228, perc_recon: 0.029978] time: 2:14:58.395764
