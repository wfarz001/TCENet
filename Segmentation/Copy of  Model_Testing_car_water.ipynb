# %%
# !pip uninstall tensorflow 
# !pip install tensorflow-gpu==1.14
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
# Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220719082949.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.14
#   Downloading tensorflow_gpu-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (377.1 MB)
#      |████████████████████████████████| 377.1 MB 8.0 kB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (3.17.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 69.4 MB/s
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.21.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (0.5.3)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.1 MB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 73.8 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.14.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.47.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14) (0.37.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (3.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.4.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (4.1.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow-gpu==1.14) (1.5.2)
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
# !pip uninstall keras 
# !pip install keras==2.2.4
# Out:
# Found existing installation: keras 2.8.0
# Uninstalling keras-2.8.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/keras-2.8.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/keras/*
# Proceed (y/n)? y
#   Successfully uninstalled keras-2.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras==2.2.4
#   Downloading Keras-2.2.4-py2.py3-none-any.whl (312 kB)
#      |████████████████████████████████| 312 kB 14.2 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.21.6)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.7.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.2.4) (1.5.2)
# Installing collected packages: keras
# Successfully installed keras-2.2.4

# %%
pip install h5py==2.10.0 --force-reinstall #need to install h5 ,otherwise it won't load the model properly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 13.8 MB/s
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting numpy>=1.7
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 63.2 MB/s
# Installing collected packages: six, numpy, h5py
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires tensorflow>=2.0.0, which is not installed.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed h5py-2.10.0 numpy-1.21.6 six-1.16.0

# %%
#!pip install h5py==2.10.0 --force-reinstall #need to install h5 ,otherwise it won't load the model properly

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/Flood_Project/Image_Stylization/instancenormalization.py /content

# %%
from instancenormalization import InstanceNormalization  
from keras.models import load_model
from matplotlib import pyplot
from numpy.random import randint
from os import listdir
from numpy import asarray
from numpy import vstack
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from matplotlib import pyplot as plt
import numpy as np
import h5py
from matplotlib.pyplot import figure

# %%
# load all images in a directory into memory
def load_images(path, size=(256,256)):
	data_list = list()
	# enumerate filenames in directory, assume all are images
	for filename in listdir(path):
		# load and resize the image
		pixels = load_img(path + filename, target_size=size)
		# convert to numpy array
		pixels = img_to_array(pixels)
		# store
		data_list.append(pixels)
	return asarray(data_list)

# %%
# dataset path
path = '/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/'

# %%
# load dataset A - Real Images
dataA_all = load_images(path + 'trainA/')
print('Loaded dataA: ', dataA_all.shape)

from sklearn.utils import resample
#To get a subset of all images, for faster training during demonstration
dataA = resample(dataA_all, 
                 replace=False,     
                 n_samples=100,    
                 random_state=42) 

# load dataset B - Synhetic Images
dataB_all = load_images(path + 'trainB/')
print('Loaded dataB: ', dataB_all.shape)
#Get a subset of all images, for faster training during demonstration
#We could have just read the list of files and only load a subset, better memory management. 
dataB = resample(dataB_all, 
                 replace=False,     
                 n_samples=100,    
                 random_state=42)
# Out:
# Loaded dataA:  (1747, 256, 256, 3)
# Loaded dataB:  (1466, 256, 256, 3)

# %%
# select a random sample of images from the dataset
def select_sample(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# retrieve selected images
	X = dataset[ix]
	return X

# %%
# plot the image, its translation, and the reconstruction
def show_plot(imagesX, imagesY1, imagesY2):
	images = vstack((imagesX, imagesY1, imagesY2))
	titles = ['Original (Synthetic)', 'Model Translated (Syn>Real)', 'Model Reconstructed(back to Synthetic)']
	# scale from [-1,1] to [0,1]
	images = (images + 1) / 2.0
	# plot images row by row
	for i in range(len(images)):
		figure(figsize=(20, 15), dpi=80)
		# define subplot
		pyplot.subplot(1, len(images) ,1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(images[i])
		# title
		pyplot.title(titles[i])
	pyplot.show()

# %%
# load dataset
A_data = resample(dataA_all, 
                 replace=False,     
                 n_samples=50,    
                 random_state=42) # reproducible results

B_data = resample(dataB_all, 
                 replace=False,     
                 n_samples=50,    
                 random_state=42) # reproducible results

A_data = (A_data - 127.5) / 127.5
B_data = (B_data - 127.5) / 127.5

# %%
# load the models
cust = {'InstanceNormalization': InstanceNormalization}
model_BtoA = load_model('/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/logs_car_water_August_28(real_551)/gen_ba_v2_4200.h5', cust)
model_AtoB = load_model('/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/logs_car_water_August_28(real_551)/gen_ab_v2_4200.h5', cust)

# %%
# plot B->A->B (Synthetic to Real to Synthetic)
B_real = select_sample(B_data, 1)
print(B_real.shape)
A_generated  = model_BtoA.predict(B_real)
B_reconstructed = model_AtoB.predict(A_generated)
show_plot(B_real, A_generated, B_reconstructed)
# Out:
# (1, 256, 256, 3)

# %%
# plot A->B->A (Real to Synthetic to Real)
A_real = select_sample(A_data, 1)
B_generated  = model_AtoB.predict(A_real)
A_reconstructed = model_BtoA.predict(B_generated)
show_plot(A_real, B_generated, A_reconstructed)

# %% [markdown]
# #Saving generated image in a folder########

# %%
#test_img_path="/content/gdrive/MyDrive/Flood_Project/Image_Stylization/test/" #synthetic test image path
#out_path="/content/gdrive/MyDrive/Flood_Project/Image_Stylization/test_output" #generated synthetic>real

# %%
test_img_path="/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/trainB/" #synthetic test image path
out_path="/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)" #generated synthetic>real

# %%
import os
from PIL import Image 
import cv2
import numpy
size=(256,256)
for file in os.listdir(test_img_path):
  print(file)
  filename=file.split('.')[0]
  pixels=load_img(test_img_path+ file, target_size=size)
  img_arr= img_to_array(pixels)
  img_arr=np.expand_dims(img_arr,axis=0)
  #print(img_arr.shape)
  generated_img  = model_BtoA.predict(img_arr) #synthectic to real translation
  #generated_img  = (generated_img + 1) / 2.0
  generated_img= np.array(generated_img)
  #print(generated_img.shape)
  out_img=np.squeeze(generated_img,axis=0)
  fn=f'{out_path}/{filename}.png'
  result = Image.fromarray((out_img * 255).astype(numpy.uint8))
  result.save(fn)
  #plt.savefig(out_path+filename+'.png') 
  print(fn)
  #fn=f'{out_path}/{filename}.png'
  #cv2.imwrite(fn,out_img)
# Out:
# 0709000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0709000.png
# 0710001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0710001.png
# 0708004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708004.png
# 0709004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0709004.png
# 0710000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0710000.png
# 0713001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0713001.png
# 0710006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0710006.png
# 0711003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0711003.png
# 0711006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0711006.png
# 0713000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0713000.png
# 0712001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0712001.png
# 0710007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0710007.png
# 0711007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0711007.png
# 0712007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0712007.png
# 0711000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0711000.png
# 0712006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0712006.png
# 0712004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0712004.png
# 0711004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0711004.png
# 0711001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0711001.png
# 0710004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0710004.png
# 0712003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0712003.png
# 0712000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0712000.png
# 0715000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0715000.png
# 0713006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0713006.png
# 0714003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0714003.png
# 0715004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0715004.png
# 0715003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0715003.png
# 0713007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0713007.png
# 0713004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0713004.png
# 0714007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0714007.png
# 0716000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0716000.png
# 0713003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0713003.png
# 0714006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0714006.png
# 0714004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0714004.png
# 0715001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0715001.png
# 0715006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0715006.png
# 0714000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0714000.png
# 0715007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0715007.png
# 0714001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0714001.png
# 0718000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0718000.png
# 0718007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0718007.png
# 0717007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0717007.png
# 0716006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0716006.png
# 0716003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0716003.png
# 0717006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0717006.png
# 0717000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0717000.png
# 0718004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0718004.png
# 0718001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0718001.png
# 0716007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0716007.png
# 0716001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0716001.png
# 0717004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0717004.png
# 0717001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0717001.png
# 0718006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0718006.png
# 0718003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0718003.png
# 0717003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0717003.png
# 0716004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0716004.png
# 0720000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0720000.png
# 0719006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0719006.png
# 0720001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0720001.png
# 0719000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0719000.png
# 0719004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0719004.png
# 0719003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0719003.png
# 0719001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0719001.png
# 0719007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0719007.png
# 0722003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0722003.png
# 0722007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0722007.png
# 0723004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0723004.png
# 0723001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0723001.png
# 0723007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0723007.png
# 0723000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0723000.png
# 0722006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0722006.png
# 0722004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0722004.png
# 0724000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0724000.png
# 0724001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0724001.png
# 0724003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0724003.png
# 0723006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0723006.png
# 0723003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0723003.png
# 0727000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0727000.png
# 0725000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0725000.png
# 0724004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0724004.png
# 0726003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0726003.png
# 0726000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0726000.png
# 0725007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0725007.png
# 0725004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0725004.png
# 0725003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0725003.png
# 0725006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0725006.png
# 0726007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0726007.png
# 0724007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0724007.png
# 0727001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0727001.png
# 0726006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0726006.png
# 0724006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0724006.png
# 0725001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0725001.png
# 0726004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0726004.png
# 0726001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0726001.png
# 0729003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0729003.png
# 0729004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0729004.png
# 0728000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0728000.png
# 0730000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0730000.png
# 0727003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0727003.png
# 0728006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0728006.png
# 0729000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0729000.png
# 0728007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0728007.png
# 0727006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0727006.png
# 0727007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0727007.png
# 0728003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0728003.png
# 0728004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0728004.png
# 0727004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0727004.png
# 0729007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0729007.png
# 0728001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0728001.png
# 0729006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0729006.png
# 0729001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0729001.png
# 0732001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0732001.png
# 0732003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0732003.png
# 0730007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0730007.png
# 0732004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0732004.png
# 0730004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0730004.png
# 0732006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0732006.png
# 0732000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0732000.png
# 0731006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0731006.png
# 0731007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0731007.png
# 0730001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0730001.png
# 0730003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0730003.png
# 0731000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0731000.png
# 0731004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0731004.png
# 0731003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0731003.png
# 0730006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0730006.png
# 0731001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0731001.png
# 0733006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0733006.png
# 0733003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0733003.png
# 0733007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0733007.png
# 0733000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0733000.png
# 0734003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0734003.png
# 0734007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0734007.png
# 0732007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0732007.png
# 0733004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0733004.png
# 0734000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0734000.png
# 0734006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0734006.png
# 0735000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0735000.png
# 0734001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0734001.png
# 0733001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0733001.png
# 0734004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0734004.png
# 0735001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0735001.png
# 0738000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0738000.png
# 0737006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0737006.png
# 0737003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0737003.png
# 0735003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0735003.png
# 0735004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0735004.png
# 0736006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0736006.png
# 0736001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0736001.png
# 0736003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0736003.png
# 0737007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0737007.png
# 0735007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0735007.png
# 0736004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0736004.png
# 0735006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0735006.png
# 0736000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0736000.png
# 0737000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0737000.png
# 0737001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0737001.png
# 0737004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0737004.png
# 0736007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0736007.png
# 0738003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0738003.png
# 0739003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0739003.png
# 0740000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0740000.png
# 0740003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0740003.png
# 0739001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0739001.png
# 0738001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0738001.png
# 0739000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0739000.png
# 0739007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0739007.png
# 0740001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0740001.png
# 0739006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0739006.png
# 0738007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0738007.png
# 0740006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0740006.png
# 0740004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0740004.png
# 0739004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0739004.png
# 0738004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0738004.png
# 0738006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0738006.png
# 0742000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0742000.png
# 0741003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0741003.png
# 0741000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0741000.png
# 0742004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0742004.png
# 0742007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0742007.png
# 0741007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0741007.png
# 0743004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0743004.png
# 0742006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0742006.png
# 0743000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0743000.png
# 0741001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0741001.png
# 0743003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0743003.png
# 0741006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0741006.png
# 0743001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0743001.png
# 0742001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0742001.png
# 0740007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0740007.png
# 0741004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0741004.png
# 0742003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0742003.png
# 0743006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0743006.png
# 0744006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0744006.png
# 0744004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0744004.png
# 0743007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0743007.png
# 0745001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0745001.png
# 0745007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0745007.png
# 0744007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0744007.png
# 0744000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0744000.png
# 0744003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0744003.png
# 0745006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0745006.png
# 0745000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0745000.png
# 0744001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0744001.png
# 0745004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0745004.png
# 0747001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0747001.png
# 0746000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0746000.png
# 0748006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0748006.png
# 0748004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0748004.png
# 0746003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0746003.png
# 0747007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0747007.png
# 0747004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0747004.png
# 0748001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0748001.png
# 0747006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0747006.png
# 0747003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0747003.png
# 0747000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0747000.png
# 0746006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0746006.png
# 0748003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0748003.png
# 0746001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0746001.png
# 0746007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0746007.png
# 0748000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0748000.png
# 0746004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0746004.png
# 0749001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0749001.png
# 0750003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0750003.png
# 0749004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0749004.png
# 0750001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0750001.png
# 0749007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0749007.png
# 0750004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0750004.png
# 0749003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0749003.png
# 0750007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0750007.png
# 0751000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0751000.png
# 0751001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0751001.png
# 0751004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0751004.png
# 0751003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0751003.png
# 0749006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0749006.png
# 0748007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0748007.png
# 0749000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0749000.png
# 0750000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0750000.png
# 0754001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0754001.png
# 0753004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0753004.png
# 0752001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0752001.png
# 0753001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0753001.png
# 0753007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0753007.png
# 0753000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0753000.png
# 0752004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0752004.png
# 0752000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0752000.png
# 0752003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0752003.png
# 0752007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0752007.png
# 0753003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0753003.png
# 0751007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0751007.png
# 0754000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0754000.png
# 0755004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0755004.png
# 0756000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0756000.png
# 0754004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0754004.png
# 0756003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0756003.png
# 0756001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0756001.png
# 0755001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0755001.png
# 0755003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0755003.png
# 0755007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0755007.png
# 0756004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0756004.png
# 0755000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0755000.png
# 0754007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0754007.png
# 0757004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0757004.png
# 0758001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0758001.png
# 0758004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0758004.png
# 0759003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0759003.png
# 0759000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0759000.png
# 0757001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0757001.png
# 0758000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0758000.png
# 0757003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0757003.png
# 0759004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0759004.png
# 0758003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0758003.png
# 0757000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0757000.png
# 0757007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0757007.png
# 0758007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0758007.png
# 0759001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0759001.png
# 0761003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0761003.png
# 0761000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0761000.png
# 0760003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0760003.png
# 0760007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0760007.png
# 0761004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0761004.png
# 0761001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0761001.png
# 0760001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0760001.png
# 0760000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0760000.png
# 0759007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0759007.png
# 0762001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0762001.png
# 0762000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0762000.png
# 0760004.png
# ...
# 0694003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0694003.png
# 0695006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0695006.png
# 0695001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0695001.png
# 0694006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0694006.png
# 0694004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0694004.png
# 0696007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0696007.png
# 0696002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0696002.png
# 0697006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697006.png
# 0699002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699002.png
# 0697007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697007.png
# 0698005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698005.png
# 0697005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697005.png
# 0697002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697002.png
# 0698004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698004.png
# 0697001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697001.png
# 0698007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698007.png
# 0699001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699001.png
# 0699004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699004.png
# 0698006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698006.png
# 0697003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697003.png
# 0698002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698002.png
# 0697004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0697004.png
# 0699005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699005.png
# 0698001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698001.png
# 0699003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699003.png
# 0698003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0698003.png
# 0702001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702001.png
# 0699006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699006.png
# 0700007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700007.png
# 0700002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700002.png
# 0702002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702002.png
# 0701005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701005.png
# 0701003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701003.png
# 0700004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700004.png
# 0701002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701002.png
# 0699007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0699007.png
# 0700005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700005.png
# 0700003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700003.png
# 0701001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701001.png
# 0701007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701007.png
# 0700006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700006.png
# 0700001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0700001.png
# 0702003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702003.png
# 0701006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701006.png
# 0701004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0701004.png
# 0703001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703001.png
# 0703007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703007.png
# 0702005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702005.png
# 0705002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705002.png
# 0704003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0704003.png
# 0703004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703004.png
# 0704001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0704001.png
# 0702007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702007.png
# 0703006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703006.png
# 0703003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703003.png
# 0703005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703005.png
# 0703000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703000.png
# 0704006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0704006.png
# 0705000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705000.png
# 0703002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0703002.png
# 0705001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705001.png
# 0702004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702004.png
# 0704002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0704002.png
# 0704007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0704007.png
# 0704004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0704004.png
# 0702006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0702006.png
# 0708001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708001.png
# 0708000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708000.png
# 0706006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706006.png
# 0707004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0707004.png
# 0707007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0707007.png
# 0707003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0707003.png
# 0705006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705006.png
# 0707006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0707006.png
# 0705003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705003.png
# 0706001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706001.png
# 0705004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705004.png
# 0707001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0707001.png
# 0706005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706005.png
# 0706007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706007.png
# 0706003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706003.png
# 0706004.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706004.png
# 0706000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706000.png
# 0707000.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0707000.png
# 0706002.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0706002.png
# 0705007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0705007.png
# 0708007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708007.png
# 0709007.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0709007.png
# 0709006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0709006.png
# 0708003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708003.png
# 0709003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0709003.png
# 0710003.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0710003.png
# 0708005.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708005.png
# 0709001.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0709001.png
# 0708006.png
# /content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/translated_1456_epoch_4200_logs(551)/0708006.png

# %% [markdown]
# #Sampling Images from One folder to another folder########

# %%
import os
import random
import shutil


files_list = []

for root, dirs, files in os.walk("/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/trainA"):
    for file in files:
        #all 
        if file.endswith(".jpg") or file.endswith(".png") or file.endswith(".jpeg"):
            files_list.append(os.path.join(root, file))


#print images
#lets me count and print the amount of jpeg,jpg,pmg 
file_count = len(files_list)
print (file_count)

# print files_list   
filesToCopy = random.sample(files_list, 1456)  #prints 200 random files from list 

destPath = "/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/real_image_1456"

# if destination dir does not exists, create it
if os.path.isdir(destPath) == False:
        os.makedirs(destPath)

# iteraate over all random files and copy them
for file in filesToCopy:
    shutil.copy(file, destPath)
# Out:
# 1747

# %% [markdown]
# #FID score calculation of Images

# %%
from PIL import Image
import os

synthetic_img_path="/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/trainB"
real_img_path="/content/gdrive/MyDrive/Flood_Project/Synthetic_Flood_Images_Blender/image_data_August_28/data_1747(real)/real_image_1456"

# %%
synthetic_images=[]
real_images=[]

for img in os.listdir(synthetic_img_path):
  image=Image.open(os.path.join(synthetic_img_path,img))
  synthetic_images.append(image)

for img in os.listdir(real_img_path):
  image=Image.open(os.path.join(real_img_path,img))
  real_images.append(image)

# %%
# convert integer to floating point values
#images1 = np.asarray(synthetic_images, dtype="float32")
#images2 = np.asarray(real_images, dtype="float32")
images1=[]
for img in synthetic_images:
  image=np.asarray(img, dtype="float32")
  images1.append(image)

# %%
images2=[]
for img in real_images:
  image=np.asarray(img, dtype="float32")
  images2.append(image)

# %%
# example of calculating the frechet inception distance in Keras
import numpy
from numpy import cov
from numpy import trace
from numpy import iscomplexobj
from numpy import asarray
from numpy.random import randint
from scipy.linalg import sqrtm
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from skimage.transform import resize

# %%
# scale an array of images to a new size
def scale_images(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return asarray(images_list)
 
# calculate frechet inception distance
def calculate_fid(model, images1, images2):
	# calculate activations
	act1 = model.predict(images1)
	act2 = model.predict(images2)
	# calculate mean and covariance statistics
	mu1, sigma1 = act1.mean(axis=0), cov(act1, rowvar=False)
	mu2, sigma2 = act2.mean(axis=0), cov(act2, rowvar=False)
	# calculate sum squared difference between means
	ssdiff = numpy.sum((mu1 - mu2)**2.0)
	# calculate sqrt of product between cov
	covmean = sqrtm(sigma1.dot(sigma2))
	# check and correct imaginary numbers from sqrt
	if iscomplexobj(covmean):
		covmean = covmean.real
	# calculate score
	fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
	return fid
 
# prepare the inception v3 model
model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))

# %%
# resize images
images1 = scale_images(images1, (299,299,3))
images2 = scale_images(images2, (299,299,3))
print('Scaled', images1.shape, images2.shape)
# Out:
# Scaled (1466, 299, 299, 3) (1456, 299, 299, 3)

# %%
# pre-process images
images1 = preprocess_input(images1)
images2 = preprocess_input(images2)

# %%
# fid between images1 and images2
fid = calculate_fid(model, images1, images2)
print('FID (different): %.3f' % fid)
# Out:
# FID (different): 284.108

# %% [markdown]
# #Resize Images and Save in Another Folder

# %%
from PIL import Image
import glob
import os

# new folder path (may need to alter for Windows OS)
# change path to your path
path = '/content/gdrive/MyDrive/Flood_Project/Real Images_and_mask/Real_Immage_and_mask_three_level/Sazara/car_image_256_256' #the path where to save resized images
# create new folder
if not os.path.exists(path):
    os.makedirs(path)

# loop over existing images and resize
# change path to your path
for filename in glob.glob('/content/gdrive/MyDrive/Flood_Project/Real Images_and_mask/Real_Immage_and_mask_three_level/Sazara/car_image/*.png'): #path of raw images
    img = Image.open(filename).resize((256,256))
    # save resized images to new folder with existing filename
    img.save('{}{}{}'.format(path,'/',os.path.split(filename)[1]))
